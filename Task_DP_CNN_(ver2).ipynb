# %% [markdown]
# # Task: Software Defect Prediction via Convolutional Neural Network
# ## Mô tả bài toán
# Dựa vào paper IEEE 2017 - DP-CNN đề xuất 1 phuơng pháp mới, DP-CNN (Defect Prediction via Convolutional Neural Network) là một phương pháp dự đoán lỗi phần mềm bằng cách kết hợp học sâu với các đặc trưng truyền thống. Thay vì chỉ dựa vào các đặc trưng thủ công như độ phức tạp mã nguồn, DP-CNN tự động học đặc trưng ngữ nghĩa và cấu trúc từ cây Cú pháp Trừu tượng (AST) bằng CNN, sau đó kết hợp với các đặc trưng truyền thống để cải thiện độ chính xác.
# ## Phương pháp đề xuất
# 1️⃣ Phân tích mã nguồn thành cây AST, trích xuất token quan trọng.
#
# 2️⃣ Mã hóa token thành vector số bằng kỹ thuật word embedding.
#
# 3️⃣ Sử dụng CNN để học đặc trưng ngữ nghĩa và cấu trúc từ mã nguồn.
#
# 4️⃣ Kết hợp với đặc trưng truyền thống để tối ưu dự đoán.
#
# 5️⃣ Huấn luyện mô hình và phân loại file là "có lỗi" hoặc "không lỗi".

# %% [markdown]
# # 1. Phân tích dữ liệu

# %% [markdown]
# - Dự kiến: Lấy tập Ant-1.6 để trainning và tập Ant-1.7 để test1
# - Tải bộ source code của bộ Ant-1.6 và Ant-1.7 từ archive.apache.org.
# - Đọc dữ liệu csv chứa thông tin về các đặc trưng truyền thống về phần mềm và label cho biết code lỗi hay không
# - Lọc chỉ lấy những file source code có trong file csv đã phân tích

# %% [markdown]
# ## Tải bộ source code trên archive.appache.org

# %%
# !wget https://archive.apache.org/dist/ant/source/apache-ant-1.6.0-src.tar.gz
# !tar -xvzf apache-ant-1.6.0-src.tar.gz

# !wget https://archive.apache.org/dist/ant/source/apache-ant-1.7.0-src.tar.gz
# !tar -xvzf apache-ant-1.7.0-src.tar.gz
# Out:
# --2025-03-21 01:08:43--  https://archive.apache.org/dist/ant/source/apache-ant-1.6.0-src.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7029218 (6.7M) [application/x-gzip]
# Saving to: ‘apache-ant-1.6.0-src.tar.gz.1’
#
# apache-ant-1.6.0-sr 100%[===================>]   6.70M  2.65MB/s    in 2.5s
#
# 2025-03-21 01:08:47 (2.65 MB/s) - ‘apache-ant-1.6.0-src.tar.gz.1’ saved [7029218/7029218]
#
# apache-ant-1.6.0/bootstrap.sh
# apache-ant-1.6.0/build.sh
# apache-ant-1.6.0/
# apache-ant-1.6.0/docs/
# apache-ant-1.6.0/docs/ant2/
# apache-ant-1.6.0/docs/images/
# apache-ant-1.6.0/docs/manual/
# apache-ant-1.6.0/docs/manual/CoreTasks/
# apache-ant-1.6.0/docs/manual/CoreTypes/
# apache-ant-1.6.0/docs/manual/Integration/
# apache-ant-1.6.0/docs/manual/OptionalTasks/
# apache-ant-1.6.0/docs/manual/OptionalTypes/
# apache-ant-1.6.0/docs/manual/stylesheets/
# apache-ant-1.6.0/docs/projects/
# apache-ant-1.6.0/docs/projects/antidote/
# apache-ant-1.6.0/docs/projects/antidote/images/
# apache-ant-1.6.0/docs/projects/antlib/
# apache-ant-1.6.0/lib/
# apache-ant-1.6.0/src/
# apache-ant-1.6.0/src/antidote/
# apache-ant-1.6.0/src/etc/
# apache-ant-1.6.0/src/etc/checkstyle/
# apache-ant-1.6.0/src/etc/testcases/
# apache-ant-1.6.0/src/etc/testcases/core/
# apache-ant-1.6.0/src/etc/testcases/core/containersrc/
# apache-ant-1.6.0/src/etc/testcases/core/containersrc/test/
# apache-ant-1.6.0/src/etc/testcases/core/include/
# apache-ant-1.6.0/src/etc/testcases/core/include/basic/
# apache-ant-1.6.0/src/etc/testcases/core/include/frag#ment/
# apache-ant-1.6.0/src/etc/testcases/core/include/included_file_parse_error/
# apache-ant-1.6.0/src/etc/testcases/core/include/included_file_task_error/
# apache-ant-1.6.0/src/etc/testcases/core/include/including_file_parse_error/
# apache-ant-1.6.0/src/etc/testcases/core/include/including_file_task_error/
# apache-ant-1.6.0/src/etc/testcases/core/include/with space/
# apache-ant-1.6.0/src/etc/testcases/core/loaderref/
# apache-ant-1.6.0/src/etc/testcases/core/loaderref/src/
# apache-ant-1.6.0/src/etc/testcases/core/topleveltasks/
# apache-ant-1.6.0/src/etc/testcases/filters/
# apache-ant-1.6.0/src/etc/testcases/filters/expected/
# apache-ant-1.6.0/src/etc/testcases/filters/input/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/ant/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/checksum/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/checksum/foo/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/checksum/foo/zap/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/concat-input/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/conditions/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copy/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copy/expected/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copy/input/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/email/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/exec/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/subdir/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifests/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/antlr/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src1/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src2/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src3/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src4/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src4/test/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src5/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/dotnet/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/expected/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/expected/de/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/input/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/output/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/output/de/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/image/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/image/src/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jdepend/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/WEB-INF/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/junitreport/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/net/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/script/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/sitraka/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/sos/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/unix/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/vss/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/wsdl/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/replace/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/style/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/subant/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/subant/subant-test1/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/subant/subant-test2/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/xmlproperty/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/xmlproperty/goldfiles/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/xmlproperty/inputs/
# apache-ant-1.6.0/src/etc/testcases/taskdefs/zip/
# apache-ant-1.6.0/src/etc/testcases/types/
# apache-ant-1.6.0/src/etc/testcases/types/assertions/
# apache-ant-1.6.0/src/etc/testcases/types/gold/
# apache-ant-1.6.0/src/main/
# apache-ant-1.6.0/src/main/org/
# apache-ant-1.6.0/src/main/org/apache/
# apache-ant-1.6.0/src/main/org/apache/tools/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/filters/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/filters/util/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/helper/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/input/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/launch/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/listener/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/loader/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/compilers/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/condition/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/cvslib/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/email/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/ccm/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/clearcase/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/depend/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/depend/constantpool/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/dotnet/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/ejb/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/extension/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/extension/resolvers/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/i18n/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/ide/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/image/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/j2ee/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/javacc/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/jdepend/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/jlink/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/jsp/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/jsp/compilers/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/junit/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/metamata/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/net/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/perforce/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/pvcs/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/scm/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/script/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/sitraka/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/sitraka/bytecode/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/sitraka/bytecode/attributes/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/sos/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/sound/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/splash/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/ssh/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/starteam/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/unix/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/vss/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/optional/windows/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/rmic/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/types/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/types/optional/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/types/optional/depend/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/types/optional/image/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/types/resolver/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/types/selectors/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/types/selectors/modifiedselector/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/util/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/util/depend/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/util/depend/bcel/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/util/facade/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/util/optional/
# apache-ant-1.6.0/src/main/org/apache/tools/ant/util/regexp/
# apache-ant-1.6.0/src/main/org/apache/tools/bzip2/
# apache-ant-1.6.0/src/main/org/apache/tools/mail/
# apache-ant-1.6.0/src/main/org/apache/tools/tar/
# apache-ant-1.6.0/src/main/org/apache/tools/zip/
# apache-ant-1.6.0/src/script/
# apache-ant-1.6.0/src/testcases/
# apache-ant-1.6.0/src/testcases/org/
# apache-ant-1.6.0/src/testcases/org/apache/
# apache-ant-1.6.0/src/testcases/org/apache/tools/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/filters/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/condition/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/dir1/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/dir2/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/email/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/depend/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/i18n/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/image/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/jdepend/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/junit/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/metamata/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/net/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/perforce/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/script/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/sitraka/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/sos/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/splash/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/ssh/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/unix/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/taskdefs/optional/vss/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/types/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/types/optional/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/types/optional/depend/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/types/selectors/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/util/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/util/facade/
# apache-ant-1.6.0/src/testcases/org/apache/tools/ant/util/regexp/
# apache-ant-1.6.0/src/testcases/org/apache/tools/mail/
# apache-ant-1.6.0/src/testcases/org/apache/tools/tar/
# apache-ant-1.6.0/src/testcases/org/apache/tools/zip/
# apache-ant-1.6.0/src/testcases/org/example/
# apache-ant-1.6.0/src/testcases/org/example/junit/
# apache-ant-1.6.0/src/testcases/org/example/tasks/
# apache-ant-1.6.0/src/testcases/org/example/types/
# apache-ant-1.6.0/KEYS
# apache-ant-1.6.0/LICENSE
# apache-ant-1.6.0/LICENSE.dom
# apache-ant-1.6.0/LICENSE.sax
# apache-ant-1.6.0/LICENSE.xerces
# apache-ant-1.6.0/README
# apache-ant-1.6.0/WHATSNEW
# apache-ant-1.6.0/bootstrap.bat
# apache-ant-1.6.0/build.bat
# apache-ant-1.6.0/build.xml
# apache-ant-1.6.0/docs/LICENSE
# apache-ant-1.6.0/docs/ant2/FunctionalRequirements.html
# apache-ant-1.6.0/docs/ant2/VFS.txt
# apache-ant-1.6.0/docs/ant2/actionlist.html
# apache-ant-1.6.0/docs/ant2/features.html
# apache-ant-1.6.0/docs/ant2/original-specification.html
# apache-ant-1.6.0/docs/ant2/requested-features.html
# apache-ant-1.6.0/docs/ant2/requested-features.txt
# apache-ant-1.6.0/docs/ant_in_anger.html
# apache-ant-1.6.0/docs/ant_task_guidelines.html
# apache-ant-1.6.0/docs/antnews.html
# apache-ant-1.6.0/docs/appendix_e.pdf
# apache-ant-1.6.0/docs/breadcrumbs.js
# apache-ant-1.6.0/docs/bylaws.html
# apache-ant-1.6.0/docs/contributors.html
# apache-ant-1.6.0/docs/cvs.html
# apache-ant-1.6.0/docs/external.html
# apache-ant-1.6.0/docs/faq.html
# apache-ant-1.6.0/docs/favicon.ico
# apache-ant-1.6.0/docs/images/JDJEditorsChoiceAward.jpg
# apache-ant-1.6.0/docs/images/ant_logo.ico
# apache-ant-1.6.0/docs/images/ant_logo_large.gif
# apache-ant-1.6.0/docs/images/ant_logo_medium.gif
# apache-ant-1.6.0/docs/images/ant_logo_small.gif
# apache-ant-1.6.0/docs/images/beta.png
# apache-ant-1.6.0/docs/images/current.gif
# apache-ant-1.6.0/docs/images/group-logo.gif
# apache-ant-1.6.0/docs/images/jp_rcwinner_2003.gif
# apache-ant-1.6.0/docs/images/jw_ec_logo_winner2002.gif
# apache-ant-1.6.0/docs/images/jw_ec_logo_winner2003.gif
# apache-ant-1.6.0/docs/images/label.gif
# apache-ant-1.6.0/docs/images/menu-left.gif
# apache-ant-1.6.0/docs/images/menu-right.gif
# apache-ant-1.6.0/docs/images/page.gif
# apache-ant-1.6.0/docs/images/printer.gif
# apache-ant-1.6.0/docs/images/project-logo.gif
# apache-ant-1.6.0/docs/images/sdm_productivity_award.gif
# apache-ant-1.6.0/docs/images/search-left.gif
# apache-ant-1.6.0/docs/images/search-right.gif
# apache-ant-1.6.0/docs/images/spacer.gif
# apache-ant-1.6.0/docs/images/tab-left.gif
# apache-ant-1.6.0/docs/images/tab-right.gif
# apache-ant-1.6.0/docs/images/tabSel-left.gif
# apache-ant-1.6.0/docs/images/tabSel-right.gif
# apache-ant-1.6.0/docs/index.html
# apache-ant-1.6.0/docs/legal.html
# apache-ant-1.6.0/docs/license.html
# apache-ant-1.6.0/docs/mail.html
# apache-ant-1.6.0/docs/manual/CoreTasks/ant.html
# apache-ant-1.6.0/docs/manual/CoreTasks/antcall.html
# apache-ant-1.6.0/docs/manual/CoreTasks/antstructure.html
# apache-ant-1.6.0/docs/manual/CoreTasks/apply.html
# apache-ant-1.6.0/docs/manual/CoreTasks/available.html
# apache-ant-1.6.0/docs/manual/CoreTasks/basename.html
# apache-ant-1.6.0/docs/manual/CoreTasks/buildnumber.html
# apache-ant-1.6.0/docs/manual/CoreTasks/changelog.html
# apache-ant-1.6.0/docs/manual/CoreTasks/checksum.html
# apache-ant-1.6.0/docs/manual/CoreTasks/chmod.html
# apache-ant-1.6.0/docs/manual/CoreTasks/common.html
# apache-ant-1.6.0/docs/manual/CoreTasks/concat.html
# apache-ant-1.6.0/docs/manual/CoreTasks/condition.html
# apache-ant-1.6.0/docs/manual/CoreTasks/conditions.html
# apache-ant-1.6.0/docs/manual/CoreTasks/copy.html
# apache-ant-1.6.0/docs/manual/CoreTasks/copydir.html
# apache-ant-1.6.0/docs/manual/CoreTasks/copyfile.html
# apache-ant-1.6.0/docs/manual/CoreTasks/cvs.html
# apache-ant-1.6.0/docs/manual/CoreTasks/cvspass.html
# apache-ant-1.6.0/docs/manual/CoreTasks/cvstagdiff.html
# apache-ant-1.6.0/docs/manual/CoreTasks/defaultexcludes.html
# apache-ant-1.6.0/docs/manual/CoreTasks/delete.html
# apache-ant-1.6.0/docs/manual/CoreTasks/deltree.html
# apache-ant-1.6.0/docs/manual/CoreTasks/dependset.html
# apache-ant-1.6.0/docs/manual/CoreTasks/dirname.html
# apache-ant-1.6.0/docs/manual/CoreTasks/ear.html
# apache-ant-1.6.0/docs/manual/CoreTasks/echo.html
# apache-ant-1.6.0/docs/manual/CoreTasks/exec.html
# apache-ant-1.6.0/docs/manual/CoreTasks/fail.html
# apache-ant-1.6.0/docs/manual/CoreTasks/filter.html
# apache-ant-1.6.0/docs/manual/CoreTasks/fixcrlf.html
# apache-ant-1.6.0/docs/manual/CoreTasks/genkey.html
# apache-ant-1.6.0/docs/manual/CoreTasks/get.html
# apache-ant-1.6.0/docs/manual/CoreTasks/gunzip.html
# apache-ant-1.6.0/docs/manual/CoreTasks/gzip.html
# apache-ant-1.6.0/docs/manual/CoreTasks/import.html
# apache-ant-1.6.0/docs/manual/CoreTasks/input.html
# apache-ant-1.6.0/docs/manual/CoreTasks/jar.html
# apache-ant-1.6.0/docs/manual/CoreTasks/java.html
# apache-ant-1.6.0/docs/manual/CoreTasks/javac.html
# apache-ant-1.6.0/docs/manual/CoreTasks/javadoc.html
# apache-ant-1.6.0/docs/manual/CoreTasks/loadfile.html
# apache-ant-1.6.0/docs/manual/CoreTasks/loadproperties.html
# apache-ant-1.6.0/docs/manual/CoreTasks/macrodef.html
# apache-ant-1.6.0/docs/manual/CoreTasks/mail.html
# apache-ant-1.6.0/docs/manual/CoreTasks/manifest.html
# apache-ant-1.6.0/docs/manual/CoreTasks/mkdir.html
# apache-ant-1.6.0/docs/manual/CoreTasks/move.html
# apache-ant-1.6.0/docs/manual/CoreTasks/pack.html
# apache-ant-1.6.0/docs/manual/CoreTasks/parallel.html
# apache-ant-1.6.0/docs/manual/CoreTasks/patch.html
# apache-ant-1.6.0/docs/manual/CoreTasks/pathconvert.html
# apache-ant-1.6.0/docs/manual/CoreTasks/presetdef.html
# apache-ant-1.6.0/docs/manual/CoreTasks/property.html
# apache-ant-1.6.0/docs/manual/CoreTasks/recorder.html
# apache-ant-1.6.0/docs/manual/CoreTasks/rename.html
# apache-ant-1.6.0/docs/manual/CoreTasks/replace.html
# apache-ant-1.6.0/docs/manual/CoreTasks/rmic.html
# apache-ant-1.6.0/docs/manual/CoreTasks/sequential.html
# apache-ant-1.6.0/docs/manual/CoreTasks/signjar.html
# apache-ant-1.6.0/docs/manual/CoreTasks/sleep.html
# apache-ant-1.6.0/docs/manual/CoreTasks/sql.html
# apache-ant-1.6.0/docs/manual/CoreTasks/style.html
# apache-ant-1.6.0/docs/manual/CoreTasks/subant.html
# apache-ant-1.6.0/docs/manual/CoreTasks/sync.html
# apache-ant-1.6.0/docs/manual/CoreTasks/tar.html
# apache-ant-1.6.0/docs/manual/CoreTasks/taskdef.html
# apache-ant-1.6.0/docs/manual/CoreTasks/tempfile.html
# apache-ant-1.6.0/docs/manual/CoreTasks/touch.html
# apache-ant-1.6.0/docs/manual/CoreTasks/tstamp.html
# apache-ant-1.6.0/docs/manual/CoreTasks/typedef.html
# apache-ant-1.6.0/docs/manual/CoreTasks/unpack.html
# apache-ant-1.6.0/docs/manual/CoreTasks/untar.html
# apache-ant-1.6.0/docs/manual/CoreTasks/unzip.html
# apache-ant-1.6.0/docs/manual/CoreTasks/uptodate.html
# apache-ant-1.6.0/docs/manual/CoreTasks/waitfor.html
# apache-ant-1.6.0/docs/manual/CoreTasks/war.html
# apache-ant-1.6.0/docs/manual/CoreTasks/whichresource.html
# apache-ant-1.6.0/docs/manual/CoreTasks/xmlproperty.html
# apache-ant-1.6.0/docs/manual/CoreTasks/zip.html
# apache-ant-1.6.0/docs/manual/CoreTypes/antlib.html
# apache-ant-1.6.0/docs/manual/CoreTypes/assertions.html
# apache-ant-1.6.0/docs/manual/CoreTypes/custom-programming.html
# apache-ant-1.6.0/docs/manual/CoreTypes/description.html
# apache-ant-1.6.0/docs/manual/CoreTypes/dirset.html
# apache-ant-1.6.0/docs/manual/CoreTypes/filelist.html
# apache-ant-1.6.0/docs/manual/CoreTypes/fileset.html
# apache-ant-1.6.0/docs/manual/CoreTypes/filterchain.html
# apache-ant-1.6.0/docs/manual/CoreTypes/filterset.html
# apache-ant-1.6.0/docs/manual/CoreTypes/mapper.html
# apache-ant-1.6.0/docs/manual/CoreTypes/namespace.html
# apache-ant-1.6.0/docs/manual/CoreTypes/patternset.html
# apache-ant-1.6.0/docs/manual/CoreTypes/permissions.html
# apache-ant-1.6.0/docs/manual/CoreTypes/propertyset.html
# apache-ant-1.6.0/docs/manual/CoreTypes/selectors-program.html
# apache-ant-1.6.0/docs/manual/CoreTypes/selectors.html
# apache-ant-1.6.0/docs/manual/CoreTypes/xmlcatalog.html
# apache-ant-1.6.0/docs/manual/CoreTypes/zipfileset.html
# apache-ant-1.6.0/docs/manual/Integration/Antidote.html
# apache-ant-1.6.0/docs/manual/Integration/VAJAntTool.html
# apache-ant-1.6.0/docs/manual/Integration/anttool1.gif
# apache-ant-1.6.0/docs/manual/Integration/jext-plugin.html
# apache-ant-1.6.0/docs/manual/Integration/remacc.gif
# apache-ant-1.6.0/docs/manual/Integration/toolmenu.gif
# apache-ant-1.6.0/docs/manual/LICENSE
# apache-ant-1.6.0/docs/manual/OptionalTasks/BorlandEJBTasks.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/BorlandGenerateClient.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/antlr.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/attrib.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/cab.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/ccm.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/chgrp.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/chown.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/clearcase.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/csc.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/depend.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/dotnet.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/echoproperties.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/ejb.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/ftp.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/icontract.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/ilasm.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/ildasm.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/image-classdiagram.gif
# apache-ant-1.6.0/docs/manual/OptionalTasks/image.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/importtypelib.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jarlib-available.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jarlib-display.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jarlib-manifest.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jarlib-resolve.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/javacc.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/javah.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jdepend.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jjdoc.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jjtree.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jlink.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jpcoverage.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jsharpc.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/jspc.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/junit.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/junitreport.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/maudit.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/mimemail.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/mmetrics.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/mparse.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/native2ascii.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/netrexxc.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/perforce.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/perforce.html.orig
# apache-ant-1.6.0/docs/manual/OptionalTasks/propertyfile.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/pvcstask.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/renameextensions.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/replaceregexp.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/rexec.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/rpm.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/scp.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/script.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/scriptdef.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/serverdeploy.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/setproxy.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/sos.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/sound.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/splash.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/sshexec.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/starteam.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/stylebook.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/symlink.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/telnet.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/test.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/translate.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/vbc.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/vss.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/wljspc.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/wsdltodotnet.html
# apache-ant-1.6.0/docs/manual/OptionalTasks/xmlvalidate.html
# apache-ant-1.6.0/docs/manual/OptionalTypes/classfileset.html
# apache-ant-1.6.0/docs/manual/OptionalTypes/extension.html
# apache-ant-1.6.0/docs/manual/OptionalTypes/extensionset.html
# apache-ant-1.6.0/docs/manual/antexternal.html
# apache-ant-1.6.0/docs/manual/anttaskslist.html
# apache-ant-1.6.0/docs/manual/base_task_classes.html
# apache-ant-1.6.0/docs/manual/conceptstypeslist.html
# apache-ant-1.6.0/docs/manual/coretasklist.html
# apache-ant-1.6.0/docs/manual/cover.html
# apache-ant-1.6.0/docs/manual/credits.html
# apache-ant-1.6.0/docs/manual/develop.html
# apache-ant-1.6.0/docs/manual/developlist.html
# apache-ant-1.6.0/docs/manual/dirtasks.html
# apache-ant-1.6.0/docs/manual/favicon.ico
# apache-ant-1.6.0/docs/manual/feedback.html
# apache-ant-1.6.0/docs/manual/ide.html
# apache-ant-1.6.0/docs/manual/index.html
# apache-ant-1.6.0/docs/manual/inputhandler.html
# apache-ant-1.6.0/docs/manual/install.html
# apache-ant-1.6.0/docs/manual/installlist.html
# apache-ant-1.6.0/docs/manual/intro.html
# apache-ant-1.6.0/docs/manual/listeners.html
# apache-ant-1.6.0/docs/manual/optionaltasklist.html
# apache-ant-1.6.0/docs/manual/platform.html
# apache-ant-1.6.0/docs/manual/running.html
# apache-ant-1.6.0/docs/manual/runninglist.html
# apache-ant-1.6.0/docs/manual/stylesheets/antmanual.css
# apache-ant-1.6.0/docs/manual/sysclasspath.html
# apache-ant-1.6.0/docs/manual/tasksoverview.html
# apache-ant-1.6.0/docs/manual/toc.html
# apache-ant-1.6.0/docs/manual/tutorial-writing-tasks-src.zip
# apache-ant-1.6.0/docs/manual/tutorial-writing-tasks.html
# apache-ant-1.6.0/docs/manual/using.html
# apache-ant-1.6.0/docs/manual/usinglist.html
# apache-ant-1.6.0/docs/mission.html
# apache-ant-1.6.0/docs/page.css
# apache-ant-1.6.0/docs/problems.html
# apache-ant-1.6.0/docs/projects.html
# apache-ant-1.6.0/docs/projects/antidote/design.html
# apache-ant-1.6.0/docs/projects/antidote/images/screenshot.jpg
# apache-ant-1.6.0/docs/projects/antidote/index.html
# apache-ant-1.6.0/docs/projects/antidote/module.html
# apache-ant-1.6.0/docs/projects/antlib/antlib_classloaders.html
# apache-ant-1.6.0/docs/projects/antlib/antlib_contract.html
# apache-ant-1.6.0/docs/projects/antlib/antlib_descriptors.html
# apache-ant-1.6.0/docs/projects/antlib/antlib_namespaces.html
# apache-ant-1.6.0/docs/projects/antlib/antlib_roadmap.html
# apache-ant-1.6.0/docs/projects/antlib/index.html
# apache-ant-1.6.0/docs/projects/antlib/roles.html
# apache-ant-1.6.0/docs/projects/index.html
# apache-ant-1.6.0/docs/resources.html
# apache-ant-1.6.0/lib/README
# apache-ant-1.6.0/lib/xercesImpl.jar
# apache-ant-1.6.0/lib/xml-apis.jar
# apache-ant-1.6.0/src/antidote/WHAT-IS-THIS-P
# apache-ant-1.6.0/src/etc/ant-update.xsl
# apache-ant-1.6.0/src/etc/changelog.xsl
# apache-ant-1.6.0/src/etc/checkstyle/RequiredHeader.txt
# apache-ant-1.6.0/src/etc/checkstyle/checkstyle-config
# apache-ant-1.6.0/src/etc/checkstyle/checkstyle-frames.xsl
# apache-ant-1.6.0/src/etc/checkstyle/checkstyle-text.xsl
# apache-ant-1.6.0/src/etc/checkstyle/checkstyle-xdoc.xsl
# apache-ant-1.6.0/src/etc/coverage-frames.xsl
# apache-ant-1.6.0/src/etc/jdepend-frames.xsl
# apache-ant-1.6.0/src/etc/jdepend.xsl
# apache-ant-1.6.0/src/etc/junit-frames.xsl
# apache-ant-1.6.0/src/etc/junit-noframes.xsl
# apache-ant-1.6.0/src/etc/log.xsl
# apache-ant-1.6.0/src/etc/manifest
# apache-ant-1.6.0/src/etc/maudit-frames.xsl
# apache-ant-1.6.0/src/etc/mmetrics-frames.xsl
# apache-ant-1.6.0/src/etc/tagdiff.xsl
# apache-ant-1.6.0/src/etc/testcases/asf-logo.gif
# apache-ant-1.6.0/src/etc/testcases/core/case.xml
# apache-ant-1.6.0/src/etc/testcases/core/containersrc/test/SpecialSeq.java
# apache-ant-1.6.0/src/etc/testcases/core/directoryscanner.xml
# apache-ant-1.6.0/src/etc/testcases/core/immutable.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/basic/include.inc
# apache-ant-1.6.0/src/etc/testcases/core/include/basic/include.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/basic/relative.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/frag#ment/include.inc
# apache-ant-1.6.0/src/etc/testcases/core/include/frag#ment/include.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/frag#ment/relative.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/frag#ment/simple.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/included_file_parse_error/build.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/included_file_parse_error/included_file.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/included_file_task_error/build.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/included_file_task_error/included_file.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/including_file_parse_error/build.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/including_file_parse_error/included_file.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/including_file_task_error/build.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/including_file_task_error/included_file.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/with space/include.inc
# apache-ant-1.6.0/src/etc/testcases/core/include/with space/include.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/with space/relative.xml
# apache-ant-1.6.0/src/etc/testcases/core/include/with space/simple.xml
# apache-ant-1.6.0/src/etc/testcases/core/loaderref/loaderref.xml
# apache-ant-1.6.0/src/etc/testcases/core/loaderref/src/Task1.java
# apache-ant-1.6.0/src/etc/testcases/core/taskcontainer.xml
# apache-ant-1.6.0/src/etc/testcases/core/topleveltasks/notarget.xml
# apache-ant-1.6.0/src/etc/testcases/core/topleveltasks/targetlevelant.xml
# apache-ant-1.6.0/src/etc/testcases/core/topleveltasks/toplevelant.xml
# apache-ant-1.6.0/src/etc/testcases/filters/build.xml
# apache-ant-1.6.0/src/etc/testcases/filters/concat.xml
# apache-ant-1.6.0/src/etc/testcases/filters/dynamicfilter.xml
# apache-ant-1.6.0/src/etc/testcases/filters/expected/escapeunicode.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.head.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.headAllSkip.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.headLines.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.headLinesSkip.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.headSkip.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.headtail.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.tail.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.tailAllSkip.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.tailLines.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.tailLinesSkip.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/head-tail.tailSkip.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/linecontains.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/replacetokens.test
# apache-ant-1.6.0/src/etc/testcases/filters/expected/stripjavacomments.test
# apache-ant-1.6.0/src/etc/testcases/filters/head-tail.xml
# apache-ant-1.6.0/src/etc/testcases/filters/input/escapeunicode.test
# apache-ant-1.6.0/src/etc/testcases/filters/input/head-tail.small.test
# apache-ant-1.6.0/src/etc/testcases/filters/input/head-tail.test
# apache-ant-1.6.0/src/etc/testcases/filters/input/linecontains.test
# apache-ant-1.6.0/src/etc/testcases/filters/input/replacetokens.test
# apache-ant-1.6.0/src/etc/testcases/filters/input/stripjavacomments.test
# apache-ant-1.6.0/src/etc/testcases/filters/tokenfilter.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/abstractcvstask.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/ant.topleveltest.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/ant.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/ant/ant.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/ant/references.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/antlib.current-test.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/antlib.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/antstructure.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/available.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/basename.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/bunzip2.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/bzip2.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/calltarget.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/checksum.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/checksum/foo/Bar
# apache-ant-1.6.0/src/etc/testcases/taskdefs/checksum/foo/zap/Eenie
# apache-ant-1.6.0/src/etc/testcases/taskdefs/classloader.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/concat-input/A
# apache-ant-1.6.0/src/etc/testcases/taskdefs/concat-input/B
# apache-ant-1.6.0/src/etc/testcases/taskdefs/concat.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/condition.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/conditions/isreference.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copy.filterset
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copy.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copy/expected/utf-8
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copy/input/iso8859-1
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copydir.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/copyfile.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/cvspass.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/defaultexcludes.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/delete.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/deltree.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/dependset.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/dirname.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/dynamictask.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/echo.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/email/mail.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/exec/exec.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/exec/spawn.sh
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo-huge.tar.bz2
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo-huge.tar.gz
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo.gif.bz2
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo.gif.gz
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo.gif.md5
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo.gif.tar
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo.gif.tar.bz2
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo.gif.tar.gz
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/asf-logo.gif.zip
# apache-ant-1.6.0/src/etc/testcases/taskdefs/expected/copy.filterset.filtered
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fail.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/filter.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/filter1.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/filter2.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/filter3.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/filterdefs.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/build.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk1.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk2.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk3.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk4.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk5.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk6.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk7.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk8.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Junk9.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/Mac2Unix
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/crcrlf.dos
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/crcrlf.mac
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/crcrlf.unix
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/input.lf.utf16
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/expected/longlines.lf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk1.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk2.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk3.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk4.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk5.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk6.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk7.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk8.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Junk9.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/Mac2Unix
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/crcrlf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/input.crlf.utf16
# apache-ant-1.6.0/src/etc/testcases/taskdefs/fixcrlf/input/longlines.crlf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/get.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/gunzip.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/gzip.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/bad.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/import.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/import_bad_import.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/imported.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/subdir/importinsequential-inner.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/subdir/importinsequential.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/subdir/importintarget-inner.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/subdir/importintarget.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/subdir/serial.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/unnamed1.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/unnamed2.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/import/unnamedImport.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/initializeclass.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/input.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/input.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/jar.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/java.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/loadfile.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/loadproperties.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/macrodef.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifest.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifests/test1.mf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifests/test2.mf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifests/test3.mf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifests/test4.mf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifests/test5.mf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifests/test6.mf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/manifests/test7.mf
# apache-ant-1.6.0/src/etc/testcases/taskdefs/mkdir.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/move.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/multimap.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/WsdlToDotnet.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/antlr/antlr.g
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/antlr/antlr.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/antlr/extended.calc.g
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/antlr/java.g
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/antlr/java.tree.g
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/depend.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src1/A.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src1/B.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src1/C.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src1/D.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src1/E.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src2/A.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src2/B.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src3/A.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src3/B.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src4/test/ContainsOnlyInner.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src4/test/MethodParam.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src4/test/Outer.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src5/A.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/depend/src5/B.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/dotnet.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/dotnet/HelloWorld.wsdl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/dotnet/example.cs
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/dotnet/example.il
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/dotnet/example2.cs
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/dotnet/example2.il
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/dotnet/jsharp.java
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/echoproperties.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/echoproperties.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/expected/de/template.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/input/resources_ger_DE.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/input/template.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/output/de/template.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/i18n/translate/translate.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/image/image.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/image/src/badimage.jpg
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/image/src/largeimage.jpg
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jdepend/jdepend.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/1nvalid-classname.jsp
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/WEB-INF/web.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/default.jsp
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/missing_tld.jsp
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/simple.jsp
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/uriroot.jsp
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jsp/xml.jsp
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/jspc.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/junit.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/junitreport.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/junitreport/TEST-sampleproject.coins.CoinTest.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/junitreport/TEST-sampleproject.util.UniqueStringTest.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/net/ftp.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/propertyfile.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/pvcs.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/replaceregexp.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/replaceregexp.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/replaceregexp2.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/replaceregexp2.result.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/script.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/script/scriptdef.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/script_reference.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/sitraka/covreport-test.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/sos/sos.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/unix/symlink.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/vss/vss.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/wsdl/StockQuoteService.wsdl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xalan-redirect-in.xsl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/about.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/catalog
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/doc.dtd
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/doc.xsd
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/doc.xsl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/endpiece.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/endpiece2.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/iso-2022-jp.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/test.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/test.xsl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/utf-8.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xml/validate.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xmlvalidate.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xslt.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xsltliaison-encoding-in.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xsltliaison-encoding-in.xsl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xsltliaison-in.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xsltliaison-in.xsl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xsltliaison-include.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/optional/xsltliaison-include.xsl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/parallel.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/presetdef.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/property.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/property1.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/property2.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/property3.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/property4.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/property5.properties
# apache-ant-1.6.0/src/etc/testcases/taskdefs/rename.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/replace.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/replace/result.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/replace/source.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/replace/value.txt
# apache-ant-1.6.0/src/etc/testcases/taskdefs/signjar.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/sleep.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/style/build.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/style/data.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/style/printParams.xsl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/style/testNewerStylesheet.xsl
# apache-ant-1.6.0/src/etc/testcases/taskdefs/subant.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/subant/genericsubant.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/subant/subant-test1/mysubant.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/subant/subant-test2/mysubant.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/tar.xml
# apache-ant-1.6.0/src/etc/testcases/taskdefs/taskdef.xml
# ...
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/RmicAdvancedTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/RmicTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/SQLExecTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/SignJarTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/SleepTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/StyleTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/SubAntTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/SyncTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TStampTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TarTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TaskdefTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TaskdefsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TestProcess.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TimeProcess.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TouchTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TypeAdapterTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/TypedefTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/UntarTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/UnzipTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/UpToDateTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/WarTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/WhichResourceTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/XmlPropertyTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/XmlnsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/ZipTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/AntVersionTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/ContainsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/EqualsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/IsFailureTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/IsFileSelectedTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/IsReachableTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/IsReferenceTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/IsSignedTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/ParserSupportsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/TypeFoundTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/condition/XorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/cvslib/ChangeLogParserTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/cvslib/ChangeLogWriterTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/dir1/B.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/dir2/A.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/email/EmailAddressTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/email/EmailTaskTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/ANTLRTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/AbstractXSLTLiaisonTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/BeanShellScriptTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/DotnetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/EchoPropertiesTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/JavahTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/JspcTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/Native2AsciiTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/PropertyFileTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/PvcsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/ReplaceRegExpTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/RhinoReferenceTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/RhinoScriptTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/RpmTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/SchemaValidateTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/TraXLiaisonTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/WsdlToDotnetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/XmlValidateCatalogTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/XmlValidateTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/XsltTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/depend/DependTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/i18n/TranslateTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/image/ImageTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/jdepend/JDependTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/DOMUtilTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/JUnitClassLoaderTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/JUnitReportTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/JUnitTaskTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/JUnitTestListenerTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/JUnitTestRunnerTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/JUnitVersionHelperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/NoVmCrash.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/Printer.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/Sleeper.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/SuiteMethodTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/TestFormatter.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/VmCrash.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/XMLFormatterWithCDATAOnSystemOut.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/net/FTPTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/perforce/P4ChangeTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/perforce/p4integrate.xml
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/script/ScriptDefTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/sos/SOSTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/splash/SplashScreenTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/ssh/ScpTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/unix/SymlinkTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/taskdefs/optional/vss/MSVSSTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/AbstractFileSetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/AddTypeTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/AssertionsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/CommandlineJavaTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/CommandlineTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/DescriptionTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/DirSetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/EnumeratedAttributeTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/FileListTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/FileSetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/FilterSetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/FlexIntegerTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/MapperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/PathTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/PatternSetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/PermissionsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/PolyTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/PropertySetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/RedirectorElementTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/ResourceComparatorsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/ResourceOutputTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/TarFileSetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/XMLCatalogBuildFileTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/XMLCatalogTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/ZipFileSetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/mappers/GlobMapperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/mappers/MapperResult.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/mappers/RegexpPatternMapperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/optional/ScriptConditionTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/optional/ScriptMapperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/optional/ScriptSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/optional/depend/ClassFileSetTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/resources/JavaResourceTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/resources/TarResourceTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/BaseSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/ContainsRegexpTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/ContainsSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/DateSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/DependSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/DepthSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/FilenameSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/MockAlgorithm.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/MockCache.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/MockComparator.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/ModifiedSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/PresentSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/README
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/SignedSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/SizeSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/types/selectors/TypeSelectorTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/ClasspathUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/CollectionUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/DOMElementWriterTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/DateUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/FileUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/GlobPatternMapperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/JAXPUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/JavaEnvUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/LazyFileOutputStreamTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/LineOrientedOutputStreamTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/LoaderUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/PackageNameMapperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/ReaderInputStreamTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/ResourceUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/StringUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/UnPackageNameMapperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/XMLFragmentTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/facade/FacadeTaskHelperTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/facade/ImplementationSpecificArgumentTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/regexp/JakartaOroMatcherTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/regexp/JakartaOroRegexpTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/regexp/JakartaRegexpMatcherTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/regexp/JakartaRegexpRegexpTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/regexp/Jdk14RegexpMatcherTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/regexp/Jdk14RegexpRegexpTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/regexp/RegexpMatcherTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/ant/util/regexp/RegexpTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/mail/MailMessageTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/tar/TarEntryTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/tar/TarOutputStreamTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/tar/TarRoundTripTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/zip/AsiExtraFieldTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/zip/ExtraFieldUtilsTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/zip/ZipEntryTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/zip/ZipLongTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/zip/ZipOutputStreamTest.java
# apache-ant-1.7.0/src/tests/junit/org/apache/tools/zip/ZipShortTest.java
# apache-ant-1.7.0/src/tests/junit/org/example/junit/Output.java
# apache-ant-1.7.0/src/tests/junit/org/example/junit/ThreadedOutput.java
# apache-ant-1.7.0/src/tests/junit/org/example/junit/XmlParserTest.java
# apache-ant-1.7.0/src/tests/junit/org/example/tasks/TaskdefTestContainerTask.java
# apache-ant-1.7.0/src/tests/junit/org/example/tasks/TaskdefTestSimpleTask.java
# apache-ant-1.7.0/src/tests/junit/org/example/tasks/antlib.xml
# apache-ant-1.7.0/src/tests/junit/org/example/tasks/antlib2.xml
# apache-ant-1.7.0/src/tests/junit/org/example/types/TypedefTestType.java

# %% [markdown]
# ## Tải bộ dữ liệu Apache chứa các đặc trưng truyền thống

# %%
import os
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

train_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/ant-1.6.csv"
test_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/ant-1.7.csv"

train_csv = pd.read_csv(train_csv_path)
test_csv = pd.read_csv(test_csv_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2. Tiền xử lí dữ liệu

# %% [markdown]
# ## Chuẩn hoá dữ liệu giữa 2 dạng dữ liệu và loại bỏ

# %% [markdown]
# ### Chuẩn hoá giữa 2 dạng dữ liệu (csv và file source code)

# %%
# Chuẩn hóa tên file từ CSV để phù hợp với thư mục tools/
def convert_csv_name_to_java_filename(csv_name):
    """
    Chuyển:
    'org.apache.tools.ant.taskdefs.Property'  → 'ant/taskdefs/Property.java'
    'org.apache.tools.mail.MailLogger'        → 'mail/MailLogger.java'

    Cách làm:
    - Tìm 'tools.' trong đường dẫn, lấy phần sau nó làm thư mục gốc.
    - Nếu không có 'tools.', giữ nguyên.
    """
    parts = csv_name.split('.')
    if 'tools' in parts:
        index = parts.index('tools') + 1  # Lấy phần sau 'tools'
        return "/".join(parts[index:]) + ".java"
    return csv_name + ".java"


# Hàm lấy tất cả file Java trong thư mục mã nguồn (bao gồm tất cả thư mục con trong tools/)
def get_all_java_files(directory):
    """Lấy tất cả file Java trong thư mục tools/ """
    java_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".java"):
                java_files.append(os.path.join(root, file))
    return java_files


# Chuyển đường dẫn file Java thành dạng để so sánh với CSV
def convert_java_path_to_filename(java_path, base_dir):
    """Chuyển đường dẫn file Java thành tên tương đương trong CSV"""
    relative_path = os.path.relpath(java_path, base_dir)  # Lấy đường dẫn tương đối
    return relative_path.replace("\\", "/")  # Đảm bảo dạng Linux-style path

# %%
# Lấy danh sách file Java từ CSV (giữ đúng tầng thư mục `ant/`, `mail/`...)
train_csv_files = set(train_csv['name'].apply(convert_csv_name_to_java_filename))
test_csv_files = set(test_csv['name'].apply(convert_csv_name_to_java_filename))

# Đường dẫn đến mã nguồn Apache Ant (lấy toàn bộ tools/)
train_dir = "apache-ant-1.6.0/src/main/org/apache/tools"
test_dir = "apache-ant-1.7.0/src/main/org/apache/tools"

# Lấy tất cả file Java từ thư mục mã nguồn
train_files_all = get_all_java_files(train_dir)
test_files_all = get_all_java_files(test_dir)

# Tạo danh sách file từ mã nguồn ở dạng `ant/taskdefs/Property.java`
train_files_as_java = {convert_java_path_to_filename(f, train_dir) for f in train_files_all}
test_files_as_java = {convert_java_path_to_filename(f, test_dir) for f in test_files_all}

# Kiểm tra số lượng file khớp giữa CSV và mã nguồn
matched_train_files = train_files_as_java.intersection(train_csv_files)
matched_test_files = test_files_as_java.intersection(test_csv_files)

print(f"Số file trong CSV (Ant 1.6): {len(train_csv_files)}")
print(f"Số file có trong mã nguồn Ant 1.6: {len(train_files_all)}")
print(f"Số file trùng khớp giữa CSV và mã nguồn Ant 1.6: {len(matched_train_files)}")

print(f"Số file trong CSV (Ant 1.7): {len(test_csv_files)}")
print(f"Số file có trong mã nguồn Ant 1.7: {len(test_files_all)}")
print(f"Số file trùng khớp giữa CSV và mã nguồn Ant 1.7: {len(matched_test_files)}")
# Out:
# Số file trong CSV (Ant 1.6): 351
# Số file có trong mã nguồn Ant 1.6: 650
# Số file trùng khớp giữa CSV và mã nguồn Ant 1.6: 350
# Số file trong CSV (Ant 1.7): 745
# Số file có trong mã nguồn Ant 1.7: 778
# Số file trùng khớp giữa CSV và mã nguồn Ant 1.7: 741

# %% [markdown]
# ### Xoá những file source code không trùng trong file CSV
# Nhận thấy file source code thường có số lượng lớn hơn so với CSV. Chính vì thế, ta chỉ lấy những file source code và csv sau chuẩn hoá có name trùng nhau để có thể kết hợp các đặc trưng sau khi huấn luyện.

# %%
# Chỉ giữ lại các file Java có trong CSV
def get_java_files_by_csv(directory, csv_files):
    """Chỉ lấy file Java có trong danh sách CSV"""
    matched_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            full_path = os.path.join(root, file)
            relative_path = convert_java_path_to_filename(full_path, directory)
            if relative_path in csv_files:
                matched_files.append(full_path)
    return matched_files

# %%
filtered_train_files = get_java_files_by_csv(train_dir, matched_train_files)
filtered_test_files = get_java_files_by_csv(test_dir, matched_test_files)

print(f"Số file Java sau khi lọc theo CSV (Ant 1.6): {len(filtered_train_files)}")
print(f"Số file Java sau khi lọc theo CSV (Ant 1.7): {len(filtered_test_files)}")
# Out:
# Số file Java sau khi lọc theo CSV (Ant 1.6): 350
# Số file Java sau khi lọc theo CSV (Ant 1.7): 741

# %% [markdown]
# ### Lưu lại file csv sau khi đã xử lí và loại bỏ

# %%
# Lọc lại DataFrame chỉ giữ các file có trong Source Code
filtered_train_csv = train_csv[train_csv['name'].apply(convert_csv_name_to_java_filename).isin(matched_train_files)]
filtered_test_csv = test_csv[test_csv['name'].apply(convert_csv_name_to_java_filename).isin(matched_test_files)]

# Lưu lại CSV mới chỉ chứa các file có trong Source Code
filtered_train_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/filtered_ant-1.6.csv"
filtered_test_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/filtered_ant-1.7.csv"

filtered_train_csv.to_csv(filtered_train_csv_path, index=False)
filtered_test_csv.to_csv(filtered_test_csv_path, index=False)

print(f"File CSV mới đã được lưu: {filtered_train_csv_path}")
print(f"File CSV mới đã được lưu: {filtered_test_csv_path}")

# Đọc dữ liệu từ file CSV mới
filtered_train_df = pd.read_csv(filtered_train_csv_path)
filtered_test_df = pd.read_csv(filtered_test_csv_path)

# In số lượng file còn lại sau khi lọc
print(f"Số lượng file còn lại trong CSV mới (Ant 1.6): {filtered_train_df.shape[0]}")
print(f"Số lượng file còn lại trong CSV mới (Ant 1.7): {filtered_test_df.shape[0]}")
# Out:
# File CSV mới đã được lưu: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/filtered_ant-1.6.csv
# File CSV mới đã được lưu: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/filtered_ant-1.7.csv
# Số lượng file còn lại trong CSV mới (Ant 1.6): 350
# Số lượng file còn lại trong CSV mới (Ant 1.7): 741

# %% [markdown]
# ## Chia data và phân loại nhãn

# %% [markdown]
# ### Chuyển bài toán Multi-label classification thành bài toán Binary Label

# %%
# Chuyển đổi label: Nếu bug >= 1 thì gán thành 1, ngược lại giữ nguyên
filtered_train_df['bug'] = filtered_train_df['bug'].apply(lambda x: 1 if x >= 1 else 0)
filtered_test_df['bug'] = filtered_test_df['bug'].apply(lambda x: 1 if x >= 1 else 0)

# Kiểm tra lại số lượng mẫu sau khi chuẩn hóa
print("📌 Số lượng mỗi lớp sau khi xử lý trong tập train:")
print(filtered_train_df['bug'].value_counts())

print("\n📌 Số lượng mỗi lớp sau khi xử lý trong tập test:")
print(filtered_test_df['bug'].value_counts())
# Out:
# 📌 Số lượng mỗi lớp sau khi xử lý trong tập train:
# bug
# 0    258
# 1     92
# Name: count, dtype: int64
#
# 📌 Số lượng mỗi lớp sau khi xử lý trong tập test:
# bug
# 0    575
# 1    166
# Name: count, dtype: int64

# %% [markdown]
# ### Chia dữ liệu vào các tập train,test,validation

# %%
from sklearn.model_selection import train_test_split

# Chia tập train thành train và validation
train_df, val_df = train_test_split(filtered_train_df, test_size=0.2, random_state=42, stratify=filtered_train_df['bug'])
test_df = filtered_test_df

# Lưu tập train, validation và test mới sau khi chuẩn hóa
train_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/train_data_ant1.6.csv"
val_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/val_data_ant1.6.csv"
test_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/test_data_ant1.7.csv"

# Lưu các tập dữ liệu vào các file CSV tương ứng
train_df.to_csv(train_csv_path, index=False)
val_df.to_csv(val_csv_path, index=False)
test_df.to_csv(test_csv_path, index=False)

# In thông báo
print(f"Dữ liệu đã được chuẩn hóa và lưu tại: {train_csv_path}")
print(f"Dữ liệu đã được chuẩn hóa và lưu tại: {val_csv_path}")
print(f"Dữ liệu đã được chuẩn hóa và lưu tại: {test_csv_path}")
# Out:
# Dữ liệu đã được chuẩn hóa và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/train_data_ant1.6.csv
# Dữ liệu đã được chuẩn hóa và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/val_data_ant1.6.csv
# Dữ liệu đã được chuẩn hóa và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/test_data_ant1.7.csv

# %%
# Kiểm tra số lượng mẫu trong mỗi lớp của tập train
print("📌 Số lượng mỗi lớp trong tập train:")
print(train_df['bug'].value_counts())

# Kiểm tra số lượng mẫu trong mỗi lớp của tập validation
print("\n📌 Số lượng mỗi lớp trong tập validation:")
print(val_df['bug'].value_counts())

# Kiểm tra số lượng mẫu trong mỗi lớp của tập test
print("\n📌 Số lượng mỗi lớp trong tập test:")
print(test_df['bug'].value_counts())
# Out:
# 📌 Số lượng mỗi lớp trong tập train:
# bug
# 0    206
# 1     74
# Name: count, dtype: int64
#
# 📌 Số lượng mỗi lớp trong tập validation:
# bug
# 0    52
# 1    18
# Name: count, dtype: int64
#
# 📌 Số lượng mỗi lớp trong tập test:
# bug
# 0    575
# 1    166
# Name: count, dtype: int64

# %% [markdown]
# ## Kiểm tra cân bằng dữ liệu

# %% [markdown]
# ### Visualization phân phối dữ liệu dựa vào nhãn trước khi processing

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Kiểm tra số lượng mẫu trong từng lớp của từng tập (train, val, test)
train_bug_counts = train_df['bug'].value_counts()
val_bug_counts = val_df['bug'].value_counts()
test_bug_counts = test_df['bug'].value_counts()

# Vẽ biểu đồ cho tập train
plt.figure(figsize=(18, 5))

# Tập train
plt.subplot(1, 3, 1)
sns.barplot(x=train_bug_counts.index, y=train_bug_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập train")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Tập validation
plt.subplot(1, 3, 2)
sns.barplot(x=val_bug_counts.index, y=val_bug_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập validation")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Tập test
plt.subplot(1, 3, 3)
sns.barplot(x=test_bug_counts.index, y=test_bug_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập test")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Hiển thị các biểu đồ
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-078f49168a68>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=train_bug_counts.index, y=train_bug_counts.values, palette="viridis")
# <ipython-input-20-078f49168a68>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=val_bug_counts.index, y=val_bug_counts.values, palette="viridis")
# <ipython-input-20-078f49168a68>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=test_bug_counts.index, y=test_bug_counts.values, palette="viridis")

# %% [markdown]
# Nhận thấy dữ liệu Bug đang mất cân bằng so với dữ liệu No bug, có thể xử lí bằng 1 số cách như SMOTE, xoá bớt dữ liệu trong No Bug,.. Theo bài báo, ở đây xử lí bằng cáchnhân đôi các instance từ lớp

# %% [markdown]
# ### Xử lí mất cân bằng dữ liệu

# %%
# Nhân đôi các mẫu của lớp bug=1 trong các tập dữ liệu train, validation, test

# Tập train
bug_class_train = train_df[train_df['bug'] == 1]
duplicated_bug_class_train = pd.concat([bug_class_train, bug_class_train])
balanced_train_df = pd.concat([train_df[train_df['bug'] == 0], duplicated_bug_class_train])
balanced_train_df = balanced_train_df.reset_index(drop=True)

# Tập validation
bug_class_val = val_df[val_df['bug'] == 1]
duplicated_bug_class_val = pd.concat([bug_class_val, bug_class_val])
balanced_val_df = pd.concat([val_df[val_df['bug'] == 0], duplicated_bug_class_val])
balanced_val_df = balanced_val_df.reset_index(drop=True)

# Tập test
bug_class_test = test_df[test_df['bug'] == 1]
duplicated_bug_class_test = pd.concat([bug_class_test, bug_class_test])
balanced_test_df = pd.concat([test_df[test_df['bug'] == 0], duplicated_bug_class_test])
balanced_test_df = balanced_test_df.reset_index(drop=True)

# Kiểm tra kết quả
print(f"Số lượng file trong tập train sau cân bằng:\n{balanced_train_df['bug'].value_counts()}")
print(f"Số lượng file trong tập validation sau cân bằng:\n{balanced_val_df['bug'].value_counts()}")
print(f"Số lượng file trong tập test sau cân bằng:\n{balanced_test_df['bug'].value_counts()}")
# Out:
# Số lượng file trong tập train sau cân bằng:
# bug
# 0    206
# 1    148
# Name: count, dtype: int64
# Số lượng file trong tập validation sau cân bằng:
# bug
# 0    52
# 1    36
# Name: count, dtype: int64
# Số lượng file trong tập test sau cân bằng:
# bug
# 0    575
# 1    332
# Name: count, dtype: int64

# %%
# Lưu các tập dữ liệu đã được cân bằng
balanced_train_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_train_data.csv"
balanced_val_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_val_data.csv"
balanced_test_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_test_data.csv"

balanced_train_df.to_csv(balanced_train_csv_path, index=False)
balanced_val_df.to_csv(balanced_val_csv_path, index=False)
balanced_test_df.to_csv(balanced_test_csv_path, index=False)

print(f"Dữ liệu train đã được cân bằng và lưu tại: {balanced_train_csv_path}")
print(f"Dữ liệu validation đã được cân bằng và lưu tại: {balanced_val_csv_path}")
print(f"Dữ liệu test đã được cân bằng và lưu tại: {balanced_test_csv_path}")
# Out:
# Dữ liệu train đã được cân bằng và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_train_data.csv
# Dữ liệu validation đã được cân bằng và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_val_data.csv
# Dữ liệu test đã được cân bằng và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_test_data.csv

# %% [markdown]
# ### Visualization lại dữ liệu sau khi xử lí

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Kiểm tra số lượng mẫu trong từng lớp của từng tập (train, val, test) sau cân bằng
balanced_train_counts = balanced_train_df['bug'].value_counts()
balanced_val_counts = balanced_val_df['bug'].value_counts()
balanced_test_counts = balanced_test_df['bug'].value_counts()

# Vẽ biểu đồ cho tập balanced
plt.figure(figsize=(18, 5))

# Tập train balanced
plt.subplot(1, 3, 1)
sns.barplot(x=balanced_train_counts.index, y=balanced_train_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập train (Balanced)")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Tập validation balanced
plt.subplot(1, 3, 2)
sns.barplot(x=balanced_val_counts.index, y=balanced_val_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập validation (Balanced)")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Tập test balanced
plt.subplot(1, 3, 3)
sns.barplot(x=balanced_test_counts.index, y=balanced_test_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập test (Balanced)")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-ede4eba8d77c>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=balanced_train_counts.index, y=balanced_train_counts.values, palette="viridis")
# <ipython-input-23-ede4eba8d77c>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=balanced_val_counts.index, y=balanced_val_counts.values, palette="viridis")
# <ipython-input-23-ede4eba8d77c>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=balanced_test_counts.index, y=balanced_test_counts.values, palette="viridis")

# %% [markdown]
# ## Lọc ra các file mới chứa các source code trùng với file

# %% [markdown]
# ### Tập train

# %%
# Chuẩn hóa danh sách file bug=1 từ CSV để khớp với source code
bug_files_csv = set(train_df['name'].apply(convert_csv_name_to_java_filename))

# Chuẩn hóa danh sách file từ source code để có dạng giống CSV
source_files_formatted = set(convert_java_path_to_filename(f, train_dir) for f in filtered_train_files)

print(f"📌 Tổng số file trong CSV: {len(bug_files_csv)}")
print(f"📌 Tổng số file source code có trong thư mục: {len(source_files_formatted)}")

# Lọc ra các file trong train_dir có tên trùng với CSV
matched_files = bug_files_csv.intersection(source_files_formatted)

# Lọc danh sách file từ train_dir để chỉ giữ các file có trong matched_files
train_files_new = [f for f in filtered_train_files if convert_java_path_to_filename(f, train_dir) in matched_files]

train_new_df = pd.DataFrame({'name': train_files_new})
print(f"📌 Tổng số file source code có trong thư mục sau khi lọc: {len(train_files_new)}")
# Out:
# 📌 Tổng số file trong CSV: 280
# 📌 Tổng số file source code có trong thư mục: 350
# 📌 Tổng số file source code có trong thư mục sau khi lọc: 280

# %% [markdown]
# ### Tập validation

# %%
# Chuẩn hóa danh sách file bug=1 từ CSV để khớp với source code
bug_files_csv = set(val_df['name'].apply(convert_csv_name_to_java_filename))

# Chuẩn hóa danh sách file từ source code để có dạng giống CSV
source_files_formatted = set(convert_java_path_to_filename(f, train_dir) for f in filtered_train_files)

print(f"📌 Tổng số file trong CSV: {len(bug_files_csv)}")
print(f"📌 Tổng số file source code có trong thư mục: {len(source_files_formatted)}")

# Lọc ra các file trong train_dir có tên trùng với CSV
matched_files = bug_files_csv.intersection(source_files_formatted)

# Lọc danh sách file từ train_dir để chỉ giữ các file có trong matched_files
val_dir_new = [f for f in filtered_train_files if convert_java_path_to_filename(f, train_dir) in matched_files]

# Lọc danh sách file từ train_dir để chỉ giữ các file có trong matched_files
val_files_new = [f for f in filtered_train_files if convert_java_path_to_filename(f, train_dir) in matched_files]

val_new_df= pd.DataFrame({'name': val_files_new})
print(f"📌 Tổng số file source code có trong thư mục sau khi lọc: {len(val_files_new)}")
# Out:
# 📌 Tổng số file trong CSV: 70
# 📌 Tổng số file source code có trong thư mục: 350
# 📌 Tổng số file source code có trong thư mục sau khi lọc: 70

# %% [markdown]
# ## Nhân đôi file dữ liệu trong source code

# %% [markdown]
# Để đảm bảo dữ liệu huấn luyện được đồng bộ giữa CSV và mã nguồn,` cần nhân đôi các file source code tương ứng với các file đã bị nhân đôi trong CSV.

# %% [markdown]
# ### Tập train

# %%
import shutil
# 🔹 Lọc danh sách file có bug=1 từ CSV
bug_train_csv = set(train_df[train_df['bug'] == 1]['name'].apply(convert_csv_name_to_java_filename))

# 🔹 Lọc danh sách file source code có bug=1
train_files_new_1 = [file for file in filtered_train_files if convert_java_path_to_filename(file, train_dir) in bug_train_csv]

print(f"📌 Tổng số file bug=1 trong CSV: {len(bug_train_csv)}")
print(f"📌 Tổng số file source code có bug=1: {len(train_files_new_1)}")

# 🔹 3. Nhân đôi file source code có bug=1 và cập nhật danh sách
duplicated_files = []
for file in train_files_new_1:
    duplicate_file_path = file.replace(".java", "_dup.java")  # Tạo tên file mới
    shutil.copy(file, duplicate_file_path)  # Sao chép file
    duplicated_files.append(duplicate_file_path)

# 🔹 4. Cập nhật danh sách filtered_train_files
train_files_new += duplicated_files  # Thêm file nhân đôi vào danh sách gốc

# 🔹 5. Kiểm tra lại số lượng file sau nhân đôi
print(f"📌 Số file source code gốc (train set): {len(train_files_new) - len(duplicated_files)}")
print(f"📌 Số file source code nhân đôi: {len(duplicated_files)}")
print(f"✅ Tổng số file source code sau nhân đôi: {len(train_files_new)}")

# 🔹 6. Hiển thị danh sách file đã nhân đôi
print("\n📜 Danh sách file đã nhân đôi:")
print(duplicated_files[:10])  # Hiển thị 10 file đầu tiên
# Out:
# 📌 Tổng số file bug=1 trong CSV: 74
# 📌 Tổng số file source code có bug=1: 74
# 📌 Số file source code gốc (train set): 280
# 📌 Số file source code nhân đôi: 74
# ✅ Tổng số file source code sau nhân đôi: 354
#
# 📜 Danh sách file đã nhân đôi:
# ['apache-ant-1.6.0/src/main/org/apache/tools/zip/ZipOutputStream_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/zip/ZipEntry_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/zip/ZipFile_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/ProjectHelper_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/ComponentHelper_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/Diagnostics_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/RuntimeConfigurable_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/ProjectComponent_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/Target_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/Project_dup.java']

# %% [markdown]
# ### Tập validation

# %%
import shutil

# 🔹 Lọc danh sách file có bug=1 từ CSV
bug_val_csv = set(val_df[val_df['bug'] == 1]['name'].apply(convert_csv_name_to_java_filename))

# 🔹 Lọc danh sách file source code có bug=1
val_files_new_1 = [file for file in val_files_new if convert_java_path_to_filename(file, train_dir) in bug_val_csv]

print(f"📌 Tổng số file bug=1 trong CSV: {len(bug_val_csv)}")
print(f"📌 Tổng số file source code có bug=1: {len(val_files_new_1)}")

# 🔹 3. Nhân đôi file source code có bug=1 và cập nhật danh sách
duplicated_files = []
for file in val_files_new_1:
    duplicate_file_path = file.replace(".java", "_dup.java")  # Tạo tên file mới
    shutil.copy(file, duplicate_file_path)  # Sao chép file
    duplicated_files.append(duplicate_file_path)

# 🔹 4. Cập nhật danh sách filtered_validation_files
val_files_new += duplicated_files  # Thêm file nhân đôi vào danh sách gốc

# 🔹 5. Kiểm tra lại số lượng file sau nhân đôi
print(f"📌 Số file source code gốc (validation set): {len(val_files_new) - len(duplicated_files)}")
print(f"📌 Số file source code nhân đôi: {len(duplicated_files)}")
print(f"✅ Tổng số file source code sau nhân đôi: {len(val_files_new)}")

# 🔹 6. Hiển thị danh sách file đã nhân đôi
print("\n📜 Danh sách file đã nhân đôi:")
print(duplicated_files[:10])  # Hiển thị 10 file đầu tiên
# Out:
# 📌 Tổng số file bug=1 trong CSV: 18
# 📌 Tổng số file source code có bug=1: 18
# 📌 Số file source code gốc (validation set): 70
# 📌 Số file source code nhân đôi: 18
# ✅ Tổng số file source code sau nhân đôi: 88
#
# 📜 Danh sách file đã nhân đôi:
# ['apache-ant-1.6.0/src/main/org/apache/tools/ant/UnknownElement_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/Task_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/IntrospectionHelper_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/PropertyHelper_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/Definer_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/Replace_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/PumpStreamHandler_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/DependSet_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/MacroInstance_dup.java', 'apache-ant-1.6.0/src/main/org/apache/tools/ant/taskdefs/SQLExec_dup.java']

# %% [markdown]
# ### Tập test

# %%
import shutil

# 🔹 Lọc danh sách file có bug=1 từ CSV
bug_test_csv = set(test_df[test_df['bug'] == 1]['name'].apply(convert_csv_name_to_java_filename))

# 🔹 Lọc danh sách file source code có bug=1
test_files_new_1 = [file for file in filtered_test_files if convert_java_path_to_filename(file, test_dir) in bug_test_csv]

print(f"📌 Tổng số file bug=1 trong CSV: {len(bug_test_csv)}")
print(f"📌 Tổng số file source code có bug=1: {len(test_files_new_1)}")

# 🔹 3. Nhân đôi file source code có bug=1 và cập nhật danh sách
duplicated_files = []
for file in test_files_new_1:
    duplicate_file_path = file.replace(".java", "_dup.java")  # Tạo tên file mới
    shutil.copy(file, duplicate_file_path)  # Sao chép file
    duplicated_files.append(duplicate_file_path)

# 🔹 4. Cập nhật danh sách filtered_test_files
filtered_test_files += duplicated_files  # Thêm file nhân đôi vào danh sách gốc

# 🔹 5. Kiểm tra lại số lượng file sau nhân đôi
print(f"📌 Số file source code gốc (test set): {len(filtered_test_files) - len(duplicated_files)}")
print(f"📌 Số file source code nhân đôi: {len(duplicated_files)}")
print(f"✅ Tổng số file source code sau nhân đôi: {len(filtered_test_files)}")

# 🔹 6. Hiển thị danh sách file đã nhân đôi
print("\n📜 Danh sách file đã nhân đôi:")
print(duplicated_files[:10])  # Hiển thị 10 file đầu tiên
# Out:
# 📌 Tổng số file bug=1 trong CSV: 166
# 📌 Tổng số file source code có bug=1: 166
# 📌 Số file source code gốc (test set): 741
# 📌 Số file source code nhân đôi: 166
# ✅ Tổng số file source code sau nhân đôi: 907
#
# 📜 Danh sách file đã nhân đôi:
# ['apache-ant-1.7.0/src/main/org/apache/tools/bzip2/CBZip2InputStream_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/bzip2/CBZip2OutputStream_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/zip/UnrecognizedExtraField_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/zip/AsiExtraField_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/zip/ZipShort_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/zip/ExtraFieldUtils_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/zip/ZipOutputStream_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/zip/ZipEntry_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/zip/ZipFile_dup.java', 'apache-ant-1.7.0/src/main/org/apache/tools/zip/ZipLong_dup.java']

# %% [markdown]
# # 2. Phân tích cây AST

# %%
# !pip install javalang
# Out:
# Collecting javalang
#   Downloading javalang-0.13.0-py3-none-any.whl.metadata (805 bytes)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from javalang) (1.17.0)
# Downloading javalang-0.13.0-py3-none-any.whl (22 kB)
# Installing collected packages: javalang
# Successfully installed javalang-0.13.0

# %%
import javalang

def extract_tokens_from_file(file_path):
    """Trích xuất các token quan trọng từ cây AST của mã nguồn Java"""
    try:
        with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
            code = f.read()

        tokens = []
        tree = javalang.parse.parse(code)  # Phân tích mã nguồn thành AST

        for path, node in tree:
            if isinstance(node, javalang.tree.MethodInvocation):
                tokens.append(node.member)
            elif isinstance(node, javalang.tree.ClassDeclaration):
                tokens.append(node.name)
            elif isinstance(node, javalang.tree.ConstructorDeclaration):
                tokens.append(node.name)
            elif isinstance(node, javalang.tree.VariableDeclarator):
                tokens.append(node.name)
            elif isinstance(node, javalang.tree.MemberReference):
                tokens.append(node.member)
            elif isinstance(node, javalang.tree.IfStatement):
                tokens.append("<IF>")
            elif isinstance(node, javalang.tree.ForStatement):
                tokens.append("<FOR>")
            elif isinstance(node, javalang.tree.WhileStatement):
                tokens.append("<WHILE>")
            elif isinstance(node, javalang.tree.CatchClause):
                tokens.append("<CATCH>")

        return tokens
    except Exception as e:
        print(f"Lỗi khi xử lý file {file_path}: {e}")
        return []

# %%
import javalang

def extract_tokens_from_file(file_path):
    """Trích xuất các token quan trọng từ cây AST của mã nguồn Java (cải tiến)."""
    try:
        with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
            code = f.read()

        tokens = []
        tree = javalang.parse.parse(code)  # Phân tích mã nguồn thành AST

        for path, node in tree:
            # ✅ Trích xuất tên Method và Constructor với tiền tố 'METHOD_'
            if isinstance(node, javalang.tree.MethodDeclaration):
                tokens.append(f"METHOD_{node.name}")
            elif isinstance(node, javalang.tree.ConstructorDeclaration):
                tokens.append(f"METHOD_{node.name}")

            # ✅ Lấy danh sách tên Class/Interface với tiền tố 'CLASS_'
            elif isinstance(node, javalang.tree.ClassDeclaration) or isinstance(node, javalang.tree.InterfaceDeclaration):
                tokens.append(f"CLASS_{node.name}")

            # ✅ Lấy biến với tiền tố 'VAR_' để phân biệt
            elif isinstance(node, javalang.tree.VariableDeclarator):
                tokens.append(f"VAR_{node.name}")

            # ✅ Lấy các thành viên class
            elif isinstance(node, javalang.tree.MemberReference):
                tokens.append(f"MEMBER_{node.member}")

            # ✅ Thêm thông tin Annotation (nếu có)
            elif isinstance(node, javalang.tree.Annotation):
                tokens.append(f"ANNOTATION_{node.name}")

            # ✅ Lấy các từ khóa điều kiện & vòng lặp
            elif isinstance(node, javalang.tree.IfStatement):
                tokens.append("<IF>")
            elif isinstance(node, javalang.tree.ForStatement):
                tokens.append("<FOR>")
            elif isinstance(node, javalang.tree.WhileStatement):
                tokens.append("<WHILE>")
            elif isinstance(node, javalang.tree.DoStatement):
                tokens.append("<DO>")
            elif isinstance(node, javalang.tree.SwitchStatement):
                tokens.append("<SWITCH>")
            elif hasattr(javalang.tree, "CaseStatement") and isinstance(node, javalang.tree.CaseStatement):
                tokens.append("<CASE>")  # ✅ Chỉ thêm nếu `CaseStatement` tồn tại
            elif isinstance(node, javalang.tree.TryStatement):
                tokens.append("<TRY>")
            elif isinstance(node, javalang.tree.ThrowStatement):
                tokens.append("<THROW>")
            elif isinstance(node, javalang.tree.CatchClause):
                tokens.append("<CATCH>")
            elif isinstance(node, javalang.tree.ReturnStatement):
                tokens.append("<RETURN>")

            # ✅ Lấy thông tin kiểu dữ liệu biến
            elif isinstance(node, javalang.tree.LocalVariableDeclaration):
                for var in node.declarators:
                    tokens.append(f"VAR_{var.name}_TYPE_{node.type.name}")

            # ✅ Lấy kiểu dữ liệu tham số của hàm
            elif isinstance(node, javalang.tree.MethodDeclaration):
                for param in node.parameters:
                    tokens.append(f"PARAM_{param.name}_TYPE_{param.type.name}")

            # ✅ Lấy tên các import để hiểu bối cảnh code
            elif isinstance(node, javalang.tree.Import):
                tokens.append(f"IMPORT_{node.path}")

        return tokens
    except Exception as e:
        print(f"Lỗi khi xử lý file {file_path}: {e}")
        return []

# %%
sample_file = filtered_train_files[9]  # Lấy một file từ danh sách đã lọc
sample_tokens = extract_tokens_from_file(sample_file)
print("📌 Token từ file mẫu:", sample_tokens)
# Out:
# 📌 Token từ file mẫu: ['IMPORT_java.util.Hashtable', 'IMPORT_java.util.Vector', 'IMPORT_java.util.zip.ZipException', 'CLASS_ExtraFieldUtils', 'VAR_implementations', 'MEMBER_implementations', 'METHOD_register', '<TRY>', 'VAR_ze_TYPE_ZipExtraField', 'VAR_ze', 'MEMBER_c', '<CATCH>', '<THROW>', 'MEMBER_c', '<CATCH>', '<THROW>', 'MEMBER_c', '<CATCH>', '<THROW>', 'MEMBER_c', 'METHOD_createExtraField', 'VAR_c_TYPE_Class', 'VAR_c', 'MEMBER_headerId', '<IF>', 'MEMBER_c', '<RETURN>', 'VAR_u_TYPE_UnrecognizedExtraField', 'VAR_u', 'MEMBER_headerId', '<RETURN>', 'MEMBER_u', 'METHOD_parse', 'VAR_v_TYPE_Vector', 'VAR_v', 'VAR_start_TYPE_int', 'VAR_start', '<WHILE>', 'MEMBER_start', 'MEMBER_length', 'VAR_headerId_TYPE_ZipShort', 'VAR_headerId', 'MEMBER_data', 'MEMBER_start', 'VAR_length_TYPE_int', 'VAR_length', 'MEMBER_data', 'MEMBER_start', '<IF>', 'MEMBER_start', 'MEMBER_length', 'MEMBER_length', '<THROW>', 'MEMBER_start', '<TRY>', 'VAR_ze_TYPE_ZipExtraField', 'VAR_ze', 'MEMBER_headerId', 'MEMBER_data', 'MEMBER_start', 'MEMBER_length', 'MEMBER_ze', '<CATCH>', '<THROW>', '<CATCH>', '<THROW>', 'MEMBER_start', 'MEMBER_length', '<IF>', 'MEMBER_start', 'MEMBER_length', '<THROW>', 'MEMBER_start', 'VAR_result_TYPE_ZipExtraField', 'VAR_result', 'MEMBER_result', '<RETURN>', 'MEMBER_result', 'METHOD_mergeLocalFileDataData', 'VAR_sum_TYPE_int', 'VAR_sum', 'MEMBER_length', '<FOR>', 'VAR_i', 'MEMBER_i', 'MEMBER_length', 'MEMBER_i', 'MEMBER_sum', 'MEMBER_data', 'MEMBER_i', 'VAR_result_TYPE_byte', 'VAR_result', 'MEMBER_sum', 'VAR_start_TYPE_int', 'VAR_start', '<FOR>', 'VAR_i', 'MEMBER_i', 'MEMBER_length', 'MEMBER_i', 'MEMBER_data', 'MEMBER_i', 'MEMBER_result', 'MEMBER_start', 'MEMBER_data', 'MEMBER_i', 'MEMBER_result', 'MEMBER_start', 'VAR_local_TYPE_byte', 'VAR_local', 'MEMBER_data', 'MEMBER_i', 'MEMBER_local', 'MEMBER_result', 'MEMBER_start', 'MEMBER_length', 'MEMBER_start', 'MEMBER_length', '<RETURN>', 'MEMBER_result', 'METHOD_mergeCentralDirectoryData', 'VAR_sum_TYPE_int', 'VAR_sum', 'MEMBER_length', '<FOR>', 'VAR_i', 'MEMBER_i', 'MEMBER_length', 'MEMBER_i', 'MEMBER_sum', 'MEMBER_data', 'MEMBER_i', 'VAR_result_TYPE_byte', 'VAR_result', 'MEMBER_sum', 'VAR_start_TYPE_int', 'VAR_start', '<FOR>', 'VAR_i', 'MEMBER_i', 'MEMBER_length', 'MEMBER_i', 'MEMBER_data', 'MEMBER_i', 'MEMBER_result', 'MEMBER_start', 'MEMBER_data', 'MEMBER_i', 'MEMBER_result', 'MEMBER_start', 'VAR_local_TYPE_byte', 'VAR_local', 'MEMBER_data', 'MEMBER_i', 'MEMBER_local', 'MEMBER_result', 'MEMBER_start', 'MEMBER_length', 'MEMBER_start', 'MEMBER_length', '<RETURN>', 'MEMBER_result']

# %%
# Trích xuất token từ tất cả các file trong tập train và test
train_tokens = {file: extract_tokens_from_file(file) for file in train_files_new}
test_tokens = {file: extract_tokens_from_file(file) for file in filtered_test_files}
val_tokens = {file: extract_tokens_from_file(file) for file in val_files_new}
# Kiểm tra kết quả
print(f"Số file đã trích xuất token (train): {len(train_tokens)}")
print(f"Số file đã trích xuất token (validation): {len(val_tokens)}")
print(f"Số file đã trích xuất token (test): {len(test_tokens)}")

# Xem một file mẫu
sample_file = filtered_train_files[0]
print("📌 Token từ file:", sample_file)
print(train_tokens[sample_file])
# Out:
# Số file đã trích xuất token (train): 354
# Số file đã trích xuất token (validation): 88
# Số file đã trích xuất token (test): 907
# 📌 Token từ file: apache-ant-1.6.0/src/main/org/apache/tools/bzip2/CRC.java
# ['CLASS_CRC', 'VAR_crc32Table', 'METHOD_CRC', 'METHOD_initialiseCRC', 'MEMBER_globalCrc', 'METHOD_getFinalCRC', '<RETURN>', 'MEMBER_globalCrc', 'METHOD_getGlobalCRC', '<RETURN>', 'MEMBER_globalCrc', 'METHOD_setGlobalCRC', 'MEMBER_globalCrc', 'MEMBER_newCrc', 'METHOD_updateCRC', 'VAR_temp_TYPE_int', 'VAR_temp', 'MEMBER_globalCrc', 'MEMBER_inCh', '<IF>', 'MEMBER_temp', 'MEMBER_temp', 'MEMBER_temp', 'MEMBER_globalCrc', 'MEMBER_globalCrc', 'MEMBER_crc32Table', 'MEMBER_temp', 'VAR_globalCrc']

# %%
from google.colab import drive
import pickle
import os

# 🔹 1. Mount Google Drive
drive.mount('/content/drive')

# 🔹 2. Định nghĩa đường dẫn lưu file
save_dir = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/"
save_path = os.path.join(save_dir, "dp_cnn_tokens.pkl")

# 🔹 3. Tạo thư mục nếu chưa tồn tại
os.makedirs(save_dir, exist_ok=True)

# 🔹 4. Lưu file vào thư mục trong Google Drive
data = {
    "train_tokens": train_tokens,
    "test_tokens": test_tokens,
    "val_tokens": val_tokens
}

with open(save_path, "wb") as f:
    pickle.dump(data, f)

print(f"✅ File đã được lưu tại: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ File đã được lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/dp_cnn_tokens.pkl

# %% [markdown]
# # 3. Word embedding

# %% [markdown]
# - Làm bên folder khác: https://drive.google.com/file/d/13aXuvPECb4fUPLQEEVwSRNUCZQBukSur/view?usp=sharing
# - Token sau khi embedding được lưu vào trong file dp_cnn_embeddings.pkl có link: "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/dp_cnn_embeddings.pkl"

# %%
import pickle
import numpy as np
from google.colab import drive
import os

drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/dp_cnn_embeddings.pkl'


# Mở và đọc dữ liệu từ file .pkl
with open(file_path, 'rb') as f:
    data = pickle.load(f)

X_train = data['X_train_embeddings']
X_test = data['X_test_embeddings']
X_val = data['X_val_embeddings']

print(f"📌 Dữ liệu train shape: {X_train.shape}")
print(f"📌 Dữ liệu validation shape: {X_val.shape}")
print(f"📌 Dữ liệu test shape: {X_test.shape}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 📌 Dữ liệu train shape: (354, 100, 30)
# 📌 Dữ liệu validation shape: (88, 100, 30)
# 📌 Dữ liệu test shape: (907, 100, 30)

# %% [markdown]
# Kiểm tra lại nhãn

# %%
import numpy as np

# Chuyển nhãn thành NumPy array
y_train = np.array(balanced_train_df['bug'].values)  # 0 hoặc 1
y_val = np.array(balanced_val_df['bug'].values)  # 0 hoặc 1
y_test = np.array(balanced_test_df['bug'].values)  # 0 hoặc 1

print(f"📌 Nhãn train shape: {y_train.shape}")
print(f"📌 Nhãn val shape: {y_val.shape}")
print(f"📌 Nhãn test shape: {y_test.shape}")
# Out:
# 📌 Nhãn train shape: (354,)
# 📌 Nhãn val shape: (88,)
# 📌 Nhãn test shape: (907,)

# %% [markdown]
# # 4. Huấn luyện mạng CNN

# %% [markdown]
# - Huấn luyện CNN để trích xuất đặc trưng từ mã nguồn thông qua các vector word embedding (dạng chuỗi token).
# - Lấy các đặc trưng truyền thống từ file CSV
# - Ghép nối đặc trưng CNN và đặc trưng truyền thống để tổng hợp thông tin.
# - Dự đoán lỗi phần mềm bằng lớp Logistic Regression (lớp Dense cuối cùng với sigmoid).

# %% [markdown]
# ##Trích xuất các cột số từ CSV làm đầu vào bổ sung

# %%
X_train_traditional = np.array(balanced_train_df.iloc[:, 1:-1].values)  # Bỏ cột đầu tiên (name) và cuối cùng (bug)
X_test_traditional = np.array(balanced_test_df.iloc[:, 1:-1].values)
X_val_traditional = np.array(balanced_val_df.iloc[:, 1:-1].values)

print(f"📌 Traditional Features - Train shape: {X_train_traditional.shape}")
print(f"📌 Traditional Features - Validation shape: {X_val_traditional.shape}")
print(f"📌 Traditional Features - Test shape: {X_test_traditional.shape}")

print(X_train_traditional[1])
# Out:
# 📌 Traditional Features - Train shape: (354, 20)
# 📌 Traditional Features - Validation shape: (88, 20)
# 📌 Traditional Features - Test shape: (907, 20)
# [  3.           4.           0.           4.          21.
#    3.           0.           4.           1.           1.5
#  144.           1.           0.           0.96078431   1.
#    2.           3.          46.66666667   9.           3.3333    ]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_traditional = scaler.fit_transform(X_train_traditional)
X_val_traditional = scaler.transform(X_val_traditional)
X_test_traditional = scaler.transform(X_test_traditional)

# %%
## Định nghĩa cấu trúc mạng nơ ron và huấn luyện

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, Dense, Dropout, Input, Concatenate, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Định nghĩa siêu tham số tối ưu
FILTERS = 250
KERNEL_SIZE = 5
DENSE_UNITS = 100
DROPOUT_RATE = 0.1
LEARNING_RATE = 0.001
NUM_TRADITIONAL_FEATURES = X_train_traditional.shape[1]  # Số đặc trưng truyền thống
MAX_SEQUENCE_LENGTH = 100
EMBEDDING_DIM = 30

# Input từ CNN
input_layer_cnn = Input(shape=(MAX_SEQUENCE_LENGTH, EMBEDDING_DIM))  # (None, 100, 30)

# Các lớp Conv1D và MaxPooling
conv_layer_1 = Conv1D(filters=FILTERS, kernel_size=KERNEL_SIZE, activation='relu')(input_layer_cnn)
batch_norm_1 = BatchNormalization()(conv_layer_1)  # Batch Normalization
conv_layer_2 = Conv1D(filters=FILTERS, kernel_size=KERNEL_SIZE, activation='relu')(batch_norm_1)
batch_norm_2 = BatchNormalization()(conv_layer_2)  # Batch Normalization
pool_layer = GlobalMaxPooling1D()(batch_norm_2)

# Thêm lớp Dense và Dropout
dense_layer = Dense(DENSE_UNITS, activation='relu')(pool_layer)
dropout_layer = Dropout(DROPOUT_RATE)(dense_layer)

# Lấy Traditional Features và concatenate với đầu ra của mạng CNN
input_layer_traditional = Input(shape=(NUM_TRADITIONAL_FEATURES,))
merged_features = Concatenate()([dropout_layer, input_layer_traditional])

# Đưa qua lớp dense
dense_2_layer = Dense(DENSE_UNITS, activation='relu', kernel_regularizer=l2(0.01))(merged_features)

# Lớp Logistic Regression (Dự đoán lỗi phần mềm)
output_layer = Dense(1, activation='sigmoid')(dense_2_layer)

# Tạo mô hình tổng hợp
model = Model(inputs=[input_layer_cnn, input_layer_traditional], outputs=output_layer)

# Compile mô hình với learning rate thấp hơn
optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Sử dụng ReduceLROnPlateau callback để điều chỉnh learning rate khi cần thiết
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=0.00001)

# Hiển thị kiến trúc mô hình
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8             │ (None, 100, 30)        │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_8 (Conv1D)         │ (None, 96, 250)        │         37,750 │ input_layer_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 96, 250)        │          1,000 │ conv1d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_9 (Conv1D)         │ (None, 92, 250)        │        312,750 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 92, 250)        │          1,000 │ conv1d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling1d_4    │ (None, 250)            │              0 │ batch_normalization_9… │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 100)            │         25,100 │ global_max_pooling1d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 100)            │              0 │ dense_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_9             │ (None, 20)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 120)            │              0 │ dropout_4[0][0],       │
# │ (Concatenate)             │                        │                │ input_layer_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 100)            │         12,100 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 1)              │            101 │ dense_13[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 389,801 (1.49 MB)
#  Trainable params: 388,801 (1.48 MB)
#  Non-trainable params: 1,000 (3.91 KB)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report

# 🔹 Số epochs để huấn luyện
epochs = 50
history_dict = {}

# 🔹 Tạo callback để in kết quả sau mỗi epoch
class MetricsCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        # Dự đoán trên tập test ngay sau epoch hiện tại
        y_pred = (self.model.predict([X_test, X_test_traditional]) > 0.5).astype("int32")

        # Tính Classification Report đúng cách
        report = classification_report(y_test, y_pred, output_dict=True)

        # Lưu lịch sử từng epoch
        history_dict[epoch + 1] = {
            "accuracy": logs["accuracy"],
            "val_accuracy": logs["val_accuracy"],
            "loss": logs["loss"],
            "val_loss": logs["val_loss"],
            "precision": report["1"]["precision"] if "1" in report else 0,
            "recall": report["1"]["recall"] if "1" in report else 0,
            "f1-score": report["1"]["f1-score"] if "1" in report else 0
        }

        # 🔥 In kết quả sau mỗi epoch
        print(f"\n📌 Epoch {epoch + 1}/{epochs} - "
              f"Accuracy: {logs['accuracy']:.4f}, "
              f"Loss: {logs['loss']:.4f}, "
              f"Val Accuracy: {logs['val_accuracy']:.4f}, "
              f"Val Loss: {logs['val_loss']:.4f}, "
              f"Precision: {history_dict[epoch + 1]['precision']:.4f}, "
              f"Recall: {history_dict[epoch + 1]['recall']:.4f}, "
              f"F1-score: {history_dict[epoch + 1]['f1-score']:.4f}")

# 🔹 Huấn luyện mô hình với callback tùy chỉnh
history = model.fit(
    [X_train, X_train_traditional], y_train,
    validation_data=([X_val, X_val_traditional], y_val),
    epochs=epochs, batch_size=16, verbose=0,
    callbacks=[MetricsCallback()]
)

# 🔹 In toàn bộ lịch sử sau khi huấn luyện xong
print("\n📊 History Dict:")
print(history_dict)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
#
# 📌 Epoch 1/50 - Accuracy: 0.6271, Loss: 1.7598, Val Accuracy: 0.6136, Val Loss: 1.5423, Precision: 0.5043, Recall: 0.8735, F1-score: 0.6395
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 2/50 - Accuracy: 0.7147, Loss: 1.4171, Val Accuracy: 0.7500, Val Loss: 1.3284, Precision: 0.6295, Recall: 0.7319, F1-score: 0.6769
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 3/50 - Accuracy: 0.7740, Loss: 1.2015, Val Accuracy: 0.6364, Val Loss: 1.2746, Precision: 0.5691, Recall: 0.8313, F1-score: 0.6756
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 4/50 - Accuracy: 0.7740, Loss: 1.0690, Val Accuracy: 0.7727, Val Loss: 1.1343, Precision: 0.6621, Recall: 0.7259, F1-score: 0.6925
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
#
# 📌 Epoch 5/50 - Accuracy: 0.8107, Loss: 0.9582, Val Accuracy: 0.6932, Val Loss: 1.0909, Precision: 0.6018, Recall: 0.8012, F1-score: 0.6873
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 6/50 - Accuracy: 0.8107, Loss: 0.8821, Val Accuracy: 0.7386, Val Loss: 1.0167, Precision: 0.6630, Recall: 0.7289, F1-score: 0.6944
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 7/50 - Accuracy: 0.8192, Loss: 0.8168, Val Accuracy: 0.7500, Val Loss: 0.9712, Precision: 0.6742, Recall: 0.7169, F1-score: 0.6949
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 8/50 - Accuracy: 0.8531, Loss: 0.7569, Val Accuracy: 0.7386, Val Loss: 0.9297, Precision: 0.6603, Recall: 0.7319, F1-score: 0.6943
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
#
# 📌 Epoch 9/50 - Accuracy: 0.8701, Loss: 0.6912, Val Accuracy: 0.7159, Val Loss: 0.9146, Precision: 0.6272, Recall: 0.7651, F1-score: 0.6893
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 10/50 - Accuracy: 0.8644, Loss: 0.6636, Val Accuracy: 0.7386, Val Loss: 0.9453, Precision: 0.5729, Recall: 0.8163, F1-score: 0.6733
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 11/50 - Accuracy: 0.8333, Loss: 0.6732, Val Accuracy: 0.7386, Val Loss: 0.8680, Precision: 0.7490, Recall: 0.5753, F1-score: 0.6508
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 12/50 - Accuracy: 0.8672, Loss: 0.6267, Val Accuracy: 0.7500, Val Loss: 0.8695, Precision: 0.7417, Recall: 0.5361, F1-score: 0.6224
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step
#
# 📌 Epoch 13/50 - Accuracy: 0.8503, Loss: 0.6693, Val Accuracy: 0.7386, Val Loss: 0.8505, Precision: 0.7441, Recall: 0.5693, F1-score: 0.6451
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 14/50 - Accuracy: 0.8785, Loss: 0.5570, Val Accuracy: 0.7273, Val Loss: 0.8548, Precision: 0.7440, Recall: 0.5602, F1-score: 0.6392
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 15/50 - Accuracy: 0.9011, Loss: 0.5298, Val Accuracy: 0.7500, Val Loss: 0.8288, Precision: 0.6420, Recall: 0.7831, F1-score: 0.7056
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
#
# 📌 Epoch 16/50 - Accuracy: 0.8927, Loss: 0.5314, Val Accuracy: 0.7386, Val Loss: 0.8575, Precision: 0.7469, Recall: 0.5422, F1-score: 0.6283
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
#
# 📌 Epoch 17/50 - Accuracy: 0.8955, Loss: 0.5022, Val Accuracy: 0.7386, Val Loss: 0.7789, Precision: 0.6791, Recall: 0.7139, F1-score: 0.6960
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 18/50 - Accuracy: 0.9040, Loss: 0.4809, Val Accuracy: 0.6932, Val Loss: 0.9869, Precision: 0.8424, Recall: 0.4187, F1-score: 0.5594
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 19/50 - Accuracy: 0.9040, Loss: 0.4737, Val Accuracy: 0.7500, Val Loss: 0.7516, Precision: 0.7094, Recall: 0.6837, F1-score: 0.6963
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step
#
# 📌 Epoch 20/50 - Accuracy: 0.9124, Loss: 0.4182, Val Accuracy: 0.7159, Val Loss: 0.8544, Precision: 0.7440, Recall: 0.5602, F1-score: 0.6392
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 21/50 - Accuracy: 0.8701, Loss: 0.4790, Val Accuracy: 0.7159, Val Loss: 0.7764, Precision: 0.7138, Recall: 0.6837, F1-score: 0.6985
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 22/50 - Accuracy: 0.9068, Loss: 0.4393, Val Accuracy: 0.7500, Val Loss: 0.8431, Precision: 0.7650, Recall: 0.5392, F1-score: 0.6325
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 23/50 - Accuracy: 0.9266, Loss: 0.3749, Val Accuracy: 0.7500, Val Loss: 0.7923, Precision: 0.7111, Recall: 0.6747, F1-score: 0.6924
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step
#
# 📌 Epoch 24/50 - Accuracy: 0.9209, Loss: 0.3999, Val Accuracy: 0.7500, Val Loss: 0.8654, Precision: 0.7683, Recall: 0.5693, F1-score: 0.6540
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
#
# 📌 Epoch 25/50 - Accuracy: 0.9379, Loss: 0.3437, Val Accuracy: 0.7273, Val Loss: 0.8366, Precision: 0.6883, Recall: 0.6717, F1-score: 0.6799
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
#
# 📌 Epoch 26/50 - Accuracy: 0.8757, Loss: 0.4520, Val Accuracy: 0.7727, Val Loss: 0.8047, Precision: 0.5630, Recall: 0.8343, F1-score: 0.6723
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 27/50 - Accuracy: 0.9237, Loss: 0.3713, Val Accuracy: 0.7614, Val Loss: 0.7609, Precision: 0.6875, Recall: 0.6627, F1-score: 0.6748
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 28/50 - Accuracy: 0.8701, Loss: 0.4308, Val Accuracy: 0.7727, Val Loss: 0.7471, Precision: 0.6904, Recall: 0.6717, F1-score: 0.6809
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
#
# 📌 Epoch 29/50 - Accuracy: 0.9153, Loss: 0.3792, Val Accuracy: 0.7386, Val Loss: 0.7548, Precision: 0.7224, Recall: 0.6506, F1-score: 0.6846
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 30/50 - Accuracy: 0.8785, Loss: 0.4140, Val Accuracy: 0.7386, Val Loss: 0.7788, Precision: 0.7571, Recall: 0.6386, F1-score: 0.6928
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
#
# 📌 Epoch 31/50 - Accuracy: 0.9407, Loss: 0.3306, Val Accuracy: 0.7500, Val Loss: 0.8264, Precision: 0.7491, Recall: 0.6386, F1-score: 0.6894
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 32/50 - Accuracy: 0.9548, Loss: 0.2843, Val Accuracy: 0.7614, Val Loss: 0.8590, Precision: 0.5923, Recall: 0.7922, F1-score: 0.6778
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 33/50 - Accuracy: 0.9463, Loss: 0.2976, Val Accuracy: 0.7614, Val Loss: 1.0328, Precision: 0.7919, Recall: 0.5271, F1-score: 0.6329
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
#
# 📌 Epoch 34/50 - Accuracy: 0.9294, Loss: 0.2958, Val Accuracy: 0.6705, Val Loss: 1.1716, Precision: 0.8263, Recall: 0.4157, F1-score: 0.5531
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 35/50 - Accuracy: 0.9181, Loss: 0.3466, Val Accuracy: 0.7500, Val Loss: 0.8214, Precision: 0.7276, Recall: 0.6114, F1-score: 0.6645
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 36/50 - Accuracy: 0.9011, Loss: 0.3414, Val Accuracy: 0.7841, Val Loss: 0.6895, Precision: 0.7055, Recall: 0.6205, F1-score: 0.6603
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step
#
# 📌 Epoch 37/50 - Accuracy: 0.9407, Loss: 0.2967, Val Accuracy: 0.7159, Val Loss: 0.9680, Precision: 0.7778, Recall: 0.5060, F1-score: 0.6131
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 38/50 - Accuracy: 0.9124, Loss: 0.3296, Val Accuracy: 0.7500, Val Loss: 0.8457, Precision: 0.7559, Recall: 0.5783, F1-score: 0.6553
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 39/50 - Accuracy: 0.9407, Loss: 0.2657, Val Accuracy: 0.7273, Val Loss: 0.9212, Precision: 0.7915, Recall: 0.5030, F1-score: 0.6151
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# 📌 Epoch 40/50 - Accuracy: 0.9548, Loss: 0.2426, Val Accuracy: 0.7500, Val Loss: 1.0331, Precision: 0.7511, Recall: 0.5361, F1-score: 0.6257
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
#
# 📌 Epoch 41/50 - Accuracy: 0.8249, Loss: 0.4584, Val Accuracy: 0.8182, Val Loss: 0.6631, Precision: 0.6941, Recall: 0.6355, F1-score: 0.6635
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 42/50 - Accuracy: 0.9237, Loss: 0.3158, Val Accuracy: 0.7386, Val Loss: 0.7886, Precision: 0.6997, Recall: 0.6596, F1-score: 0.6791
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 43/50 - Accuracy: 0.9435, Loss: 0.2673, Val Accuracy: 0.7614, Val Loss: 0.8209, Precision: 0.7662, Recall: 0.5331, F1-score: 0.6288
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 44/50 - Accuracy: 0.9322, Loss: 0.2587, Val Accuracy: 0.7386, Val Loss: 0.8587, Precision: 0.7564, Recall: 0.5331, F1-score: 0.6254
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 45/50 - Accuracy: 0.9605, Loss: 0.2143, Val Accuracy: 0.7386, Val Loss: 0.8580, Precision: 0.7424, Recall: 0.5904, F1-score: 0.6577
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
#
# 📌 Epoch 46/50 - Accuracy: 0.9407, Loss: 0.2293, Val Accuracy: 0.7614, Val Loss: 0.9224, Precision: 0.7706, Recall: 0.5060, F1-score: 0.6109
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 47/50 - Accuracy: 0.9576, Loss: 0.2080, Val Accuracy: 0.7386, Val Loss: 0.9336, Precision: 0.7063, Recall: 0.6084, F1-score: 0.6537
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 48/50 - Accuracy: 0.9548, Loss: 0.2104, Val Accuracy: 0.7955, Val Loss: 0.7728, Precision: 0.6981, Recall: 0.6687, F1-score: 0.6831
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
#
# 📌 Epoch 49/50 - Accuracy: 0.9548, Loss: 0.2139, Val Accuracy: 0.7386, Val Loss: 0.8475, Precision: 0.7118, Recall: 0.6175, F1-score: 0.6613
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# 📌 Epoch 50/50 - Accuracy: 0.9576, Loss: 0.2030, Val Accuracy: 0.7614, Val Loss: 0.8634, Precision: 0.7043, Recall: 0.6386, F1-score: 0.6698
#
# 📊 History Dict:
# {1: {'accuracy': 0.6271186470985413, 'val_accuracy': 0.6136363744735718, 'loss': 1.7598437070846558, 'val_loss': 1.5422511100769043, 'precision': 0.5043478260869565, 'recall': 0.8734939759036144, 'f1-score': 0.639470782800441}, 2: {'accuracy': 0.7146892547607422, 'val_accuracy': 0.75, 'loss': 1.4171079397201538, 'val_loss': 1.3284021615982056, 'precision': 0.6295336787564767, 'recall': 0.7319277108433735, 'f1-score': 0.6768802228412256}, 3: {'accuracy': 0.7740113139152527, 'val_accuracy': 0.6363636255264282, 'loss': 1.201481819152832, 'val_loss': 1.2746413946151733, 'precision': 0.5690721649484536, 'recall': 0.8313253012048193, 'f1-score': 0.6756425948592412}, 4: {'accuracy': 0.7740113139152527, 'val_accuracy': 0.7727272510528564, 'loss': 1.0689904689788818, 'val_loss': 1.1342575550079346, 'precision': 0.6620879120879121, 'recall': 0.7259036144578314, 'f1-score': 0.6925287356321839}, 5: {'accuracy': 0.8107344508171082, 'val_accuracy': 0.6931818127632141, 'loss': 0.9582367539405823, 'val_loss': 1.0909382104873657, 'precision': 0.6018099547511312, 'recall': 0.8012048192771084, 'f1-score': 0.6873385012919897}, 6: {'accuracy': 0.8107344508171082, 'val_accuracy': 0.7386363744735718, 'loss': 0.882094144821167, 'val_loss': 1.0166749954223633, 'precision': 0.663013698630137, 'recall': 0.7289156626506024, 'f1-score': 0.6944045911047346}, 7: {'accuracy': 0.8192090392112732, 'val_accuracy': 0.75, 'loss': 0.8167572021484375, 'val_loss': 0.9711858630180359, 'precision': 0.6742209631728046, 'recall': 0.7168674698795181, 'f1-score': 0.6948905109489051}, 8: {'accuracy': 0.8531073331832886, 'val_accuracy': 0.7386363744735718, 'loss': 0.7569208741188049, 'val_loss': 0.9296854138374329, 'precision': 0.6603260869565217, 'recall': 0.7319277108433735, 'f1-score': 0.6942857142857143}, 9: {'accuracy': 0.8700565099716187, 'val_accuracy': 0.7159090638160706, 'loss': 0.6912059783935547, 'val_loss': 0.9145982265472412, 'precision': 0.6271604938271605, 'recall': 0.7650602409638554, 'f1-score': 0.689280868385346}, 10: {'accuracy': 0.8644067645072937, 'val_accuracy': 0.7386363744735718, 'loss': 0.6636291742324829, 'val_loss': 0.9452708959579468, 'precision': 0.572938689217759, 'recall': 0.8162650602409639, 'f1-score': 0.6732919254658385}, 11: {'accuracy': 0.8333333134651184, 'val_accuracy': 0.7386363744735718, 'loss': 0.6731531620025635, 'val_loss': 0.8680433630943298, 'precision': 0.7490196078431373, 'recall': 0.5753012048192772, 'f1-score': 0.6507666098807495}, 12: {'accuracy': 0.8672316670417786, 'val_accuracy': 0.75, 'loss': 0.6267492771148682, 'val_loss': 0.8694549798965454, 'precision': 0.7416666666666667, 'recall': 0.536144578313253, 'f1-score': 0.6223776223776224}, 13: {'accuracy': 0.8502824902534485, 'val_accuracy': 0.7386363744735718, 'loss': 0.6693425178527832, 'val_loss': 0.8505138754844666, 'precision': 0.7440944881889764, 'recall': 0.5692771084337349, 'f1-score': 0.6450511945392492}, 14: {'accuracy': 0.8785310983657837, 'val_accuracy': 0.7272727489471436, 'loss': 0.5570247173309326, 'val_loss': 0.8548362255096436, 'precision': 0.744, 'recall': 0.5602409638554217, 'f1-score': 0.6391752577319587}, 15: {'accuracy': 0.901129961013794, 'val_accuracy': 0.75, 'loss': 0.5298212170600891, 'val_loss': 0.8287702202796936, 'precision': 0.6419753086419753, 'recall': 0.7831325301204819, 'f1-score': 0.7055630936227951}, 16: {'accuracy': 0.8926553726196289, 'val_accuracy': 0.7386363744735718, 'loss': 0.5313685536384583, 'val_loss': 0.8574773669242859, 'precision': 0.7468879668049793, 'recall': 0.5421686746987951, 'f1-score': 0.6282722513089005}, 17: {'accuracy': 0.895480215549469, 'val_accuracy': 0.7386363744735718, 'loss': 0.5021547079086304, 'val_loss': 0.7788696885108948, 'precision': 0.6790830945558739, 'recall': 0.713855421686747, 'f1-score': 0.6960352422907489}, 18: {'accuracy': 0.903954803943634, 'val_accuracy': 0.6931818127632141, 'loss': 0.4808979332447052, 'val_loss': 0.986894965171814, 'precision': 0.8424242424242424, 'recall': 0.4186746987951807,  ...

# %%
y_pred_prob = model.predict([X_test, X_test_traditional])
print(y_pred_prob[:30])  # In 10 giá trị dự đoán ban đầu để kiểm tra
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# [[4.47535396e-01]
#  [4.22003359e-04]
#  [2.33637495e-03]
#  [8.79514124e-03]
#  [2.30921502e-03]
#  [2.02339783e-04]
#  [3.95052619e-02]
#  [1.33987173e-01]
#  [1.18977083e-02]
#  [5.87612055e-02]
#  [9.24624875e-03]
#  [2.60802984e-01]
#  [4.64778859e-03]
#  [9.75051597e-02]
#  [3.49695273e-02]
#  [8.60595226e-01]
#  [1.00821845e-01]
#  [4.21297125e-04]
#  [4.13611357e-04]
#  [3.45850140e-01]
#  [3.61304381e-04]
#  [7.57820904e-03]
#  [9.40192025e-03]
#  [7.89124548e-01]
#  [7.90842436e-03]
#  [1.76042169e-02]
#  [3.13983679e-01]
#  [1.89266115e-01]
#  [2.45448355e-05]
#  [3.58410507e-01]]

# %%
import matplotlib.pyplot as plt

# Kiểm tra và trích xuất dữ liệu từ history_dict
epochs_values = list(history_dict.keys())

train_acc = [history_dict[ep].get("accuracy", None) for ep in epochs_values]
val_acc = [history_dict[ep].get("val_accuracy", None) for ep in epochs_values]
train_loss = [history_dict[ep].get("loss", None) for ep in epochs_values]
val_loss = [history_dict[ep].get("val_loss", None) for ep in epochs_values]
precision = [history_dict[ep].get("precision", None) for ep in epochs_values]
recall = [history_dict[ep].get("recall", None) for ep in epochs_values]
f1_score = [history_dict[ep].get("f1-score", None) for ep in epochs_values]

# Tạo biểu đồ
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 🔹 1. Vẽ biểu đồ Accuracy
axes[0, 0].plot(epochs_values, train_acc, marker='o', label="Train Accuracy", color='b')
axes[0, 0].plot(epochs_values, val_acc, marker='s', label="Validation Accuracy", color='g')
axes[0, 0].set_xlabel("Epochs")
axes[0, 0].set_ylabel("Accuracy")
axes[0, 0].set_title("Train & Validation Accuracy vs. Epochs")
axes[0, 0].legend()
axes[0, 0].grid()

# 🔹 2. Vẽ biểu đồ Loss
axes[0, 1].plot(epochs_values, train_loss, marker='o', label="Train Loss", color='r')
axes[0, 1].plot(epochs_values, val_loss, marker='s', label="Validation Loss", color='purple')
axes[0, 1].set_xlabel("Epochs")
axes[0, 1].set_ylabel("Loss")
axes[0, 1].set_title("Train & Validation Loss vs. Epochs")
axes[0, 1].legend()
axes[0, 1].grid()

# 🔹 3. Vẽ biểu đồ Precision, Recall, F1-score
axes[1, 0].plot(epochs_values, precision, marker='o', label="Precision", color='orange')
axes[1, 0].plot(epochs_values, recall, marker='s', label="Recall", color='brown')
axes[1, 0].plot(epochs_values, f1_score, marker='^', label="F1-Score", color='cyan')
axes[1, 0].set_xlabel("Epochs")
axes[1, 0].set_ylabel("Score")
axes[1, 0].set_title("Precision, Recall & F1-Score vs. Epochs")
axes[1, 0].legend()
axes[1, 0].grid()

# Ẩn ô trống (nếu có)
axes[1, 1].axis("off")

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping

# 🔹 1. Thêm Early Stopping để tránh overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# 🔹 2. Huấn luyện mô hình với batch size nhỏ hơn để tăng khả năng generalization
model.fit(
    [X_train, X_train_traditional], y_train,
    validation_data=([X_val, X_val_traditional], y_val),
    epochs=epochs, batch_size=16, verbose=0,
    callbacks=[MetricsCallback()]
)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
#
# 📌 Epoch 1/50 - Accuracy: 0.9576, Loss: 0.1859, Val Accuracy: 0.7614, Val Loss: 0.8322, Precision: 0.7148, Recall: 0.5964, F1-score: 0.6502
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
#
# 📌 Epoch 2/50 - Accuracy: 0.9689, Loss: 0.1970, Val Accuracy: 0.7500, Val Loss: 0.8337, Precision: 0.7184, Recall: 0.5994, F1-score: 0.6535
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 3/50 - Accuracy: 0.9576, Loss: 0.1877, Val Accuracy: 0.7614, Val Loss: 0.8462, Precision: 0.7046, Recall: 0.6898, F1-score: 0.6971
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 4/50 - Accuracy: 0.9520, Loss: 0.1863, Val Accuracy: 0.7955, Val Loss: 0.9413, Precision: 0.6354, Recall: 0.7560, F1-score: 0.6905
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
#
# 📌 Epoch 5/50 - Accuracy: 0.9661, Loss: 0.1946, Val Accuracy: 0.7386, Val Loss: 0.8455, Precision: 0.7128, Recall: 0.6205, F1-score: 0.6634
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#
# 📌 Epoch 6/50 - Accuracy: 0.9746, Loss: 0.1680, Val Accuracy: 0.7500, Val Loss: 0.8187, Precision: 0.6686, Recall: 0.6928, F1-score: 0.6805

# %%
from sklearn.metrics import classification_report

# 🔹 1. Dự đoán trên tập test
y_pred = (model.predict([X_test, X_test_traditional]) > 0.5).astype("int32")

# 🔹 2. In báo cáo kết quả
print(classification_report(y_test, y_pred))

# %% [markdown]
# # Đánh giá mô hình

# %%
import matplotlib.pyplot as plt

# Trích xuất dữ liệu từ history_dict
epochs_values = list(history_dict.keys())
accuracy = [history_dict[ep]["accuracy"] for ep in epochs_values]
precision = [history_dict[ep]["precision"] for ep in epochs_values]
recall = [history_dict[ep]["recall"] for ep in epochs_values]
f1_score = [history_dict[ep]["f1-score"] for ep in epochs_values]

# 🔹 Vẽ biểu đồ
plt.figure(figsize=(12, 6))

plt.plot(epochs_values, accuracy, marker='o', linestyle='--', label="Accuracy")
plt.plot(epochs_values, precision, marker='s', label="Precision")
plt.plot(epochs_values, recall, marker='^', label="Recall")
plt.plot(epochs_values, f1_score, marker='d', label="F1-score")

plt.xlabel("Epochs")
plt.ylabel("Score")
plt.title("So sánh Accuracy, Precision, Recall, F1-score theo số Epochs")
plt.legend()
plt.grid()

plt.show()
