# %% [markdown]
# # Task: Software Defect Prediction via Convolutional Neural Network
# ## Mô tả bài toán
# Dựa vào paper IEEE 2017 - DP-CNN đề xuất 1 phuơng pháp mới, DP-CNN (Defect Prediction via Convolutional Neural Network) là một phương pháp dự đoán lỗi phần mềm bằng cách kết hợp học sâu với các đặc trưng truyền thống. Thay vì chỉ dựa vào các đặc trưng thủ công như độ phức tạp mã nguồn, DP-CNN tự động học đặc trưng ngữ nghĩa và cấu trúc từ cây Cú pháp Trừu tượng (AST) bằng CNN, sau đó kết hợp với các đặc trưng truyền thống để cải thiện độ chính xác.
# ## Phương pháp đề xuất
# 1️⃣ Phân tích mã nguồn thành cây AST, trích xuất token quan trọng.
#
# 2️⃣ Mã hóa token thành vector số bằng kỹ thuật word embedding.
#
# 3️⃣ Sử dụng CNN để học đặc trưng ngữ nghĩa và cấu trúc từ mã nguồn.
#
# 4️⃣ Kết hợp với đặc trưng truyền thống để tối ưu dự đoán.
#
# 5️⃣ Huấn luyện mô hình và phân loại file là "có lỗi" hoặc "không lỗi".

# %% [markdown]
# # 1. Phân tích dữ liệu

# %% [markdown]
# - Dự kiến: Lấy tập Synapse-1.1 để trainning và tập Synapse-1.2 để test1
# - Tải bộ source code của bộ Synapse-1.1 và Synapse-1.2 từ archive.apache.org.
# - Đọc dữ liệu csv chứa thông tin về các đặc trưng truyền thống về phần mềm và label cho biết code lỗi hay không
# - Lọc chỉ lấy những file source code có trong file csv đã phân tích

# %% [markdown]
# ## Tải bộ source code trên archive.appache.org

# %%
# !wget https://archive.apache.org/dist/synapse/1.1/synapse-1.1-src.tar.gz
# !tar -xvzf synapse-1.1-src.tar.gz

# !wget https://archive.apache.org/dist/synapse/1.2/synapse-1.2-src.tar.gz
# !tar -xvzf synapse-1.2-src.tar.gz
# Out:
# --2025-03-22 17:20:37--  https://archive.apache.org/dist/synapse/1.1/synapse-1.1-src.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3955793 (3.8M) [application/x-gzip]
# Saving to: ‘synapse-1.1-src.tar.gz.1’
#
# synapse-1.1-src.tar 100%[===================>]   3.77M  4.10MB/s    in 0.9s
#
# 2025-03-22 17:20:38 (4.10 MB/s) - ‘synapse-1.1-src.tar.gz.1’ saved [3955793/3955793]
#
# synapse-1.1-src/repository/conf/
# synapse-1.1-src/repository/conf/sample/
# synapse-1.1-src/repository/conf/sample/resources/
# synapse-1.1-src/repository/conf/sample/resources/policy/
# synapse-1.1-src/repository/conf/sample/resources/endpoint/
# synapse-1.1-src/repository/conf/sample/resources/proxy/
# synapse-1.1-src/repository/conf/sample/resources/spring/
# synapse-1.1-src/repository/conf/sample/resources/script/
# synapse-1.1-src/repository/conf/sample/resources/security/
# synapse-1.1-src/repository/conf/sample/resources/sequence/
# synapse-1.1-src/repository/conf/sample/resources/validate/
# synapse-1.1-src/repository/conf/sample/resources/misc/
# synapse-1.1-src/repository/conf/sample/resources/misc/server/
# synapse-1.1-src/repository/conf/sample/resources/misc/client/
# synapse-1.1-src/repository/conf/sample/resources/transform/
# synapse-1.1-src/repository/conf/sample/resources/mtom/
# synapse-1.1-src/repository/conf/sample/resources/xquery/
# synapse-1.1-src/repository/conf/sample/resources/vfs/
# synapse-1.1-src/src/main/
# synapse-1.1-src/src/main/assembly/
# synapse-1.1-src/src/main/release/
# synapse-1.1-src/src/main/release/docs/
# synapse-1.1-src/src/main/bin/
# synapse-1.1-src/src/main/bin/native/
# synapse-1.1-src/src/site/
# synapse-1.1-src/src/site/resources/
# synapse-1.1-src/src/site/resources/download/
# synapse-1.1-src/src/site/resources/download/0.90/
# synapse-1.1-src/src/site/resources/download/0.91/
# synapse-1.1-src/src/site/resources/download/M1/
# synapse-1.1-src/src/site/resources/download/1.0/
# synapse-1.1-src/src/site/resources/download/M2/
# synapse-1.1-src/src/site/resources/presentations/
# synapse-1.1-src/src/site/xdoc/
# synapse-1.1-src/modules/extensions/
# synapse-1.1-src/modules/extensions/src/
# synapse-1.1-src/modules/extensions/src/test/
# synapse-1.1-src/modules/extensions/src/test/java/
# synapse-1.1-src/modules/extensions/src/test/java/org/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/spring/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/throttle/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/validate/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/bsf/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/bsf/javascript/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/transform/
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/xquery/
# synapse-1.1-src/modules/extensions/src/test/resources/
# synapse-1.1-src/modules/extensions/src/main/
# synapse-1.1-src/modules/extensions/src/main/java/
# synapse-1.1-src/modules/extensions/src/main/java/org/
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/spring/
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/throttle/
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/attachment/
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/bsf/
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/xquery/
# synapse-1.1-src/modules/extensions/src/main/resources/
# synapse-1.1-src/modules/extensions/src/main/resources/META-INF/
# synapse-1.1-src/modules/extensions/src/main/resources/META-INF/services/
# synapse-1.1-src/modules/extensions/logs/
# synapse-1.1-src/modules/mar/
# synapse-1.1-src/modules/transports/
# synapse-1.1-src/modules/transports/src/
# synapse-1.1-src/modules/transports/src/test/
# synapse-1.1-src/modules/transports/src/test/java/
# synapse-1.1-src/modules/transports/src/test/java/org/
# synapse-1.1-src/modules/transports/src/test/java/org/apache/
# synapse-1.1-src/modules/transports/src/test/java/org/apache/synapse/
# synapse-1.1-src/modules/transports/src/test/java/org/apache/synapse/transport/
# synapse-1.1-src/modules/transports/src/test/java/org/apache/synapse/transport/vfs/
# synapse-1.1-src/modules/transports/src/test/resources/
# synapse-1.1-src/modules/transports/src/main/
# synapse-1.1-src/modules/transports/src/main/java/
# synapse-1.1-src/modules/transports/src/main/java/org/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/threads/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/util/
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/vfs/
# synapse-1.1-src/modules/samples/
# synapse-1.1-src/modules/samples/services/
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/conf/
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/src/
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/src/samples/
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/src/samples/services/
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/wsdl/
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/conf/
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/src/
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/src/samples/
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/src/samples/services/
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/wsdl/
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/conf/
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/wsdl/
# synapse-1.1-src/modules/samples/services/MTOMSwASampleService/
# synapse-1.1-src/modules/samples/services/MTOMSwASampleService/conf/
# synapse-1.1-src/modules/samples/services/MTOMSwASampleService/src/
# synapse-1.1-src/modules/samples/services/MTOMSwASampleService/src/samples/
# synapse-1.1-src/modules/samples/services/MTOMSwASampleService/src/samples/services/
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/conf/
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/wsdl/
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/conf/
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/conf/service1/
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/conf/service2/
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/src/
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/src/samples/
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/src/samples/services/
# synapse-1.1-src/modules/samples/src/
# synapse-1.1-src/modules/samples/src/test/
# synapse-1.1-src/modules/samples/src/test/java/
# synapse-1.1-src/modules/samples/src/test/java/org/
# synapse-1.1-src/modules/samples/src/test/java/org/apache/
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/
# synapse-1.1-src/modules/samples/src/test/resources/
# synapse-1.1-src/modules/samples/src/main/
# synapse-1.1-src/modules/samples/src/main/java/
# synapse-1.1-src/modules/samples/src/main/java/samples/
# synapse-1.1-src/modules/samples/src/main/java/samples/mediators/
# synapse-1.1-src/modules/samples/src/main/java/samples/common/
# synapse-1.1-src/modules/samples/src/main/java/samples/userguide/
# synapse-1.1-src/modules/samples/src/main/java/samples/util/
# synapse-1.1-src/modules/samples/src/main/scripts/
# synapse-1.1-src/modules/samples/src/main/resources/
# synapse-1.1-src/modules/samples/src/main/resources/META-INF/
# synapse-1.1-src/modules/core/
# synapse-1.1-src/modules/core/src/
# synapse-1.1-src/modules/core/src/test/
# synapse-1.1-src/modules/core/src/test/java/
# synapse-1.1-src/modules/core/src/test/java/org/
# synapse-1.1-src/modules/core/src/test/java/org/apache/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/utils/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/ext/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/db/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/builtin/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/filters/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/base/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/transform/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/eip/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/registry/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/registry/url/
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/n2n/
# synapse-1.1-src/modules/core/src/test/resources/
# synapse-1.1-src/modules/core/src/main/
# synapse-1.1-src/modules/core/src/main/java/
# synapse-1.1-src/modules/core/src/main/java/org/
# synapse-1.1-src/modules/core/src/main/java/org/apache/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/ext/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/db/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/builtin/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/filters/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/base/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/transform/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/eip/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/eip/aggregator/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/eip/splitter/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/core/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/core/axis2/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/statistics/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/statistics/impl/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/startup/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/startup/tasks/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/startup/quartz/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/endpoints/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/endpoints/dispatch/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/endpoints/utils/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/endpoints/algorithms/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/utils/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/metrics/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/registry/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/registry/url/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/util/
# synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/util/concurrent/
# synapse-1.1-src/modules/core/src/main/resources/
# synapse-1.1-src/modules/core/src/main/resources/META-INF/
# synapse-1.1-src/modules/core/logs/
# synapse-1.1-src/modules/war/
# synapse-1.1-src/modules/handler/
# synapse-1.1-src/modules/handler/src/
# synapse-1.1-src/modules/handler/src/test/
# synapse-1.1-src/modules/handler/src/test/java/
# synapse-1.1-src/modules/handler/src/test/resources/
# synapse-1.1-src/modules/handler/src/main/
# synapse-1.1-src/modules/handler/src/main/java/
# synapse-1.1-src/modules/handler/src/main/java/org/
# synapse-1.1-src/modules/handler/src/main/java/org/apache/
# synapse-1.1-src/modules/handler/src/main/java/org/apache/synapse/
# synapse-1.1-src/modules/handler/src/main/java/org/apache/synapse/handler/
# synapse-1.1-src/modules/handler/src/main/java/org/apache/synapse/util/
# synapse-1.1-src/modules/handler/src/main/resources/
# synapse-1.1-src/modules/handler/src/main/resources/META-INF/
# synapse-1.1-src/NOTICE
# synapse-1.1-src/LICENSE
# synapse-1.1-src/BUILDING.txt
# synapse-1.1-src/README.txt
# synapse-1.1-src/repository/conf/sample/resources/policy/sample_policy_1.xml
# synapse-1.1-src/repository/conf/sample/resources/policy/policy_3.xml
# synapse-1.1-src/repository/conf/sample/resources/policy/throttle_policy.xml
# synapse-1.1-src/repository/conf/sample/resources/policy/sample_rm_policy_1.xml
# synapse-1.1-src/repository/conf/sample/resources/policy/client_policy_3.xml
# synapse-1.1-src/repository/conf/sample/resources/policy/policy_1.xml
# synapse-1.1-src/repository/conf/sample/resources/endpoint/dynamic_endpt_1.xml
# synapse-1.1-src/repository/conf/sample/resources/proxy/sample_proxy_1.wsdl
# synapse-1.1-src/repository/conf/sample/resources/spring/synapse_spring_unittest.xml
# synapse-1.1-src/repository/conf/sample/resources/spring/springsample.xml
# synapse-1.1-src/repository/conf/sample/resources/script/stockquoteTransform.rb
# synapse-1.1-src/repository/conf/sample/resources/script/stockquoteTransform.js
# synapse-1.1-src/repository/conf/sample/resources/security/store.jks
# synapse-1.1-src/repository/conf/sample/resources/sequence/dynamic_seq_1.xml
# synapse-1.1-src/repository/conf/sample/resources/validate/validate.xsd
# synapse-1.1-src/repository/conf/sample/resources/validate/validate2.xsd
# synapse-1.1-src/repository/conf/sample/resources/misc/server/axis2.xml
# synapse-1.1-src/repository/conf/sample/resources/misc/client/axis2.xml
# synapse-1.1-src/repository/conf/sample/resources/misc/commission.xml
# synapse-1.1-src/repository/conf/sample/resources/misc/synapse.xml
# synapse-1.1-src/repository/conf/sample/resources/transform/message.xml
# synapse-1.1-src/repository/conf/sample/resources/transform/transform_unittest.xslt
# synapse-1.1-src/repository/conf/sample/resources/transform/transform.xslt
# synapse-1.1-src/repository/conf/sample/resources/transform/transform_back.xslt
# synapse-1.1-src/repository/conf/sample/resources/transform/transform_load.xml
# synapse-1.1-src/repository/conf/sample/resources/transform/transform_load_2.xml
# synapse-1.1-src/repository/conf/sample/resources/transform/small_message.xml
# synapse-1.1-src/repository/conf/sample/resources/transform/transform_load_3.xml
# synapse-1.1-src/repository/conf/sample/resources/mtom/asf-logo.gif
# synapse-1.1-src/repository/conf/sample/resources/xquery/xquery_commisson.xq
# synapse-1.1-src/repository/conf/sample/resources/xquery/xquery_req.xq
# synapse-1.1-src/repository/conf/sample/resources/xquery/xquery_res.xq
# synapse-1.1-src/repository/conf/sample/resources/vfs/test.xml
# synapse-1.1-src/repository/conf/sample/resources/synapse.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_100.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_101.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_200.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_300.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_201.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_400.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_420.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_360.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_361.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_362.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_380.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_10.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_11.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_50.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_51.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_52.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_53.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_54.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_55.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_56.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_0.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_1.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_2.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_3.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_4.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_5.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_150.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_6.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_151.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_250.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_7.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_350.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_251.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_152.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_8.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_351.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_252.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_153.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_9.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_370.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_352.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_253.xml
# synapse-1.1-src/repository/conf/sample/README.txt
# synapse-1.1-src/repository/conf/sample/synapse_sample_371.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_353.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_254.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_255.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_372.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_390.xml
# synapse-1.1-src/repository/conf/sample/synapse_sample_391.xml
# synapse-1.1-src/repository/conf/synapse.xml
# synapse-1.1-src/repository/conf/wrapper.conf
# synapse-1.1-src/repository/conf/axis2.xml
# synapse-1.1-src/repository/conf/web.xml
# synapse-1.1-src/repository/conf/synapse.properties
# synapse-1.1-src/src/main/assembly/src.xml
# synapse-1.1-src/src/main/assembly/bin.xml
# synapse-1.1-src/src/main/release/docs/release_notes.txt
# synapse-1.1-src/src/main/release/docs/endorsed_libs.txt
# synapse-1.1-src/src/main/release/NOTICE
# synapse-1.1-src/src/main/release/LICENSE
# synapse-1.1-src/src/main/release/BUILDING.txt
# synapse-1.1-src/src/main/release/README.txt
# synapse-1.1-src/src/main/bin/native/wrapper-solaris-x86-32
# synapse-1.1-src/src/main/bin/native/wrapper-linux-x86-32
# synapse-1.1-src/src/main/bin/native/wrapper-solaris-sparc-32
# synapse-1.1-src/src/main/bin/native/wrapper-linux-x86-64
# synapse-1.1-src/src/main/bin/native/wrapper-solaris-sparc-64
# synapse-1.1-src/src/main/bin/native/wrapper-windows-x86-32.exe
# synapse-1.1-src/src/main/bin/libwrapper-solaris-x86-32.so
# synapse-1.1-src/src/main/bin/run-synapse-service.bat
# synapse-1.1-src/src/main/bin/synapse.bat
# synapse-1.1-src/src/main/bin/wrapper-windows-x86-32.dll
# synapse-1.1-src/src/main/bin/install-synapse-service.bat
# synapse-1.1-src/src/main/bin/libwrapper-linux-x86-32.so
# synapse-1.1-src/src/main/bin/libwrapper-solaris-sparc-32.so
# synapse-1.1-src/src/main/bin/synapse.sh
# synapse-1.1-src/src/main/bin/synapse-daemon.sh
# synapse-1.1-src/src/main/bin/uninstall-synapse-service.bat
# synapse-1.1-src/src/main/bin/libwrapper-linux-x86-64.so
# synapse-1.1-src/src/main/bin/libwrapper-solaris-sparc-64.so
# synapse-1.1-src/src/site/resources/download/0.90/download.cgi
# synapse-1.1-src/src/site/resources/download/0.90/download.html
# synapse-1.1-src/src/site/resources/download/0.91/download.cgi
# synapse-1.1-src/src/site/resources/download/0.91/download.html
# synapse-1.1-src/src/site/resources/download/M1/download.cgi
# synapse-1.1-src/src/site/resources/download/M1/download.html
# synapse-1.1-src/src/site/resources/download/1.0/download.cgi
# synapse-1.1-src/src/site/resources/download/1.0/download.html
# synapse-1.1-src/src/site/resources/download/M2/download.cgi
# synapse-1.1-src/src/site/resources/download/M2/download.html
# synapse-1.1-src/src/site/resources/presentations/ApacheCon Synapse Tute.pdf
# synapse-1.1-src/src/site/resources/Synapse_Configuration_Language.html
# synapse-1.1-src/src/site/resources/Synapse_QuickStart.html
# synapse-1.1-src/src/site/resources/doap_Synapse.rdf
# synapse-1.1-src/src/site/resources/download.cgi
# synapse-1.1-src/src/site/resources/Synapse_Samples.html
# synapse-1.1-src/src/site/resources/Synapse_Samples_Setup.html
# synapse-1.1-src/src/site/resources/Synapse_Extending.html
# synapse-1.1-src/src/site/resources/download.html
# synapse-1.1-src/src/site/xdoc/index.xml
# synapse-1.1-src/src/site/xdoc/navigation.xml
# synapse-1.1-src/src/site/site.xml
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/spring/SpringMediatorTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/spring/SpringTestBean.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/spring/TestMediateHandlerImpl.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/throttle/ThrottleMediatorSerializationTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/throttle/ThrottleMediatorTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/validate/ValidateMediatorSerializationTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/validate/ValidateMediatorTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/bsf/javascript/JavaScriptMediatorTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/bsf/GroovyScriptMediatorTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/bsf/ScriptMediatorFactoryTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/bsf/ScriptMediatorSerializationTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/bsf/ScriptMediatorTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/transform/XSLTMediatorTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/xquery/XQueryMediatorSerializationTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/xquery/XQueryMediatorTest.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/AbstractTestCase.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/mediators/TestUtils.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/TestMediator.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/TestMediateHandler.java
# synapse-1.1-src/modules/extensions/src/test/java/org/apache/synapse/TestMessageContext.java
# synapse-1.1-src/modules/extensions/src/test/resources/log4j.properties
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/spring/SpringMediatorFactory.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/spring/SpringMediatorSerializer.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/spring/SpringMediator.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/throttle/ThrottleMediatorFactory.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/throttle/ThrottleMediatorSerializer.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/throttle/ThrottleMediator.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/bsf/ScriptMediatorFactory.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/bsf/ScriptMediatorSerializer.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/bsf/ScriptMediator.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/bsf/ScriptMessageContext.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/xquery/XQueryMediator.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/xquery/MediatorBaseVariable.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/xquery/MediatorCustomVariable.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/xquery/MediatorVariable.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/xquery/XQueryMediatorFactory.java
# synapse-1.1-src/modules/extensions/src/main/java/org/apache/synapse/mediators/xquery/XQueryMediatorSerializer.java
# synapse-1.1-src/modules/extensions/src/main/resources/META-INF/services/org.apache.synapse.config.xml.MediatorFactory
# synapse-1.1-src/modules/extensions/src/main/resources/META-INF/services/org.apache.synapse.config.xml.MediatorSerializer
# synapse-1.1-src/modules/extensions/src/main/resources/META-INF/NOTICE
# synapse-1.1-src/modules/extensions/src/main/resources/META-INF/LICENSE
# synapse-1.1-src/modules/extensions/pom.xml
# synapse-1.1-src/modules/extensions/logs/synapse.log
# synapse-1.1-src/modules/extensions/logs/service.log
# synapse-1.1-src/modules/extensions/logs/trace.log
# synapse-1.1-src/modules/mar/pom.xml
# synapse-1.1-src/modules/transports/src/test/java/org/apache/synapse/transport/vfs/UtilsVFSServer.java
# synapse-1.1-src/modules/transports/src/test/java/org/apache/synapse/transport/vfs/VFSEchoRawXMLTest.java
# synapse-1.1-src/modules/transports/src/test/java/org/apache/synapse/transport/AbstractTransportTest.java
# synapse-1.1-src/modules/transports/src/test/java/org/apache/synapse/transport/UtilsTransportServer.java
# synapse-1.1-src/modules/transports/src/test/java/org/apache/synapse/transport/Echo.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/JMSListener.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/JMSConnectionFactory.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/JMSMessageReceiver.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/JMSConstants.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/JMSOutTransportInfo.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/JMSSender.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/JMSUtils.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/README.txt
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/jms/AxisJMSException.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/threads/WorkerPool.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/threads/BackportWorkerPool.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/threads/NativeWorkerPool.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/threads/WorkerPoolFactory.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/AbstractTransportSender.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/AbstractTransportListener.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/BaseTransportException.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/BaseConstants.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/AbstractPollingTransportListener.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/base/BaseUtils.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/util/PipeImpl.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/util/WorkerPool.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/util/BackportWorkerPool.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/util/NativeWorkerPool.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/util/WorkerPoolFactory.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/HttpCoreNIOSender.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/Axis2HttpRequest.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/ServerWorker.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/LoggingNHttpClientHandler.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/SSLServerIOEventDispatch.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/HttpCoreNIOListener.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/PlainServerIOEventDispatch.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/ServerHandler.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/ClientWorker.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/HostnameVerifier.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/SSLClientIOEventDispatch.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/LoggingNHttpServerConnection.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/ClientHandler.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/PlainClientIOEventDispatch.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/NhttpUtils.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/HttpCoreNIOSSLSender.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/LoggingIOSession.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/LoggingNHttpServiceHandler.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/LoggingNHttpClientConnection.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/NHttpConfiguration.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/HttpCoreNIOSSLListener.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/ConnectionPool.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/NhttpConstants.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/nhttp/HttpCoreRequestResponseTransport.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/vfs/VFSOutTransportInfo.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/vfs/VFSUtils.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/vfs/PollTableEntry.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/vfs/VFSTransportListener.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/vfs/VFSConstants.java
# synapse-1.1-src/modules/transports/src/main/java/org/apache/synapse/transport/vfs/VFSTransportSender.java
# synapse-1.1-src/modules/transports/pom.xml
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/conf/services.xml
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/src/samples/services/FastStockQuoteService.java
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/src/samples/services/PlaceOrder.java
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/src/samples/services/GetQuoteResponse.java
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/src/samples/services/GetQuote.java
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/wsdl/FastStockQuoteService.wsdl
# synapse-1.1-src/modules/samples/services/FastStockQuoteService/build.xml
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/conf/services.xml
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/src/samples/services/PlaceOrder.java
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/src/samples/services/ReliableStockQuoteService.java
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/src/samples/services/GetQuoteResponse.java
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/src/samples/services/GetQuote.java
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/wsdl/ReliableStockQuoteService.wsdl
# synapse-1.1-src/modules/samples/services/ReliableStockQuoteService/build.xml
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/conf/services.xml
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/GetFullQuoteResponse.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/GetMarketActivityResponse.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/GetFullQuote.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/GetMarketActivity.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/PlaceOrder.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/TradingDay.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/GetQuoteResponse.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/SimpleStockQuoteService.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/src/samples/services/GetQuote.java
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/wsdl/SimpleStockQuoteService.wsdl
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/store.jks
# synapse-1.1-src/modules/samples/services/SecureStockQuoteService/build.xml
# synapse-1.1-src/modules/samples/services/MTOMSwASampleService/conf/services.xml
# synapse-1.1-src/modules/samples/services/MTOMSwASampleService/src/samples/services/MTOMSwASampleService.java
# synapse-1.1-src/modules/samples/services/MTOMSwASampleService/build.xml
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/conf/services.xml
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/GetFullQuoteResponse.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/GetMarketActivityResponse.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/GetFullQuote.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/GetMarketActivity.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/PlaceOrder.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/TradingDay.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/GetQuoteResponse.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/SimpleStockQuoteService.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/src/samples/services/GetQuote.java
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/wsdl/SimpleStockQuoteService.wsdl
# synapse-1.1-src/modules/samples/services/SimpleStockQuoteService/build.xml
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/conf/service1/services.xml
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/conf/service2/services.xml
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/src/samples/services/LBService1.java
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/src/samples/services/LBService2.java
# synapse-1.1-src/modules/samples/services/LoadbalanceFailoverService/build.xml
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_54_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/AbstractAutomationTestCase.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_56_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_0_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_100_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_110_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_2_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_102_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_4_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_112_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_500_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_104_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_510_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_114_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_6_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_502_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_8_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_11_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_51_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_53_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_55_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_57_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_1_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_101_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_3_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_111_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_103_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_5_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_113_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_501_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_600_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_7_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_503_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_9_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_10_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_50_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_60_Integration.java
# synapse-1.1-src/modules/samples/src/test/java/org/apache/synapse/samples/n2n/SynapseSample_52_Integration.java
# synapse-1.1-src/modules/samples/src/main/java/samples/mediators/DiscountQuoteMediator.java
# synapse-1.1-src/modules/samples/src/main/java/samples/common/StockQuoteHandler.java
# synapse-1.1-src/modules/samples/src/main/java/samples/userguide/ThreadedClient.java
# synapse-1.1-src/modules/samples/src/main/java/samples/userguide/StockQuoteClient.java
# synapse-1.1-src/modules/samples/src/main/java/samples/userguide/PWCallback.java
# synapse-1.1-src/modules/samples/src/main/java/samples/userguide/GenericJMSClient.java
# synapse-1.1-src/modules/samples/src/main/java/samples/userguide/MTOMSwAClient.java
# synapse-1.1-src/modules/samples/src/main/java/samples/userguide/LoadbalanceFailoverClient.java
# synapse-1.1-src/modules/samples/src/main/java/samples/userguide/ServiceInvoker.java
# synapse-1.1-src/modules/samples/src/main/java/samples/util/SampleAxis2Server.java
# synapse-1.1-src/modules/samples/src/main/scripts/axis2server.bat
# synapse-1.1-src/modules/samples/src/main/scripts/axis2server.sh
# synapse-1.1-src/modules/samples/src/main/scripts/build.xml
# synapse-1.1-src/modules/samples/src/main/resources/META-INF/NOTICE
# synapse-1.1-src/modules/samples/src/main/resources/META-INF/LICENSE
# synapse-1.1-src/modules/samples/pom.xml
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/utils/Services.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/AbstractTestCase.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/ProxyServiceSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/DBLookupMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/LogMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/TestMediator.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/RegistrySerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/PropertyMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/FilterMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/HeaderMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/SendMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/IterateMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/CloneMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/SwitchMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/DropMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/ClassMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/POJOCommandMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/InMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/OutMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/SequenceMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/config/xml/FaultMediatorSerializationTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/ext/ClassMediatorTestMediator.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/ext/POJOCommandTestImplementedMediator.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/ext/POJOCommandTestHelper.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/ext/ClassMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/ext/POJOCommandMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/ext/POJOCommandTestMediator.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/db/DBLookupMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/db/DBReportMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/builtin/DropMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/builtin/PropertyMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/filters/SwitchMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/filters/FilterMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/base/SequenceMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/transform/FaultMediatorTest.java
# synapse-1.1-src/modules/core/src/test/java/org/apache/synapse/mediators/transform/HeaderMediatorTest.java
# ...
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/SALoadbalanceEndpointSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/WSDLEndpointSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/EndpointFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/XMLToEndpointMapper.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/EndpointSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/DefaultEndpointFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/AddressEndpointFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/LoadbalanceEndpointFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/DefaultEndpointSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/AddressEndpointSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/LoadbalanceEndpointSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/IndirectEndpointFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/IndirectEndpointSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ConfigurationFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SynapseMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AggregateMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ValidateMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/HeaderMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ValidateMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/XSLTMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/CloneMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/TargetFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SynapseXPathFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ResourceMapSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/TargetSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/CacheMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/DropMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/POJOCommandMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/PropertyHelper.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SequenceMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SynapseXMLConfigurationSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/MediatorSerializerFinder.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/EntryFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/StartupFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/MediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/DBLookupMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/StartupSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SwitchCase.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/LogMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SynapseMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/XMLConfigurationBuilder.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/RegistryFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/LogMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AnonymousListMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AggregateMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/XSLTMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/IterateMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AbstractListMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/IterateMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SwitchMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/CloneMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SwitchMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/CalloutMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ClassMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AbstractMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SynapseXMLConfigurationFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/DropMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ClassMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/OutMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/RMSequenceMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SequenceMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/FaultMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/StartupFinder.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/EntrySerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/MediatorPropertyFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/PropertyMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AnonymousListMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ConfigurationFactoryAndSerializerFinder.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SendMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SendMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/CacheMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/package-info.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/MediatorFactoryFinder.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/InMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AnnotatedCommandMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/DBLookupMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/MediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/DBReportMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/DBReportMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ConfigurationSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/RegistrySerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/FilterMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/PropertyMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/FilterMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/HeaderMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/OMElementUtils.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AnonymousListMediator.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ResourceMapFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AbstractListMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AbstractMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/SynapseXPathSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/CalloutMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/XMLConfigurationSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/InMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/XMLConfigConstants.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/RMSequenceMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/POJOCommandMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/OutMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AbstractDBMediatorFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/AbstractDBMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ProxyServiceFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/FaultMediatorSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ProxyServiceSerializer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/XMLToObjectMapper.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/Entry.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/SynapseConfigurationBuilder.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/SynapseConfigUtils.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/SynapseConfiguration.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/metrics/Counter.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/metrics/MetricsAggregatorModule.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/metrics/GlobalRequestCountHandler.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/metrics/MetricsConstants.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/registry/url/SimpleURLRegistry.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/registry/Registry.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/registry/RegistryEntry.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/registry/AbstractRegistry.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/registry/RegistryEntryImpl.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/concurrent/SynapseThreadFactory.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/concurrent/SynapseThreadPool.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/xpath/SynapseXPathFunctionContext.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/xpath/SynapseXPathVariableContext.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/xpath/SynapseXPathConstants.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/xpath/package-info.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/xpath/SynapseXPath.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/TextFileDataSource.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/SynapseBinaryDataSource.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/SimpleMapImpl.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/PolicyInfo.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/TemporaryData.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/WrappedTextNodeStreamReader.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/DataSourceRegistrar.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/UUIDGenerator.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/ClasspathURLStreamHandler.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/FixedByteArrayOutputStream.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/MessageHelper.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/RMIRegistryController.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/POXUtils.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/SimpleMap.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/PayloadHelper.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/util/AXIOMUtils.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/ServerManager.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/SynapseException.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/Startup.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/Mediator.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/FaultHandler.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/SynapseServer.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/ManagedLifecycle.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/Command.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/SynapseConstants.java
# synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/MessageContext.java
# synapse-1.2-src/modules/core/src/main/resources/META-INF/NOTICE
# synapse-1.2-src/modules/core/src/main/resources/META-INF/LICENSE
# synapse-1.2-src/modules/core/src/main/resources/identity.jks
# synapse-1.2-src/modules/core/src/main/resources/module.xml
# synapse-1.2-src/modules/core/src/main/resources/trust.jks
# synapse-1.2-src/modules/core/src/main/resources/log4j.properties
# synapse-1.2-src/modules/core/src/main/resources/metrics_module.xml
# synapse-1.2-src/modules/core/src/main/resources/providers.xml
# synapse-1.2-src/modules/core/pom.xml
# synapse-1.2-src/modules/core/derby.log
# synapse-1.2-src/modules/war/pom.xml
# synapse-1.2-src/modules/handler/src/main/java/org/apache/synapse/handler/SynapseInHandler.java
# synapse-1.2-src/modules/handler/src/main/java/org/apache/synapse/handler/SynapseModule.java
# synapse-1.2-src/modules/handler/src/main/java/org/apache/synapse/handler/SynapseOutHandler.java
# synapse-1.2-src/modules/handler/src/main/java/org/apache/synapse/util/HandlerUtil.java
# synapse-1.2-src/modules/handler/src/main/resources/META-INF/module.xml
# synapse-1.2-src/modules/handler/pom.xml
# synapse-1.2-src/pom.xml
# synapse-1.2-src/patches/patches.txt
# tar: A lone zero block at 48019

# %% [markdown]
# ## Tải bộ dữ liệu Apache chứa các đặc trưng truyền thống

# %%
import os
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

train_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/synapse-1.1.csv"
test_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/synapse-1.2.csv"

train_csv = pd.read_csv(train_csv_path)
test_csv = pd.read_csv(test_csv_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2. Tiền xử lí dữ liệu

# %% [markdown]
# ## Chuẩn hoá dữ liệu giữa 2 dạng dữ liệu và loại bỏ

# %% [markdown]
# ### Chuẩn hoá giữa 2 dạng dữ liệu (csv và file source code)

# %%
# Chuẩn hóa tên file từ CSV để phù hợp với thư mục tools/
def convert_csv_name_to_java_filename(csv_name):
    """
    Chuyển:
    'org.apache.synapse.config.xml.ProxyServiceFactory' → 'config/xml/ProxyServiceFactory.java'

    Cách làm:
    - Tìm 'synapse.' trong đường dẫn, lấy phần sau nó làm thư mục gốc.
    - Nếu không có 'synapse.', giữ nguyên tên và thêm .java
    """
    parts = csv_name.split('.')
    if 'synapse' in parts:
        index = parts.index('synapse') + 1  # Lấy phần sau 'synapse'
        return "/".join(parts[index:]) + ".java"
    return csv_name.replace('.', '/') + ".java"


# Hàm lấy tất cả file Java trong thư mục mã nguồn (bao gồm tất cả thư mục con trong tools/)
def get_all_java_files(directory):
    """Lấy tất cả file Java trong thư mục tools/ """
    java_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".java"):
                java_files.append(os.path.join(root, file))
    return java_files


# Chuyển đường dẫn file Java thành dạng để so sánh với CSV
def convert_java_path_to_filename(java_path, base_dir):
    """Chuyển đường dẫn file Java thành tên tương đương trong CSV"""
    relative_path = os.path.relpath(java_path, base_dir)  # Lấy đường dẫn tương đối
    return relative_path.replace("\\", "/")  # Đảm bảo dạng Linux-style path

# %%
# Lấy danh sách file Java từ CSV (giữ đúng tầng thư mục `ant/`, `mail/`...)
train_csv_files = set(train_csv['name'].apply(convert_csv_name_to_java_filename))
test_csv_files = set(test_csv['name'].apply(convert_csv_name_to_java_filename))

# Đường dẫn đến mã nguồn Apache Ant (lấy toàn bộ tools/)
train_dir = "synapse-1.1-src/modules/core/src/main/java/org/apache/synapse"
test_dir = "synapse-1.2-src/modules/core/src/main/java/org/apache/synapse"

# Lấy tất cả file Java từ thư mục mã nguồn
train_files_all = get_all_java_files(train_dir)
test_files_all = get_all_java_files(test_dir)

# Tạo danh sách file từ mã nguồn ở dạng `ant/taskdefs/Property.java`
train_files_as_java = {convert_java_path_to_filename(f, train_dir) for f in train_files_all}
test_files_as_java = {convert_java_path_to_filename(f, test_dir) for f in test_files_all}

# Kiểm tra số lượng file khớp giữa CSV và mã nguồn
matched_train_files = train_files_as_java.intersection(train_csv_files)
matched_test_files = test_files_as_java.intersection(test_csv_files)

print(f"Số file trong CSV (synapse-1.1): {len(train_csv_files)}")
print(f"Số file có trong mã nguồn synapse-1.1: {len(train_files_all)}")
print(f"Số file trùng khớp giữa CSV và mã nguồn synapse-1.1: {len(matched_train_files)}")

print(f"Số file trong CSV (synapse-1.2): {len(test_csv_files)}")
print(f"Số file có trong mã nguồn Ant synapse-1.2: {len(test_files_all)}")
print(f"Số file trùng khớp giữa CSV và mã nguồn Ant synapse-1.2: {len(matched_test_files)}")
# Out:
# Số file trong CSV (synapse-1.1): 222
# Số file có trong mã nguồn synapse-1.1: 282
# Số file trùng khớp giữa CSV và mã nguồn synapse-1.1: 222
# Số file trong CSV (synapse-1.2): 256
# Số file có trong mã nguồn Ant synapse-1.2: 344
# Số file trùng khớp giữa CSV và mã nguồn Ant synapse-1.2: 256

# %% [markdown]
# ### Xoá những file source code không trùng trong file CSV
# Nhận thấy file source code thường có số lượng lớn hơn so với CSV. Chính vì thế, ta chỉ lấy những file source code và csv sau chuẩn hoá có name trùng nhau để có thể kết hợp các đặc trưng sau khi huấn luyện.

# %%
# Chỉ giữ lại các file Java có trong CSV
def get_java_files_by_csv(directory, csv_files):
    """Chỉ lấy file Java có trong danh sách CSV"""
    matched_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            full_path = os.path.join(root, file)
            relative_path = convert_java_path_to_filename(full_path, directory)
            if relative_path in csv_files:
                matched_files.append(full_path)
    return matched_files

# %%
filtered_train_files = get_java_files_by_csv(train_dir, matched_train_files)
filtered_test_files = get_java_files_by_csv(test_dir, matched_test_files)

print(f"Số file Java sau khi lọc theo CSV (Ant 1.6): {len(filtered_train_files)}")
print(f"Số file Java sau khi lọc theo CSV (Ant 1.7): {len(filtered_test_files)}")
# Out:
# Số file Java sau khi lọc theo CSV (Ant 1.6): 222
# Số file Java sau khi lọc theo CSV (Ant 1.7): 256

# %% [markdown]
# ### Lưu lại file csv sau khi đã xử lí và loại bỏ

# %%
# Lọc lại DataFrame chỉ giữ các file có trong Source Code
filtered_train_csv = train_csv[train_csv['name'].apply(convert_csv_name_to_java_filename).isin(matched_train_files)]
filtered_test_csv = test_csv[test_csv['name'].apply(convert_csv_name_to_java_filename).isin(matched_test_files)]

# Lưu lại CSV mới chỉ chứa các file có trong Source Code
filtered_train_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/filtered_synapse-1.1.csv"
filtered_test_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/filtered_synapse-1.2.csv"

filtered_train_csv.to_csv(filtered_train_csv_path, index=False)
filtered_test_csv.to_csv(filtered_test_csv_path, index=False)

print(f"File CSV mới đã được lưu: {filtered_train_csv_path}")
print(f"File CSV mới đã được lưu: {filtered_test_csv_path}")

# Đọc dữ liệu từ file CSV mới
filtered_train_df = pd.read_csv(filtered_train_csv_path)
filtered_test_df = pd.read_csv(filtered_test_csv_path)

# In số lượng file còn lại sau khi lọc
print(f"Số lượng file còn lại trong CSV mới (synapse-1.1): {filtered_train_df.shape[0]}")
print(f"Số lượng file còn lại trong CSV mới (synapse-1.2): {filtered_test_df.shape[0]}")
# Out:
# File CSV mới đã được lưu: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/filtered_synapse-1.1.csv
# File CSV mới đã được lưu: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/filtered_synapse-1.2.csv
# Số lượng file còn lại trong CSV mới (synapse-1.1): 222
# Số lượng file còn lại trong CSV mới (synapse-1.2): 256

# %% [markdown]
# ## Chia data và phân loại nhãn

# %% [markdown]
# ### Chuyển bài toán Multi-label classification thành bài toán Binary Label

# %%
# Chuyển đổi label: Nếu bug >= 1 thì gán thành 1, ngược lại giữ nguyên
filtered_train_df['bug'] = filtered_train_df['bug'].apply(lambda x: 1 if x >= 1 else 0)
filtered_test_df['bug'] = filtered_test_df['bug'].apply(lambda x: 1 if x >= 1 else 0)

# Kiểm tra lại số lượng mẫu sau khi chuẩn hóa
print("📌 Số lượng mỗi lớp sau khi xử lý trong tập train:")
print(filtered_train_df['bug'].value_counts())

print("\n📌 Số lượng mỗi lớp sau khi xử lý trong tập test:")
print(filtered_test_df['bug'].value_counts())
# Out:
# 📌 Số lượng mỗi lớp sau khi xử lý trong tập train:
# bug
# 0    162
# 1     60
# Name: count, dtype: int64
#
# 📌 Số lượng mỗi lớp sau khi xử lý trong tập test:
# bug
# 0    170
# 1     86
# Name: count, dtype: int64

# %% [markdown]
# ### Chia dữ liệu vào các tập train,test,validation

# %%
from sklearn.model_selection import train_test_split

# Chia tập train thành train và validation
train_df, val_df = train_test_split(filtered_train_df, test_size=0.2, random_state=42, stratify=filtered_train_df['bug'])
test_df = filtered_test_df

# Lưu tập train, validation và test mới sau khi chuẩn hóa
train_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/train_data_synapse-1.1.csv"
val_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/val_data_synapse-1.1.csv"
test_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/test_data_synapse-1.2.csv"

# Lưu các tập dữ liệu vào các file CSV tương ứng
train_df.to_csv(train_csv_path, index=False)
val_df.to_csv(val_csv_path, index=False)
test_df.to_csv(test_csv_path, index=False)

# In thông báo
print(f"Dữ liệu đã được chuẩn hóa và lưu tại: {train_csv_path}")
print(f"Dữ liệu đã được chuẩn hóa và lưu tại: {val_csv_path}")
print(f"Dữ liệu đã được chuẩn hóa và lưu tại: {test_csv_path}")
# Out:
# Dữ liệu đã được chuẩn hóa và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/train_data_synapse-1.1.csv
# Dữ liệu đã được chuẩn hóa và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/val_data_synapse-1.1.csv
# Dữ liệu đã được chuẩn hóa và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/test_data_synapse-1.2.csv

# %%
# Kiểm tra số lượng mẫu trong mỗi lớp của tập train
print("📌 Số lượng mỗi lớp trong tập train:")
print(train_df['bug'].value_counts())

# Kiểm tra số lượng mẫu trong mỗi lớp của tập validation
print("\n📌 Số lượng mỗi lớp trong tập validation:")
print(val_df['bug'].value_counts())

# Kiểm tra số lượng mẫu trong mỗi lớp của tập test
print("\n📌 Số lượng mỗi lớp trong tập test:")
print(test_df['bug'].value_counts())
# Out:
# 📌 Số lượng mỗi lớp trong tập train:
# bug
# 0    129
# 1     48
# Name: count, dtype: int64
#
# 📌 Số lượng mỗi lớp trong tập validation:
# bug
# 0    33
# 1    12
# Name: count, dtype: int64
#
# 📌 Số lượng mỗi lớp trong tập test:
# bug
# 0    170
# 1     86
# Name: count, dtype: int64

# %% [markdown]
# ## Kiểm tra cân bằng dữ liệu

# %% [markdown]
# ### Visualization phân phối dữ liệu dựa vào nhãn trước khi processing

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Kiểm tra số lượng mẫu trong từng lớp của từng tập (train, val, test)
train_bug_counts = train_df['bug'].value_counts()
val_bug_counts = val_df['bug'].value_counts()
test_bug_counts = test_df['bug'].value_counts()

# Vẽ biểu đồ cho tập train
plt.figure(figsize=(18, 5))

# Tập train
plt.subplot(1, 3, 1)
sns.barplot(x=train_bug_counts.index, y=train_bug_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập train")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Tập validation
plt.subplot(1, 3, 2)
sns.barplot(x=val_bug_counts.index, y=val_bug_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập validation")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Tập test
plt.subplot(1, 3, 3)
sns.barplot(x=test_bug_counts.index, y=test_bug_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập test")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Hiển thị các biểu đồ
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-70-078f49168a68>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=train_bug_counts.index, y=train_bug_counts.values, palette="viridis")
# <ipython-input-70-078f49168a68>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=val_bug_counts.index, y=val_bug_counts.values, palette="viridis")
# <ipython-input-70-078f49168a68>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=test_bug_counts.index, y=test_bug_counts.values, palette="viridis")

# %% [markdown]
# Nhận thấy dữ liệu Bug đang mất cân bằng so với dữ liệu No bug, có thể xử lí bằng 1 số cách như SMOTE, xoá bớt dữ liệu trong No Bug,.. Theo bài báo, ở đây xử lí bằng cáchnhân đôi các instance từ lớp

# %% [markdown]
# ### Xử lí mất cân bằng dữ liệu

# %%
# Nhân đôi các mẫu của lớp bug=1 trong các tập dữ liệu train, validation, test

# Tập train
bug_class_train = train_df[train_df['bug'] == 1]
duplicated_bug_class_train = pd.concat([bug_class_train, bug_class_train])
balanced_train_df = pd.concat([train_df[train_df['bug'] == 0], duplicated_bug_class_train])
balanced_train_df = balanced_train_df.reset_index(drop=True)

# Tập validation
bug_class_val = val_df[val_df['bug'] == 1]
duplicated_bug_class_val = pd.concat([bug_class_val, bug_class_val])
balanced_val_df = pd.concat([val_df[val_df['bug'] == 0], duplicated_bug_class_val])
balanced_val_df = balanced_val_df.reset_index(drop=True)

# Tập test
bug_class_test = test_df[test_df['bug'] == 1]
duplicated_bug_class_test = pd.concat([bug_class_test, bug_class_test])
balanced_test_df = pd.concat([test_df[test_df['bug'] == 0], duplicated_bug_class_test])
balanced_test_df = balanced_test_df.reset_index(drop=True)

# Kiểm tra kết quả
print(f"Số lượng file trong tập train sau cân bằng:\n{balanced_train_df['bug'].value_counts()}")
print(f"Số lượng file trong tập validation sau cân bằng:\n{balanced_val_df['bug'].value_counts()}")
print(f"Số lượng file trong tập test sau cân bằng:\n{balanced_test_df['bug'].value_counts()}")
# Out:
# Số lượng file trong tập train sau cân bằng:
# bug
# 0    129
# 1     96
# Name: count, dtype: int64
# Số lượng file trong tập validation sau cân bằng:
# bug
# 0    33
# 1    24
# Name: count, dtype: int64
# Số lượng file trong tập test sau cân bằng:
# bug
# 1    172
# 0    170
# Name: count, dtype: int64

# %%
# Lưu các tập dữ liệu đã được cân bằng
balanced_train_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_train_data.csv"
balanced_val_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_val_data.csv"
balanced_test_csv_path = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_test_data.csv"

balanced_train_df.to_csv(balanced_train_csv_path, index=False)
balanced_val_df.to_csv(balanced_val_csv_path, index=False)
balanced_test_df.to_csv(balanced_test_csv_path, index=False)

print(f"Dữ liệu train đã được cân bằng và lưu tại: {balanced_train_csv_path}")
print(f"Dữ liệu validation đã được cân bằng và lưu tại: {balanced_val_csv_path}")
print(f"Dữ liệu test đã được cân bằng và lưu tại: {balanced_test_csv_path}")
# Out:
# Dữ liệu train đã được cân bằng và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_train_data.csv
# Dữ liệu validation đã được cân bằng và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_val_data.csv
# Dữ liệu test đã được cân bằng và lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/balanced_test_data.csv

# %% [markdown]
# ### Visualization lại dữ liệu sau khi xử lí

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Kiểm tra số lượng mẫu trong từng lớp của từng tập (train, val, test) sau cân bằng
balanced_train_counts = balanced_train_df['bug'].value_counts()
balanced_val_counts = balanced_val_df['bug'].value_counts()
balanced_test_counts = balanced_test_df['bug'].value_counts()

# Vẽ biểu đồ cho tập balanced
plt.figure(figsize=(18, 5))

# Tập train balanced
plt.subplot(1, 3, 1)
sns.barplot(x=balanced_train_counts.index, y=balanced_train_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập train (Balanced)")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Tập validation balanced
plt.subplot(1, 3, 2)
sns.barplot(x=balanced_val_counts.index, y=balanced_val_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập validation (Balanced)")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Tập test balanced
plt.subplot(1, 3, 3)
sns.barplot(x=balanced_test_counts.index, y=balanced_test_counts.values, palette="viridis")
plt.xlabel("Bug Status (0: No Bug, 1: Bug)")
plt.ylabel("Số lượng file")
plt.title("Phân bố file có lỗi và không lỗi trong tập test (Balanced)")
plt.xticks(ticks=[0, 1], labels=["No Bug", "Bug"])

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-73-ede4eba8d77c>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=balanced_train_counts.index, y=balanced_train_counts.values, palette="viridis")
# <ipython-input-73-ede4eba8d77c>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=balanced_val_counts.index, y=balanced_val_counts.values, palette="viridis")
# <ipython-input-73-ede4eba8d77c>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=balanced_test_counts.index, y=balanced_test_counts.values, palette="viridis")

# %% [markdown]
# ## Lọc ra các file mới chứa các source code trùng với file

# %% [markdown]
# ### Tập train

# %%
# Chuẩn hóa danh sách file bug=1 từ CSV để khớp với source code
bug_files_csv = set(train_df['name'].apply(convert_csv_name_to_java_filename))

# Chuẩn hóa danh sách file từ source code để có dạng giống CSV
source_files_formatted = set(convert_java_path_to_filename(f, train_dir) for f in filtered_train_files)

print(f"📌 Tổng số file trong CSV: {len(bug_files_csv)}")
print(f"📌 Tổng số file source code có trong thư mục: {len(source_files_formatted)}")

# Lọc ra các file trong train_dir có tên trùng với CSV
matched_files = bug_files_csv.intersection(source_files_formatted)

# Lọc danh sách file từ train_dir để chỉ giữ các file có trong matched_files
train_files_new = [f for f in filtered_train_files if convert_java_path_to_filename(f, train_dir) in matched_files]

train_new_df = pd.DataFrame({'name': train_files_new})
print(f"📌 Tổng số file source code có trong thư mục sau khi lọc: {len(train_files_new)}")
# Out:
# 📌 Tổng số file trong CSV: 177
# 📌 Tổng số file source code có trong thư mục: 222
# 📌 Tổng số file source code có trong thư mục sau khi lọc: 177

# %% [markdown]
# ### Tập validation

# %%
# Chuẩn hóa danh sách file bug=1 từ CSV để khớp với source code
bug_files_csv = set(val_df['name'].apply(convert_csv_name_to_java_filename))

# Chuẩn hóa danh sách file từ source code để có dạng giống CSV
source_files_formatted = set(convert_java_path_to_filename(f, train_dir) for f in filtered_train_files)

print(f"📌 Tổng số file trong CSV: {len(bug_files_csv)}")
print(f"📌 Tổng số file source code có trong thư mục: {len(source_files_formatted)}")

# Lọc ra các file trong train_dir có tên trùng với CSV
matched_files = bug_files_csv.intersection(source_files_formatted)

# Lọc danh sách file từ train_dir để chỉ giữ các file có trong matched_files
val_dir_new = [f for f in filtered_train_files if convert_java_path_to_filename(f, train_dir) in matched_files]

# Lọc danh sách file từ train_dir để chỉ giữ các file có trong matched_files
val_files_new = [f for f in filtered_train_files if convert_java_path_to_filename(f, train_dir) in matched_files]

val_new_df= pd.DataFrame({'name': val_files_new})
print(f"📌 Tổng số file source code có trong thư mục sau khi lọc: {len(val_files_new)}")
# Out:
# 📌 Tổng số file trong CSV: 45
# 📌 Tổng số file source code có trong thư mục: 222
# 📌 Tổng số file source code có trong thư mục sau khi lọc: 45

# %% [markdown]
# ## Nhân đôi file dữ liệu trong source code

# %% [markdown]
# Để đảm bảo dữ liệu huấn luyện được đồng bộ giữa CSV và mã nguồn,` cần nhân đôi các file source code tương ứng với các file đã bị nhân đôi trong CSV.

# %% [markdown]
# ### Tập train

# %%
import shutil
# 🔹 Lọc danh sách file có bug=1 từ CSV
bug_train_csv = set(train_df[train_df['bug'] == 1]['name'].apply(convert_csv_name_to_java_filename))

# 🔹 Lọc danh sách file source code có bug=1
train_files_new_1 = [file for file in filtered_train_files if convert_java_path_to_filename(file, train_dir) in bug_train_csv]

print(f"📌 Tổng số file bug=1 trong CSV: {len(bug_train_csv)}")
print(f"📌 Tổng số file source code có bug=1: {len(train_files_new_1)}")

# 🔹 3. Nhân đôi file source code có bug=1 và cập nhật danh sách
duplicated_files = []
for file in train_files_new_1:
    duplicate_file_path = file.replace(".java", "_dup.java")  # Tạo tên file mới
    shutil.copy(file, duplicate_file_path)  # Sao chép file
    duplicated_files.append(duplicate_file_path)

# 🔹 4. Cập nhật danh sách filtered_train_files
train_files_new += duplicated_files  # Thêm file nhân đôi vào danh sách gốc

# 🔹 5. Kiểm tra lại số lượng file sau nhân đôi
print(f"📌 Số file source code gốc (train set): {len(train_files_new) - len(duplicated_files)}")
print(f"📌 Số file source code nhân đôi: {len(duplicated_files)}")
print(f"✅ Tổng số file source code sau nhân đôi: {len(train_files_new)}")

# 🔹 6. Hiển thị danh sách file đã nhân đôi
print("\n📜 Danh sách file đã nhân đôi:")
print(duplicated_files[:10])  # Hiển thị 10 file đầu tiên
# Out:
# 📌 Tổng số file bug=1 trong CSV: 48
# 📌 Tổng số file source code có bug=1: 48
# 📌 Số file source code gốc (train set): 177
# 📌 Số file source code nhân đôi: 48
# ✅ Tổng số file source code sau nhân đôi: 225
#
# 📜 Danh sách file đã nhân đôi:
# ['synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/SynapseConstants_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/SynapseConfiguration_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/SynapseConfigUtils_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/SendMediatorFactory_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/TargetSerializer_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/XMLConfigurationSerializer_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/FaultMediatorSerializer_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/ProxyServiceFactory_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/POJOCommandMediatorSerializer_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/ProxyServiceSerializer_dup.java']

# %% [markdown]
# ### Tập validation

# %%
import shutil

# 🔹 Lọc danh sách file có bug=1 từ CSV
bug_val_csv = set(val_df[val_df['bug'] == 1]['name'].apply(convert_csv_name_to_java_filename))

# 🔹 Lọc danh sách file source code có bug=1
val_files_new_1 = [file for file in val_files_new if convert_java_path_to_filename(file, train_dir) in bug_val_csv]

print(f"📌 Tổng số file bug=1 trong CSV: {len(bug_val_csv)}")
print(f"📌 Tổng số file source code có bug=1: {len(val_files_new_1)}")

# 🔹 3. Nhân đôi file source code có bug=1 và cập nhật danh sách
duplicated_files = []
for file in val_files_new_1:
    duplicate_file_path = file.replace(".java", "_dup.java")  # Tạo tên file mới
    shutil.copy(file, duplicate_file_path)  # Sao chép file
    duplicated_files.append(duplicate_file_path)

# 🔹 4. Cập nhật danh sách filtered_validation_files
val_files_new += duplicated_files  # Thêm file nhân đôi vào danh sách gốc

# 🔹 5. Kiểm tra lại số lượng file sau nhân đôi
print(f"📌 Số file source code gốc (validation set): {len(val_files_new) - len(duplicated_files)}")
print(f"📌 Số file source code nhân đôi: {len(duplicated_files)}")
print(f"✅ Tổng số file source code sau nhân đôi: {len(val_files_new)}")

# 🔹 6. Hiển thị danh sách file đã nhân đôi
print("\n📜 Danh sách file đã nhân đôi:")
print(duplicated_files[:10])  # Hiển thị 10 file đầu tiên
# Out:
# 📌 Tổng số file bug=1 trong CSV: 12
# 📌 Tổng số file source code có bug=1: 12
# 📌 Số file source code gốc (validation set): 45
# 📌 Số file source code nhân đôi: 12
# ✅ Tổng số file source code sau nhân đôi: 57
#
# 📜 Danh sách file đã nhân đôi:
# ['synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/SendMediatorSerializer_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/AbstractMediatorSerializer_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/EndpointSerializer_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/EndpointFactory_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/AddressEndpointFactory_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/config/xml/endpoints/WSDLEndpointSerializer_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/mediators/builtin/RMSequenceMediator_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/endpoints/FailoverEndpoint_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/core/axis2/SynapseCallbackReceiver_dup.java', 'synapse-1.1-src/modules/core/src/main/java/org/apache/synapse/core/axis2/SynapseInitializationModule_dup.java']

# %% [markdown]
# ### Tập test

# %%
import shutil

# 🔹 Lọc danh sách file có bug=1 từ CSV
bug_test_csv = set(test_df[test_df['bug'] == 1]['name'].apply(convert_csv_name_to_java_filename))

# 🔹 Lọc danh sách file source code có bug=1
test_files_new_1 = [file for file in filtered_test_files if convert_java_path_to_filename(file, test_dir) in bug_test_csv]

print(f"📌 Tổng số file bug=1 trong CSV: {len(bug_test_csv)}")
print(f"📌 Tổng số file source code có bug=1: {len(test_files_new_1)}")

# 🔹 3. Nhân đôi file source code có bug=1 và cập nhật danh sách
duplicated_files = []
for file in test_files_new_1:
    duplicate_file_path = file.replace(".java", "_dup.java")  # Tạo tên file mới
    shutil.copy(file, duplicate_file_path)  # Sao chép file
    duplicated_files.append(duplicate_file_path)

# 🔹 4. Cập nhật danh sách filtered_test_files
filtered_test_files += duplicated_files  # Thêm file nhân đôi vào danh sách gốc

# 🔹 5. Kiểm tra lại số lượng file sau nhân đôi
print(f"📌 Số file source code gốc (test set): {len(filtered_test_files) - len(duplicated_files)}")
print(f"📌 Số file source code nhân đôi: {len(duplicated_files)}")
print(f"✅ Tổng số file source code sau nhân đôi: {len(filtered_test_files)}")

# 🔹 6. Hiển thị danh sách file đã nhân đôi
print("\n📜 Danh sách file đã nhân đôi:")
print(duplicated_files[:10])  # Hiển thị 10 file đầu tiên
# Out:
# 📌 Tổng số file bug=1 trong CSV: 86
# 📌 Tổng số file source code có bug=1: 86
# 📌 Số file source code gốc (test set): 256
# 📌 Số file source code nhân đôi: 86
# ✅ Tổng số file source code sau nhân đôi: 342
#
# 📜 Danh sách file đã nhân đôi:
# ['synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/ServerManager_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/SynapseServer_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/SynapseException_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/SynapseConstants_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/SynapseConfiguration_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/SynapseConfigUtils_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/SynapseConfigurationBuilder_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/XMLConfigConstants_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/ResourceMapFactory_dup.java', 'synapse-1.2-src/modules/core/src/main/java/org/apache/synapse/config/xml/MediatorSerializerFinder_dup.java']

# %% [markdown]
# # 2. Phân tích cây AST

# %%
# !pip install javalang
# Out:
# Requirement already satisfied: javalang in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from javalang) (1.17.0)

# %%
import javalang

def extract_tokens_from_file(file_path):
    """Trích xuất các token quan trọng từ cây AST của mã nguồn Java"""
    try:
        with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
            code = f.read()

        tokens = []
        tree = javalang.parse.parse(code)  # Phân tích mã nguồn thành AST

        for path, node in tree:
            if isinstance(node, javalang.tree.MethodInvocation):
                tokens.append(node.member)
            elif isinstance(node, javalang.tree.ClassDeclaration):
                tokens.append(node.name)
            elif isinstance(node, javalang.tree.ConstructorDeclaration):
                tokens.append(node.name)
            elif isinstance(node, javalang.tree.VariableDeclarator):
                tokens.append(node.name)
            elif isinstance(node, javalang.tree.MemberReference):
                tokens.append(node.member)
            elif isinstance(node, javalang.tree.IfStatement):
                tokens.append("<IF>")
            elif isinstance(node, javalang.tree.ForStatement):
                tokens.append("<FOR>")
            elif isinstance(node, javalang.tree.WhileStatement):
                tokens.append("<WHILE>")
            elif isinstance(node, javalang.tree.CatchClause):
                tokens.append("<CATCH>")

        return tokens
    except Exception as e:
        print(f"Lỗi khi xử lý file {file_path}: {e}")
        return []

# %%
import javalang

def extract_tokens_from_file(file_path):
    """Trích xuất các token quan trọng từ cây AST của mã nguồn Java (cải tiến)."""
    try:
        with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
            code = f.read()

        tokens = []
        tree = javalang.parse.parse(code)  # Phân tích mã nguồn thành AST

        for path, node in tree:
            # ✅ Trích xuất tên Method và Constructor với tiền tố 'METHOD_'
            if isinstance(node, javalang.tree.MethodDeclaration):
                tokens.append(f"METHOD_{node.name}")
            elif isinstance(node, javalang.tree.ConstructorDeclaration):
                tokens.append(f"METHOD_{node.name}")

            # ✅ Lấy danh sách tên Class/Interface với tiền tố 'CLASS_'
            elif isinstance(node, javalang.tree.ClassDeclaration) or isinstance(node, javalang.tree.InterfaceDeclaration):
                tokens.append(f"CLASS_{node.name}")

            # ✅ Lấy biến với tiền tố 'VAR_' để phân biệt
            elif isinstance(node, javalang.tree.VariableDeclarator):
                tokens.append(f"VAR_{node.name}")

            # ✅ Lấy các thành viên class
            elif isinstance(node, javalang.tree.MemberReference):
                tokens.append(f"MEMBER_{node.member}")

            # ✅ Thêm thông tin Annotation (nếu có)
            elif isinstance(node, javalang.tree.Annotation):
                tokens.append(f"ANNOTATION_{node.name}")

            # ✅ Lấy các từ khóa điều kiện & vòng lặp
            elif isinstance(node, javalang.tree.IfStatement):
                tokens.append("<IF>")
            elif isinstance(node, javalang.tree.ForStatement):
                tokens.append("<FOR>")
            elif isinstance(node, javalang.tree.WhileStatement):
                tokens.append("<WHILE>")
            elif isinstance(node, javalang.tree.DoStatement):
                tokens.append("<DO>")
            elif isinstance(node, javalang.tree.SwitchStatement):
                tokens.append("<SWITCH>")
            elif hasattr(javalang.tree, "CaseStatement") and isinstance(node, javalang.tree.CaseStatement):
                tokens.append("<CASE>")  # ✅ Chỉ thêm nếu `CaseStatement` tồn tại
            elif isinstance(node, javalang.tree.TryStatement):
                tokens.append("<TRY>")
            elif isinstance(node, javalang.tree.ThrowStatement):
                tokens.append("<THROW>")
            elif isinstance(node, javalang.tree.CatchClause):
                tokens.append("<CATCH>")
            elif isinstance(node, javalang.tree.ReturnStatement):
                tokens.append("<RETURN>")

            # ✅ Lấy thông tin kiểu dữ liệu biến
            elif isinstance(node, javalang.tree.LocalVariableDeclaration):
                for var in node.declarators:
                    tokens.append(f"VAR_{var.name}_TYPE_{node.type.name}")

            # ✅ Lấy kiểu dữ liệu tham số của hàm
            elif isinstance(node, javalang.tree.MethodDeclaration):
                for param in node.parameters:
                    tokens.append(f"PARAM_{param.name}_TYPE_{param.type.name}")

            # ✅ Lấy tên các import để hiểu bối cảnh code
            elif isinstance(node, javalang.tree.Import):
                tokens.append(f"IMPORT_{node.path}")

        return tokens
    except Exception as e:
        print(f"Lỗi khi xử lý file {file_path}: {e}")
        return []

# %%
sample_file = filtered_train_files[9]  # Lấy một file từ danh sách đã lọc
sample_tokens = extract_tokens_from_file(sample_file)
print("📌 Token từ file mẫu:", sample_tokens)
# Out:
# 📌 Token từ file mẫu: ['IMPORT_org.apache.axiom.om.OMAbstractFactory', 'IMPORT_org.apache.axiom.om.OMNamespace', 'IMPORT_javax.xml.namespace.QName', 'CLASS_SynapseConstants', 'VAR_SYNAPSE_NAMESPACE', 'VAR_SYNAPSE_OMNAMESPACE', 'MEMBER_SYNAPSE_NAMESPACE', 'VAR_MAIN_SEQUENCE_KEY', 'VAR_FAULT_SEQUENCE_KEY', 'VAR_SYNAPSE_SERVICE_NAME', 'VAR_SYNAPSE_OPERATION_NAME', 'VAR_SANDESHA2_MODULE_NAME', 'VAR_ADDRESSING_MODULE_NAME', 'VAR_RAMPART_MODULE_NAME', 'VAR_HEADER_TO', 'VAR_HEADER_FROM', 'VAR_HEADER_FAULT', 'VAR_HEADER_ACTION', 'VAR_HEADER_REPLY_TO', 'VAR_HEADER_MESSAGE_ID', 'VAR_PROPERTY_MESSAGE_FORMAT', 'VAR_RAMPART_POLICY', 'VAR_SANDESHA_POLICY', 'VAR_SYNAPSE_CONFIG', 'VAR_SYNAPSE_ENV', 'VAR_SYNAPSE_HOME', 'VAR_DEFAULT_PROP_PATH', 'VAR_SYNAPSE_XML', 'VAR_SYNAPSE_PROPERTIES', 'VAR_PROXY_SERVICE', 'VAR_RESPONSE', 'VAR_OUT_ONLY', 'VAR_ERROR_CODE', 'VAR_ERROR_MESSAGE', 'VAR_ERROR_DETAIL', 'VAR_SANDESHA_LAST_MESSAGE', 'VAR_SANDESHA_SEQUENCE_KEY', 'VAR_SANDESHA_SPEC_VERSION', 'VAR_RELATES_TO_FOR_POX', 'VAR_ISRESPONSE_PROPERTY', 'VAR_TRACE_LOGGER', 'VAR_SERVICE_LOGGER_PREFIX', 'VAR_TRACING_OFF', 'VAR_TRACING_ON', 'VAR_TRACING_UNSET', 'VAR_STATISTICS_OFF', 'VAR_STATISTICS_ON', 'VAR_STATISTICS_UNSET', 'VAR_SEQUENCE_STATS', 'VAR_PROXY_STATS', 'VAR_SERVICE_STATS', 'VAR_ENDPOINT_STATS', 'VAR_SEQUENCE_STATISTICS', 'VAR_PROXYSERVICE_STATISTICS', 'VAR_ENDPOINT_STATISTICS', 'VAR_TIMEOUT_HANDLER_INTERVAL', 'VAR_DEFAULT_TIMEOUT_HANDLER_INTERVAL', 'VAR_GLOBAL_TIMEOUT_INTERVAL', 'VAR_DEFAULT_GLOBAL_TIMEOUT', 'VAR_NONE', 'VAR_DISCARD', 'VAR_DISCARD_AND_FAULT', 'VAR_TIME_OUT', 'VAR_SENDING_FAULT', 'VAR_PROCESSED_ENDPOINT', 'VAR_ANONYMOUS_ENDPOINT', 'VAR_ANONYMOUS_SEQUENCE', 'VAR_FORMAT_POX', 'VAR_FORMAT_SOAP11', 'VAR_FORMAT_SOAP12']

# %%
# Trích xuất token từ tất cả các file trong tập train và test
train_tokens = {file: extract_tokens_from_file(file) for file in train_files_new}
test_tokens = {file: extract_tokens_from_file(file) for file in filtered_test_files}
val_tokens = {file: extract_tokens_from_file(file) for file in val_files_new}
# Kiểm tra kết quả
print(f"Số file đã trích xuất token (train): {len(train_tokens)}")
print(f"Số file đã trích xuất token (validation): {len(val_tokens)}")
print(f"Số file đã trích xuất token (test): {len(test_tokens)}")
# Out:
# Số file đã trích xuất token (train): 225
# Số file đã trích xuất token (validation): 57
# Số file đã trích xuất token (test): 342

# %%
from google.colab import drive
import pickle
import os

# 🔹 1. Mount Google Drive
drive.mount('/content/drive')

# 🔹 2. Định nghĩa đường dẫn lưu file
save_dir = "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/"
save_path = os.path.join(save_dir, "dp_cnn_tokens.pkl")

# 🔹 3. Tạo thư mục nếu chưa tồn tại
os.makedirs(save_dir, exist_ok=True)

# 🔹 4. Lưu file vào thư mục trong Google Drive
data = {
    "train_tokens": train_tokens,
    "test_tokens": test_tokens,
    "val_tokens": val_tokens
}

with open(save_path, "wb") as f:
    pickle.dump(data, f)

print(f"✅ File đã được lưu tại: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ File đã được lưu tại: /content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/dp_cnn_tokens.pkl

# %% [markdown]
# # 3. Word embedding

# %% [markdown]
# - Làm bên folder khác: https://drive.google.com/file/d/13aXuvPECb4fUPLQEEVwSRNUCZQBukSur/view?usp=sharing
# - Token sau khi embedding được lưu vào trong file dp_cnn_embeddings.pkl có link: "/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/dp_cnn_embeddings.pkl"

# %%
import pickle
import numpy as np
from google.colab import drive
import os

drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Colab Notebooks/NLP/Task DP-CNN/dp_cnn_embeddings.pkl'


# Mở và đọc dữ liệu từ file .pkl
with open(file_path, 'rb') as f:
    data = pickle.load(f)

X_train = data['X_train_embeddings']
X_test = data['X_test_embeddings']
X_val = data['X_val_embeddings']

print(f"📌 Dữ liệu train shape: {X_train.shape}")
print(f"📌 Dữ liệu validation shape: {X_val.shape}")
print(f"📌 Dữ liệu test shape: {X_test.shape}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 📌 Dữ liệu train shape: (225, 100, 30)
# 📌 Dữ liệu validation shape: (57, 100, 30)
# 📌 Dữ liệu test shape: (342, 100, 30)

# %% [markdown]
# Kiểm tra lại nhãn

# %%
import numpy as np

# Chuyển nhãn thành NumPy array
y_train = np.array(balanced_train_df['bug'].values)  # 0 hoặc 1
y_val = np.array(balanced_val_df['bug'].values)  # 0 hoặc 1
y_test = np.array(balanced_test_df['bug'].values)  # 0 hoặc 1

print(f"📌 Nhãn train shape: {y_train.shape}")
print(f"📌 Nhãn val shape: {y_val.shape}")
print(f"📌 Nhãn test shape: {y_test.shape}")
# Out:
# 📌 Nhãn train shape: (225,)
# 📌 Nhãn val shape: (57,)
# 📌 Nhãn test shape: (342,)

# %% [markdown]
# # 4. Huấn luyện mạng CNN

# %% [markdown]
# - Huấn luyện CNN để trích xuất đặc trưng từ mã nguồn thông qua các vector word embedding (dạng chuỗi token).
# - Lấy các đặc trưng truyền thống từ file CSV
# - Ghép nối đặc trưng CNN và đặc trưng truyền thống để tổng hợp thông tin.
# - Dự đoán lỗi phần mềm bằng lớp Logistic Regression (lớp Dense cuối cùng với sigmoid).

# %% [markdown]
# ##Trích xuất các cột số từ CSV làm đầu vào bổ sung

# %%
X_train_traditional = np.array(balanced_train_df.iloc[:, 1:-1].values)  # Bỏ cột đầu tiên (name) và cuối cùng (bug)
X_test_traditional = np.array(balanced_test_df.iloc[:, 1:-1].values)
X_val_traditional = np.array(balanced_val_df.iloc[:, 1:-1].values)

print(f"📌 Traditional Features - Train shape: {X_train_traditional.shape}")
print(f"📌 Traditional Features - Validation shape: {X_val_traditional.shape}")
print(f"📌 Traditional Features - Test shape: {X_test_traditional.shape}")

print(X_train_traditional[1])
# Out:
# 📌 Traditional Features - Train shape: (225, 20)
# 📌 Traditional Features - Validation shape: (57, 20)
# 📌 Traditional Features - Test shape: (342, 20)
# [  3.           2.           0.           9.          22.
#    3.           0.           9.           3.           2.
#  119.           0.           0.           0.75         0.55555556
#    0.           0.          38.66666667   9.           3.3333    ]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_traditional = scaler.fit_transform(X_train_traditional)
X_val_traditional = scaler.transform(X_val_traditional)
X_test_traditional = scaler.transform(X_test_traditional)

# %%
## Định nghĩa cấu trúc mạng nơ ron và huấn luyện

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, Dense, Dropout, Input, Concatenate, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Định nghĩa siêu tham số tối ưu
FILTERS = 250
KERNEL_SIZE = 5
DENSE_UNITS = 100
DROPOUT_RATE = 0.1
LEARNING_RATE = 0.001
NUM_TRADITIONAL_FEATURES = X_train_traditional.shape[1]  # Số đặc trưng truyền thống
MAX_SEQUENCE_LENGTH = 100
EMBEDDING_DIM = 30

# Input từ CNN
input_layer_cnn = Input(shape=(MAX_SEQUENCE_LENGTH, EMBEDDING_DIM))  # (None, 100, 30)

# Các lớp Conv1D và MaxPooling
conv_layer_1 = Conv1D(filters=FILTERS, kernel_size=KERNEL_SIZE, activation='relu')(input_layer_cnn)
batch_norm_1 = BatchNormalization()(conv_layer_1)  # Batch Normalization
conv_layer_2 = Conv1D(filters=FILTERS, kernel_size=KERNEL_SIZE, activation='relu')(batch_norm_1)
batch_norm_2 = BatchNormalization()(conv_layer_2)  # Batch Normalization
pool_layer = GlobalMaxPooling1D()(batch_norm_2)

# Thêm lớp Dense và Dropout
dense_layer = Dense(DENSE_UNITS, activation='relu')(pool_layer)
dropout_layer = Dropout(DROPOUT_RATE)(dense_layer)

# Lấy Traditional Features và concatenate với đầu ra của mạng CNN
input_layer_traditional = Input(shape=(NUM_TRADITIONAL_FEATURES,))
merged_features = Concatenate()([dropout_layer, input_layer_traditional])

# Đưa qua lớp dense
dense_2_layer = Dense(DENSE_UNITS, activation='relu', kernel_regularizer=l2(0.01))(merged_features)

# Lớp Logistic Regression (Dự đoán lỗi phần mềm)
output_layer = Dense(1, activation='sigmoid')(dense_2_layer)

# Tạo mô hình tổng hợp
model = Model(inputs=[input_layer_cnn, input_layer_traditional], outputs=output_layer)

# Compile mô hình với learning rate thấp hơn
optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Sử dụng ReduceLROnPlateau callback để điều chỉnh learning rate khi cần thiết
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=0.00001)

# Hiển thị kiến trúc mô hình
model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12            │ (None, 100, 30)        │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_10 (Conv1D)        │ (None, 96, 250)        │         37,750 │ input_layer_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 96, 250)        │          1,000 │ conv1d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_11 (Conv1D)        │ (None, 92, 250)        │        312,750 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 92, 250)        │          1,000 │ conv1d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling1d_6    │ (None, 250)            │              0 │ batch_normalization_9… │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 100)            │         25,100 │ global_max_pooling1d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 100)            │              0 │ dense_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_13            │ (None, 20)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 120)            │              0 │ dropout_6[0][0],       │
# │ (Concatenate)             │                        │                │ input_layer_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 100)            │         12,100 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 1)              │            101 │ dense_17[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 389,801 (1.49 MB)
#  Trainable params: 388,801 (1.48 MB)
#  Non-trainable params: 1,000 (3.91 KB)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report

# 🔹 Số epochs để huấn luyện
epochs = 50
history_dict = {}

# 🔹 Tạo callback để in kết quả sau mỗi epoch
class MetricsCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        # Dự đoán trên tập test ngay sau epoch hiện tại
        y_pred = (self.model.predict([X_test, X_test_traditional]) > 0.5).astype("int32")

        # Tính Classification Report đúng cách
        report = classification_report(y_test, y_pred, output_dict=True)

        # Lưu lịch sử từng epoch
        history_dict[epoch + 1] = {
            "accuracy": logs["accuracy"],
            "val_accuracy": logs["val_accuracy"],
            "loss": logs["loss"],
            "val_loss": logs["val_loss"],
            "precision": report["1"]["precision"] if "1" in report else 0,
            "recall": report["1"]["recall"] if "1" in report else 0,
            "f1-score": report["1"]["f1-score"] if "1" in report else 0
        }

        # 🔥 In kết quả sau mỗi epoch
        print(f"\n📌 Epoch {epoch + 1}/{epochs} - "
              f"Accuracy: {logs['accuracy']:.4f}, "
              f"Loss: {logs['loss']:.4f}, "
              f"Val Accuracy: {logs['val_accuracy']:.4f}, "
              f"Val Loss: {logs['val_loss']:.4f}, "
              f"Precision: {history_dict[epoch + 1]['precision']:.4f}, "
              f"Recall: {history_dict[epoch + 1]['recall']:.4f}, "
              f"F1-score: {history_dict[epoch + 1]['f1-score']:.4f}")

# 🔹 Huấn luyện mô hình với callback tùy chỉnh
history = model.fit(
    [X_train, X_train_traditional], y_train,
    validation_data=([X_val, X_val_traditional], y_val),
    epochs=epochs, batch_size=16, verbose=0,
    callbacks=[MetricsCallback()]
)

# 🔹 In toàn bộ lịch sử sau khi huấn luyện xong
print("\n📊 History Dict:")
print(history_dict)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# 📌 Epoch 1/50 - Accuracy: 0.8533, Loss: 0.2388, Val Accuracy: 0.7193, Val Loss: 0.6210, Precision: 0.8319, Recall: 0.5756, F1-score: 0.6804
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# 📌 Epoch 2/50 - Accuracy: 0.8400, Loss: 0.2398, Val Accuracy: 0.6667, Val Loss: 0.7370, Precision: 0.8958, Recall: 0.5000, F1-score: 0.6418
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# 📌 Epoch 3/50 - Accuracy: 0.8844, Loss: 0.2250, Val Accuracy: 0.6842, Val Loss: 0.8855, Precision: 0.9176, Recall: 0.4535, F1-score: 0.6070
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# 📌 Epoch 4/50 - Accuracy: 0.8667, Loss: 0.2234, Val Accuracy: 0.7018, Val Loss: 0.5929, Precision: 0.7820, Recall: 0.6047, F1-score: 0.6820
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# 📌 Epoch 5/50 - Accuracy: 0.8756, Loss: 0.2140, Val Accuracy: 0.6667, Val Loss: 0.8523, Precision: 0.9444, Recall: 0.4942, F1-score: 0.6489
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# 📌 Epoch 6/50 - Accuracy: 0.8578, Loss: 0.2113, Val Accuracy: 0.7193, Val Loss: 0.6728, Precision: 0.8235, Recall: 0.5698, F1-score: 0.6735
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# 📌 Epoch 7/50 - Accuracy: 0.9067, Loss: 0.1948, Val Accuracy: 0.7018, Val Loss: 0.8177, Precision: 0.9062, Recall: 0.5058, F1-score: 0.6493
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 8/50 - Accuracy: 0.9022, Loss: 0.1901, Val Accuracy: 0.7368, Val Loss: 0.7012, Precision: 0.8421, Recall: 0.5581, F1-score: 0.6713
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 9/50 - Accuracy: 0.8933, Loss: 0.1902, Val Accuracy: 0.7018, Val Loss: 0.8322, Precision: 0.8900, Recall: 0.5174, F1-score: 0.6544
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 10/50 - Accuracy: 0.8933, Loss: 0.1969, Val Accuracy: 0.7018, Val Loss: 0.7896, Precision: 0.8558, Recall: 0.5174, F1-score: 0.6449
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 11/50 - Accuracy: 0.8889, Loss: 0.1909, Val Accuracy: 0.7018, Val Loss: 0.7369, Precision: 0.8482, Recall: 0.5523, F1-score: 0.6690
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 12/50 - Accuracy: 0.9022, Loss: 0.1775, Val Accuracy: 0.7018, Val Loss: 0.7458, Precision: 0.8624, Recall: 0.5465, F1-score: 0.6690
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 13/50 - Accuracy: 0.8889, Loss: 0.2167, Val Accuracy: 0.7368, Val Loss: 0.7311, Precision: 0.8636, Recall: 0.5523, F1-score: 0.6738
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 14/50 - Accuracy: 0.9156, Loss: 0.1851, Val Accuracy: 0.7368, Val Loss: 0.7622, Precision: 0.8942, Recall: 0.5407, F1-score: 0.6739
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 15/50 - Accuracy: 0.9422, Loss: 0.1770, Val Accuracy: 0.7368, Val Loss: 0.7597, Precision: 0.8857, Recall: 0.5407, F1-score: 0.6715
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 16/50 - Accuracy: 0.9200, Loss: 0.1826, Val Accuracy: 0.7368, Val Loss: 0.8012, Precision: 0.8846, Recall: 0.5349, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 17/50 - Accuracy: 0.9333, Loss: 0.1688, Val Accuracy: 0.7368, Val Loss: 0.8373, Precision: 0.9010, Recall: 0.5291, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 18/50 - Accuracy: 0.8978, Loss: 0.1977, Val Accuracy: 0.7193, Val Loss: 0.7148, Precision: 0.8435, Recall: 0.5640, F1-score: 0.6760
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 19/50 - Accuracy: 0.9200, Loss: 0.1664, Val Accuracy: 0.7368, Val Loss: 0.8808, Precision: 0.9082, Recall: 0.5174, F1-score: 0.6593
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 20/50 - Accuracy: 0.9244, Loss: 0.1689, Val Accuracy: 0.7368, Val Loss: 0.8491, Precision: 0.8835, Recall: 0.5291, F1-score: 0.6618
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 21/50 - Accuracy: 0.9422, Loss: 0.1610, Val Accuracy: 0.7368, Val Loss: 0.8487, Precision: 0.8942, Recall: 0.5407, F1-score: 0.6739
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 22/50 - Accuracy: 0.9289, Loss: 0.1571, Val Accuracy: 0.7193, Val Loss: 0.8901, Precision: 0.9000, Recall: 0.5233, F1-score: 0.6618
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 23/50 - Accuracy: 0.9156, Loss: 0.1665, Val Accuracy: 0.7018, Val Loss: 0.9674, Precision: 0.8911, Recall: 0.5233, F1-score: 0.6593
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 24/50 - Accuracy: 0.9244, Loss: 0.1625, Val Accuracy: 0.7018, Val Loss: 1.0059, Precision: 0.9000, Recall: 0.5233, F1-score: 0.6618
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 25/50 - Accuracy: 0.9111, Loss: 0.1750, Val Accuracy: 0.7018, Val Loss: 0.9491, Precision: 0.8911, Recall: 0.5233, F1-score: 0.6593
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 26/50 - Accuracy: 0.9378, Loss: 0.1614, Val Accuracy: 0.7193, Val Loss: 0.7810, Precision: 0.8435, Recall: 0.5640, F1-score: 0.6760
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 27/50 - Accuracy: 0.9333, Loss: 0.1642, Val Accuracy: 0.7193, Val Loss: 0.8786, Precision: 0.8692, Recall: 0.5407, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 28/50 - Accuracy: 0.9600, Loss: 0.1497, Val Accuracy: 0.7193, Val Loss: 0.8904, Precision: 0.8692, Recall: 0.5407, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 29/50 - Accuracy: 0.9467, Loss: 0.1466, Val Accuracy: 0.7193, Val Loss: 0.9051, Precision: 0.8611, Recall: 0.5407, F1-score: 0.6643
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 30/50 - Accuracy: 0.9422, Loss: 0.1459, Val Accuracy: 0.7018, Val Loss: 0.9796, Precision: 0.9010, Recall: 0.5291, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 31/50 - Accuracy: 0.9511, Loss: 0.1474, Val Accuracy: 0.7193, Val Loss: 0.9255, Precision: 0.8704, Recall: 0.5465, F1-score: 0.6714
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 32/50 - Accuracy: 0.9467, Loss: 0.1463, Val Accuracy: 0.7193, Val Loss: 0.9571, Precision: 0.8868, Recall: 0.5465, F1-score: 0.6763
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 33/50 - Accuracy: 0.9511, Loss: 0.1442, Val Accuracy: 0.7018, Val Loss: 0.9252, Precision: 0.8796, Recall: 0.5523, F1-score: 0.6786
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 34/50 - Accuracy: 0.9378, Loss: 0.1472, Val Accuracy: 0.7193, Val Loss: 0.9376, Precision: 0.8952, Recall: 0.5465, F1-score: 0.6787
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 35/50 - Accuracy: 0.9200, Loss: 0.1691, Val Accuracy: 0.7018, Val Loss: 1.0257, Precision: 0.9184, Recall: 0.5233, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 36/50 - Accuracy: 0.9378, Loss: 0.1508, Val Accuracy: 0.7368, Val Loss: 0.7967, Precision: 0.8376, Recall: 0.5698, F1-score: 0.6782
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 37/50 - Accuracy: 0.9022, Loss: 0.1758, Val Accuracy: 0.7544, Val Loss: 0.7132, Precision: 0.7984, Recall: 0.5988, F1-score: 0.6844
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 38/50 - Accuracy: 0.9244, Loss: 0.1658, Val Accuracy: 0.7368, Val Loss: 0.9012, Precision: 0.8649, Recall: 0.5581, F1-score: 0.6784
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 📌 Epoch 39/50 - Accuracy: 0.9467, Loss: 0.1467, Val Accuracy: 0.7368, Val Loss: 0.9596, Precision: 0.8879, Recall: 0.5523, F1-score: 0.6810
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 40/50 - Accuracy: 0.9378, Loss: 0.1519, Val Accuracy: 0.7368, Val Loss: 1.0624, Precision: 0.9192, Recall: 0.5291, F1-score: 0.6716
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 41/50 - Accuracy: 0.9200, Loss: 0.1643, Val Accuracy: 0.7018, Val Loss: 1.1719, Precision: 0.9348, Recall: 0.5000, F1-score: 0.6515
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 42/50 - Accuracy: 0.9378, Loss: 0.1468, Val Accuracy: 0.7018, Val Loss: 0.9679, Precision: 0.8774, Recall: 0.5407, F1-score: 0.6691
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 43/50 - Accuracy: 0.9511, Loss: 0.1385, Val Accuracy: 0.7193, Val Loss: 0.9327, Precision: 0.8692, Recall: 0.5407, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 44/50 - Accuracy: 0.9511, Loss: 0.1336, Val Accuracy: 0.7193, Val Loss: 0.9837, Precision: 0.8692, Recall: 0.5407, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 45/50 - Accuracy: 0.9556, Loss: 0.1353, Val Accuracy: 0.7193, Val Loss: 1.0128, Precision: 0.8774, Recall: 0.5407, F1-score: 0.6691
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 46/50 - Accuracy: 0.9511, Loss: 0.1360, Val Accuracy: 0.7193, Val Loss: 1.0301, Precision: 0.8704, Recall: 0.5465, F1-score: 0.6714
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 47/50 - Accuracy: 0.9511, Loss: 0.1302, Val Accuracy: 0.7193, Val Loss: 1.1031, Precision: 0.8774, Recall: 0.5407, F1-score: 0.6691
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 48/50 - Accuracy: 0.9556, Loss: 0.1313, Val Accuracy: 0.7193, Val Loss: 1.1088, Precision: 0.8774, Recall: 0.5407, F1-score: 0.6691
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 49/50 - Accuracy: 0.9333, Loss: 0.1307, Val Accuracy: 0.7018, Val Loss: 1.0940, Precision: 0.8774, Recall: 0.5407, F1-score: 0.6691
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 50/50 - Accuracy: 0.9333, Loss: 0.1330, Val Accuracy: 0.7193, Val Loss: 1.0675, Precision: 0.8704, Recall: 0.5465, F1-score: 0.6714
#
# 📊 History Dict:
# {1: {'accuracy': 0.8533333539962769, 'val_accuracy': 0.719298243522644, 'loss': 0.23883748054504395, 'val_loss': 0.621049702167511, 'precision': 0.8319327731092437, 'recall': 0.5755813953488372, 'f1-score': 0.6804123711340206}, 2: {'accuracy': 0.8399999737739563, 'val_accuracy': 0.6666666865348816, 'loss': 0.2398488074541092, 'val_loss': 0.736975371837616, 'precision': 0.8958333333333334, 'recall': 0.5, 'f1-score': 0.6417910447761194}, 3: {'accuracy': 0.8844444155693054, 'val_accuracy': 0.6842105388641357, 'loss': 0.22496984899044037, 'val_loss': 0.8855060935020447, 'precision': 0.9176470588235294, 'recall': 0.45348837209302323, 'f1-score': 0.6070038910505836}, 4: {'accuracy': 0.8666666746139526, 'val_accuracy': 0.7017543911933899, 'loss': 0.22339417040348053, 'val_loss': 0.5928769111633301, 'precision': 0.7819548872180451, 'recall': 0.6046511627906976, 'f1-score': 0.6819672131147541}, 5: {'accuracy': 0.8755555748939514, 'val_accuracy': 0.6666666865348816, 'loss': 0.2140352576971054, 'val_loss': 0.8522783517837524, 'precision': 0.9444444444444444, 'recall': 0.4941860465116279, 'f1-score': 0.648854961832061}, 6: {'accuracy': 0.8577777743339539, 'val_accuracy': 0.719298243522644, 'loss': 0.21131965517997742, 'val_loss': 0.6728363633155823, 'precision': 0.8235294117647058, 'recall': 0.5697674418604651, 'f1-score': 0.6735395189003437}, 7: {'accuracy': 0.9066666960716248, 'val_accuracy': 0.7017543911933899, 'loss': 0.1948186308145523, 'val_loss': 0.817669689655304, 'precision': 0.90625, 'recall': 0.5058139534883721, 'f1-score': 0.6492537313432836}, 8: {'accuracy': 0.902222216129303, 'val_accuracy': 0.7368420958518982, 'loss': 0.19007200002670288, 'val_loss': 0.7011653780937195, 'precision': 0.8421052631578947, 'recall': 0.5581395348837209, 'f1-score': 0.6713286713286714}, 9: {'accuracy': 0.8933333158493042, 'val_accuracy': 0.7017543911933899, 'loss': 0.19021183252334595, 'val_loss': 0.8322092890739441, 'precision': 0.89, 'recall': 0.5174418604651163, 'f1-score': 0.6544117647058824}, 10: {'accuracy': 0.8933333158493042, 'val_accuracy': 0.7017543911933899, 'loss': 0.1969035118818283, 'val_loss': 0.7896490097045898, 'precision': 0.8557692307692307, 'recall': 0.5174418604651163, 'f1-score': 0.644927536231884}, 11: {'accuracy': 0.8888888955116272, 'val_accuracy': 0.7017543911933899, 'loss': 0.1908649504184723, 'val_loss': 0.7368932962417603, 'precision': 0.8482142857142857, 'recall': 0.5523255813953488, 'f1-score': 0.6690140845070423}, 12: {'accuracy': 0.902222216129303, 'val_accuracy': 0.7017543911933899, 'loss': 0.17745418846607208, 'val_loss': 0.7457873821258545, 'precision': 0.8623853211009175, 'recall': 0.5465116279069767, 'f1-score': 0.6690391459074733}, 13: {'accuracy': 0.8888888955116272, 'val_accuracy': 0.7368420958518982, 'loss': 0.2166704535484314, 'val_loss': 0.7311499118804932, 'precision': 0.8636363636363636, 'recall': 0.5523255813953488, 'f1-score': 0.6737588652482269}, 14: {'accuracy': 0.9155555367469788, 'val_accuracy': 0.7368420958518982, 'loss': 0.18513734638690948, 'val_loss': 0.7621939182281494, 'precision': 0.8942307692307693, 'recall': 0.5406976744186046, 'f1-score': 0.6739130434782609}, 15: {'accuracy': 0.9422222375869751, 'val_accuracy': 0.7368420958518982, 'loss': 0.17695997655391693, 'val_loss': 0.7596830129623413, 'precision': 0.8857142857142857, 'recall': 0.5406976744186046, 'f1-score': 0.6714801444043321}, 16: {'accuracy': 0.9200000166893005, 'val_accuracy': 0.7368420958518982, 'loss': 0.18260705471038818, 'val_loss': 0.8012062311172485, 'precision': 0.8846153846153846, 'recall': 0.5348837209302325, 'f1-score': 0.6666666666666666}, 17: {'accuracy': 0.9333333373069763, 'val_accuracy': 0.7368420958518982, 'loss': 0.16876822710037231, 'val_loss': 0.8373243808746338, 'precision': 0.900990099009901, 'recall': 0.5290697674418605, 'f1-score': 0.6666666666666666}, 18: {'accuracy': 0.897777795791626, 'val_accuracy': 0.719298243522644, 'loss': 0.1977066695690155, 'val_loss': 0.7148034572601318, 'precision': 0.8434782 ...

# %%
y_pred_prob = model.predict([X_test, X_test_traditional])
print(y_pred_prob[:30])  # In 10 giá trị dự đoán ban đầu để kiểm tra
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# [[0.02968292]
#  [0.10781024]
#  [0.26816964]
#  [0.49145943]
#  [0.5475235 ]
#  [0.3650667 ]
#  [0.7709476 ]
#  [0.96430343]
#  [0.17926414]
#  [0.16633734]
#  [0.4808456 ]
#  [0.165828  ]
#  [0.2117308 ]
#  [0.10058428]
#  [0.09764291]
#  [0.7972324 ]
#  [0.11557826]
#  [0.2553861 ]
#  [0.3291525 ]
#  [0.16368392]
#  [0.47305346]
#  [0.9379367 ]
#  [0.24554455]
#  [0.14608215]
#  [0.5142643 ]
#  [0.10389743]
#  [0.15605004]
#  [0.22849849]
#  [0.02653369]
#  [0.3910154 ]]

# %%
import matplotlib.pyplot as plt

# Kiểm tra và trích xuất dữ liệu từ history_dict
epochs_values = list(history_dict.keys())

train_acc = [history_dict[ep].get("accuracy", None) for ep in epochs_values]
val_acc = [history_dict[ep].get("val_accuracy", None) for ep in epochs_values]
train_loss = [history_dict[ep].get("loss", None) for ep in epochs_values]
val_loss = [history_dict[ep].get("val_loss", None) for ep in epochs_values]
precision = [history_dict[ep].get("precision", None) for ep in epochs_values]
recall = [history_dict[ep].get("recall", None) for ep in epochs_values]
f1_score = [history_dict[ep].get("f1-score", None) for ep in epochs_values]

# Tạo biểu đồ
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 🔹 1. Vẽ biểu đồ Accuracy
axes[0, 0].plot(epochs_values, train_acc, marker='o', label="Train Accuracy", color='b')
axes[0, 0].plot(epochs_values, val_acc, marker='s', label="Validation Accuracy", color='g')
axes[0, 0].set_xlabel("Epochs")
axes[0, 0].set_ylabel("Accuracy")
axes[0, 0].set_title("Train & Validation Accuracy vs. Epochs")
axes[0, 0].legend()
axes[0, 0].grid()

# 🔹 2. Vẽ biểu đồ Loss
axes[0, 1].plot(epochs_values, train_loss, marker='o', label="Train Loss", color='r')
axes[0, 1].plot(epochs_values, val_loss, marker='s', label="Validation Loss", color='purple')
axes[0, 1].set_xlabel("Epochs")
axes[0, 1].set_ylabel("Loss")
axes[0, 1].set_title("Train & Validation Loss vs. Epochs")
axes[0, 1].legend()
axes[0, 1].grid()

# 🔹 3. Vẽ biểu đồ Precision, Recall, F1-score
axes[1, 0].plot(epochs_values, precision, marker='o', label="Precision", color='orange')
axes[1, 0].plot(epochs_values, recall, marker='s', label="Recall", color='brown')
axes[1, 0].plot(epochs_values, f1_score, marker='^', label="F1-Score", color='cyan')
axes[1, 0].set_xlabel("Epochs")
axes[1, 0].set_ylabel("Score")
axes[1, 0].set_title("Precision, Recall & F1-Score vs. Epochs")
axes[1, 0].legend()
axes[1, 0].grid()

# Ẩn ô trống (nếu có)
axes[1, 1].axis("off")

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report

# 🔹 1. Dự đoán trên tập test
y_pred = (model.predict([X_test, X_test_traditional]) > 0.5).astype("int32")

# 🔹 2. In báo cáo kết quả
print(classification_report(y_test, y_pred))
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
#               precision    recall  f1-score   support
#
#            0       0.62      0.84      0.71       170
#            1       0.76      0.49      0.60       172
#
#     accuracy                           0.67       342
#    macro avg       0.69      0.67      0.66       342
# weighted avg       0.69      0.67      0.66       342

# %% [markdown]
# # Đánh giá mô hình

# %%
import matplotlib.pyplot as plt

# Trích xuất dữ liệu từ history_dict
epochs_values = list(history_dict.keys())
accuracy = [history_dict[ep]["accuracy"] for ep in epochs_values]
precision = [history_dict[ep]["precision"] for ep in epochs_values]
recall = [history_dict[ep]["recall"] for ep in epochs_values]
f1_score = [history_dict[ep]["f1-score"] for ep in epochs_values]

# 🔹 Vẽ biểu đồ
plt.figure(figsize=(12, 6))

plt.plot(epochs_values, accuracy, marker='o', linestyle='--', label="Accuracy")
plt.plot(epochs_values, precision, marker='s', label="Precision")
plt.plot(epochs_values, recall, marker='^', label="Recall")
plt.plot(epochs_values, f1_score, marker='d', label="F1-score")

plt.xlabel("Epochs")
plt.ylabel("Score")
plt.title("So sánh Accuracy, Precision, Recall, F1-score theo số Epochs")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ## Làm theo bài báo

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Chuyển danh sách tokens về dạng chuỗi văn bản (vì Tokenizer cần chuỗi)
train_texts = [" ".join(tokens) for tokens in train_tokens.values()]
val_texts = [" ".join(tokens) for tokens in val_tokens.values()]
test_texts = [" ".join(tokens) for tokens in test_tokens.values()]

# Tạo Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_texts)

# Số lượng từ (Vocabulary size)
vocab_size = len(tokenizer.word_index) + 1  # +1 để dành cho padding

# Mã hóa thành số
X_train_seq = tokenizer.texts_to_sequences(train_texts)
X_val_seq = tokenizer.texts_to_sequences(val_texts)
X_test_seq = tokenizer.texts_to_sequences(test_texts)

# Padding để tất cả có độ dài MAX_SEQUENCE_LENGTH
X_train = pad_sequences(X_train_seq, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
X_val = pad_sequences(X_val_seq, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
X_test = pad_sequences(X_test_seq, maxlen=MAX_SEQUENCE_LENGTH, padding='post')

# %%
from tensorflow.keras.layers import Embedding

# Input là chuỗi số nguyên
input_layer_cnn = Input(shape=(MAX_SEQUENCE_LENGTH,))  # (None, 100)

# Embedding layer
embedding_layer = Embedding(input_dim=vocab_size, output_dim=EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH)(input_layer_cnn)

# CNN
conv_layer_1 = Conv1D(filters=FILTERS, kernel_size=KERNEL_SIZE, activation='relu')(embedding_layer)
batch_norm_1 = BatchNormalization()(conv_layer_1)
conv_layer_2 = Conv1D(filters=FILTERS, kernel_size=KERNEL_SIZE, activation='relu')(batch_norm_1)
batch_norm_2 = BatchNormalization()(conv_layer_2)
pool_layer = GlobalMaxPooling1D()(batch_norm_2)
dense_layer = Dense(DENSE_UNITS, activation='relu')(pool_layer)
dropout_layer = Dropout(DROPOUT_RATE)(dense_layer)

# Truyền thống + CNN
input_layer_traditional = Input(shape=(NUM_TRADITIONAL_FEATURES,))
merged_features = Concatenate()([dropout_layer, input_layer_traditional])
dense_2_layer = Dense(DENSE_UNITS, activation='relu', kernel_regularizer=l2(0.01))(merged_features)
output_layer = Dense(1, activation='sigmoid')(dense_2_layer)

# Model
model = Model(inputs=[input_layer_cnn, input_layer_traditional], outputs=output_layer)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report

# 🔹 Số epochs để huấn luyện
epochs = 50
history_dict = {}

# 🔹 Tạo callback để in kết quả sau mỗi epoch
class MetricsCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        # Dự đoán trên tập test ngay sau epoch hiện tại
        y_pred = (self.model.predict([X_test, X_test_traditional]) > 0.5).astype("int32")

        # Tính Classification Report đúng cách
        report = classification_report(y_test, y_pred, output_dict=True)

        # Lưu lịch sử từng epoch
        history_dict[epoch + 1] = {
            "accuracy": logs["accuracy"],
            "val_accuracy": logs["val_accuracy"],
            "loss": logs["loss"],
            "val_loss": logs["val_loss"],
            "precision": report["1"]["precision"] if "1" in report else 0,
            "recall": report["1"]["recall"] if "1" in report else 0,
            "f1-score": report["1"]["f1-score"] if "1" in report else 0
        }

        # 🔥 In kết quả sau mỗi epoch
        print(f"\n📌 Epoch {epoch + 1}/{epochs} - "
              f"Accuracy: {logs['accuracy']:.4f}, "
              f"Loss: {logs['loss']:.4f}, "
              f"Val Accuracy: {logs['val_accuracy']:.4f}, "
              f"Val Loss: {logs['val_loss']:.4f}, "
              f"Precision: {history_dict[epoch + 1]['precision']:.4f}, "
              f"Recall: {history_dict[epoch + 1]['recall']:.4f}, "
              f"F1-score: {history_dict[epoch + 1]['f1-score']:.4f}")

# 🔹 Huấn luyện mô hình với callback tùy chỉnh
history = model.fit(
    [X_train, X_train_traditional], y_train,
    validation_data=([X_val, X_val_traditional], y_val),
    epochs=epochs, batch_size=32, verbose=0,
    callbacks=[MetricsCallback()]
)

# 🔹 In toàn bộ lịch sử sau khi huấn luyện xong
print("\n📊 History Dict:")
print(history_dict)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 1/50 - Accuracy: 0.9333, Loss: 0.1579, Val Accuracy: 0.7018, Val Loss: 0.8381, Precision: 0.9126, Recall: 0.5465, F1-score: 0.6836
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# 📌 Epoch 2/50 - Accuracy: 0.9022, Loss: 0.1731, Val Accuracy: 0.7193, Val Loss: 1.0372, Precision: 0.9759, Recall: 0.4709, F1-score: 0.6353
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# 📌 Epoch 3/50 - Accuracy: 0.9156, Loss: 0.1869, Val Accuracy: 0.7018, Val Loss: 0.8943, Precision: 0.8911, Recall: 0.5233, F1-score: 0.6593
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# 📌 Epoch 4/50 - Accuracy: 0.9244, Loss: 0.1738, Val Accuracy: 0.7018, Val Loss: 0.7915, Precision: 0.8475, Recall: 0.5814, F1-score: 0.6897
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# 📌 Epoch 5/50 - Accuracy: 0.9244, Loss: 0.1733, Val Accuracy: 0.6842, Val Loss: 0.7981, Precision: 0.8522, Recall: 0.5698, F1-score: 0.6829
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 6/50 - Accuracy: 0.9289, Loss: 0.1628, Val Accuracy: 0.7193, Val Loss: 0.8473, Precision: 0.8922, Recall: 0.5291, F1-score: 0.6642
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 7/50 - Accuracy: 0.9244, Loss: 0.1632, Val Accuracy: 0.7193, Val Loss: 0.8265, Precision: 0.8796, Recall: 0.5523, F1-score: 0.6786
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 8/50 - Accuracy: 0.9200, Loss: 0.1650, Val Accuracy: 0.7193, Val Loss: 0.7212, Precision: 0.8000, Recall: 0.5814, F1-score: 0.6734
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 📌 Epoch 9/50 - Accuracy: 0.9156, Loss: 0.1659, Val Accuracy: 0.7193, Val Loss: 0.7790, Precision: 0.8684, Recall: 0.5756, F1-score: 0.6923
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# 📌 Epoch 10/50 - Accuracy: 0.9244, Loss: 0.1709, Val Accuracy: 0.6842, Val Loss: 0.8980, Precision: 0.9271, Recall: 0.5174, F1-score: 0.6642
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 11/50 - Accuracy: 0.9200, Loss: 0.1670, Val Accuracy: 0.7368, Val Loss: 0.8340, Precision: 0.9100, Recall: 0.5291, F1-score: 0.6691
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 12/50 - Accuracy: 0.9333, Loss: 0.1602, Val Accuracy: 0.7018, Val Loss: 0.7897, Precision: 0.8796, Recall: 0.5523, F1-score: 0.6786
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 13/50 - Accuracy: 0.9156, Loss: 0.1659, Val Accuracy: 0.7719, Val Loss: 0.8228, Precision: 0.8932, Recall: 0.5349, F1-score: 0.6691
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 14/50 - Accuracy: 0.9156, Loss: 0.1645, Val Accuracy: 0.7018, Val Loss: 0.7932, Precision: 0.8889, Recall: 0.5581, F1-score: 0.6857
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 15/50 - Accuracy: 0.9244, Loss: 0.1574, Val Accuracy: 0.7018, Val Loss: 0.7962, Precision: 0.8739, Recall: 0.5640, F1-score: 0.6855
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 16/50 - Accuracy: 0.9333, Loss: 0.1533, Val Accuracy: 0.7018, Val Loss: 0.7831, Precision: 0.8684, Recall: 0.5756, F1-score: 0.6923
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 17/50 - Accuracy: 0.9289, Loss: 0.1506, Val Accuracy: 0.7018, Val Loss: 0.7988, Precision: 0.8673, Recall: 0.5698, F1-score: 0.6877
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 18/50 - Accuracy: 0.9333, Loss: 0.1537, Val Accuracy: 0.7193, Val Loss: 0.8351, Precision: 0.8889, Recall: 0.5581, F1-score: 0.6857
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 19/50 - Accuracy: 0.9244, Loss: 0.1478, Val Accuracy: 0.7193, Val Loss: 0.8438, Precision: 0.8796, Recall: 0.5523, F1-score: 0.6786
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 20/50 - Accuracy: 0.9289, Loss: 0.1566, Val Accuracy: 0.7018, Val Loss: 0.8023, Precision: 0.8673, Recall: 0.5698, F1-score: 0.6877
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 21/50 - Accuracy: 0.9289, Loss: 0.1718, Val Accuracy: 0.7544, Val Loss: 0.9507, Precision: 0.9451, Recall: 0.5000, F1-score: 0.6540
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# 📌 Epoch 22/50 - Accuracy: 0.9289, Loss: 0.1744, Val Accuracy: 0.7193, Val Loss: 0.8641, Precision: 0.9010, Recall: 0.5291, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 23/50 - Accuracy: 0.9333, Loss: 0.1586, Val Accuracy: 0.6842, Val Loss: 0.7936, Precision: 0.8673, Recall: 0.5698, F1-score: 0.6877
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 24/50 - Accuracy: 0.9333, Loss: 0.1525, Val Accuracy: 0.7018, Val Loss: 0.7858, Precision: 0.8559, Recall: 0.5872, F1-score: 0.6966
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 25/50 - Accuracy: 0.9333, Loss: 0.1535, Val Accuracy: 0.7018, Val Loss: 0.7879, Precision: 0.8547, Recall: 0.5814, F1-score: 0.6920
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 26/50 - Accuracy: 0.9378, Loss: 0.1473, Val Accuracy: 0.7193, Val Loss: 0.8090, Precision: 0.8522, Recall: 0.5698, F1-score: 0.6829
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 27/50 - Accuracy: 0.9333, Loss: 0.1490, Val Accuracy: 0.7193, Val Loss: 0.8217, Precision: 0.8522, Recall: 0.5698, F1-score: 0.6829
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 28/50 - Accuracy: 0.9289, Loss: 0.1476, Val Accuracy: 0.7193, Val Loss: 0.8472, Precision: 0.9048, Recall: 0.5523, F1-score: 0.6859
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 29/50 - Accuracy: 0.9333, Loss: 0.1424, Val Accuracy: 0.7193, Val Loss: 0.8440, Precision: 0.8649, Recall: 0.5581, F1-score: 0.6784
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 30/50 - Accuracy: 0.9378, Loss: 0.1430, Val Accuracy: 0.7193, Val Loss: 0.8190, Precision: 0.8319, Recall: 0.5756, F1-score: 0.6804
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 31/50 - Accuracy: 0.9200, Loss: 0.1594, Val Accuracy: 0.7368, Val Loss: 0.7443, Precision: 0.7929, Recall: 0.6453, F1-score: 0.7115
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 32/50 - Accuracy: 0.9244, Loss: 0.1682, Val Accuracy: 0.7193, Val Loss: 0.8631, Precision: 0.8509, Recall: 0.5640, F1-score: 0.6783
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 33/50 - Accuracy: 0.9333, Loss: 0.1593, Val Accuracy: 0.7368, Val Loss: 0.9349, Precision: 0.9010, Recall: 0.5291, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 34/50 - Accuracy: 0.9333, Loss: 0.1521, Val Accuracy: 0.7018, Val Loss: 0.8392, Precision: 0.8421, Recall: 0.5581, F1-score: 0.6713
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 35/50 - Accuracy: 0.9378, Loss: 0.1553, Val Accuracy: 0.7368, Val Loss: 0.7276, Precision: 0.7730, Recall: 0.6337, F1-score: 0.6965
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 36/50 - Accuracy: 0.9200, Loss: 0.1787, Val Accuracy: 0.7193, Val Loss: 0.7545, Precision: 0.7868, Recall: 0.6221, F1-score: 0.6948
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 37/50 - Accuracy: 0.9378, Loss: 0.1574, Val Accuracy: 0.7193, Val Loss: 0.8416, Precision: 0.8807, Recall: 0.5581, F1-score: 0.6833
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 38/50 - Accuracy: 0.9111, Loss: 0.1560, Val Accuracy: 0.7193, Val Loss: 0.8641, Precision: 0.8972, Recall: 0.5581, F1-score: 0.6882
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 39/50 - Accuracy: 0.9244, Loss: 0.1510, Val Accuracy: 0.7193, Val Loss: 0.8201, Precision: 0.8621, Recall: 0.5814, F1-score: 0.6944
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 40/50 - Accuracy: 0.9333, Loss: 0.1483, Val Accuracy: 0.7193, Val Loss: 0.7905, Precision: 0.8387, Recall: 0.6047, F1-score: 0.7027
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 41/50 - Accuracy: 0.9378, Loss: 0.1475, Val Accuracy: 0.7368, Val Loss: 0.7861, Precision: 0.8189, Recall: 0.6047, F1-score: 0.6957
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 42/50 - Accuracy: 0.9244, Loss: 0.1503, Val Accuracy: 0.7368, Val Loss: 0.8267, Precision: 0.8279, Recall: 0.5872, F1-score: 0.6871
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 43/50 - Accuracy: 0.9333, Loss: 0.1396, Val Accuracy: 0.7193, Val Loss: 0.8665, Precision: 0.8649, Recall: 0.5581, F1-score: 0.6784
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 44/50 - Accuracy: 0.9333, Loss: 0.1404, Val Accuracy: 0.7018, Val Loss: 0.9106, Precision: 0.9135, Recall: 0.5523, F1-score: 0.6884
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 45/50 - Accuracy: 0.9067, Loss: 0.1506, Val Accuracy: 0.7368, Val Loss: 0.9920, Precision: 0.9684, Recall: 0.5349, F1-score: 0.6891
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 46/50 - Accuracy: 0.9200, Loss: 0.1526, Val Accuracy: 0.7368, Val Loss: 0.9332, Precision: 0.9126, Recall: 0.5465, F1-score: 0.6836
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 47/50 - Accuracy: 0.9289, Loss: 0.1406, Val Accuracy: 0.7018, Val Loss: 0.8669, Precision: 0.8807, Recall: 0.5581, F1-score: 0.6833
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 48/50 - Accuracy: 0.9289, Loss: 0.1414, Val Accuracy: 0.7018, Val Loss: 0.8427, Precision: 0.8534, Recall: 0.5756, F1-score: 0.6875
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 49/50 - Accuracy: 0.9333, Loss: 0.1375, Val Accuracy: 0.7018, Val Loss: 0.8571, Precision: 0.8596, Recall: 0.5698, F1-score: 0.6853
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# 📌 Epoch 50/50 - Accuracy: 0.9422, Loss: 0.1334, Val Accuracy: 0.7193, Val Loss: 0.8741, Precision: 0.8818, Recall: 0.5640, F1-score: 0.6879
#
# 📊 History Dict:
# {1: {'accuracy': 0.9333333373069763, 'val_accuracy': 0.7017543911933899, 'loss': 0.1579260379076004, 'val_loss': 0.8380790948867798, 'precision': 0.912621359223301, 'recall': 0.5465116279069767, 'f1-score': 0.6836363636363636}, 2: {'accuracy': 0.902222216129303, 'val_accuracy': 0.719298243522644, 'loss': 0.17306838929653168, 'val_loss': 1.0371977090835571, 'precision': 0.9759036144578314, 'recall': 0.47093023255813954, 'f1-score': 0.6352941176470588}, 3: {'accuracy': 0.9155555367469788, 'val_accuracy': 0.7017543911933899, 'loss': 0.1868518739938736, 'val_loss': 0.8942532539367676, 'precision': 0.8910891089108911, 'recall': 0.5232558139534884, 'f1-score': 0.6593406593406593}, 4: {'accuracy': 0.9244444370269775, 'val_accuracy': 0.7017543911933899, 'loss': 0.17379622161388397, 'val_loss': 0.7915256023406982, 'precision': 0.847457627118644, 'recall': 0.5813953488372093, 'f1-score': 0.6896551724137931}, 5: {'accuracy': 0.9244444370269775, 'val_accuracy': 0.6842105388641357, 'loss': 0.1733003556728363, 'val_loss': 0.7981124520301819, 'precision': 0.8521739130434782, 'recall': 0.5697674418604651, 'f1-score': 0.6829268292682927}, 6: {'accuracy': 0.9288889169692993, 'val_accuracy': 0.719298243522644, 'loss': 0.1627914160490036, 'val_loss': 0.847323477268219, 'precision': 0.8921568627450981, 'recall': 0.5290697674418605, 'f1-score': 0.6642335766423357}, 7: {'accuracy': 0.9244444370269775, 'val_accuracy': 0.719298243522644, 'loss': 0.1631527841091156, 'val_loss': 0.8265331983566284, 'precision': 0.8796296296296297, 'recall': 0.5523255813953488, 'f1-score': 0.6785714285714286}, 8: {'accuracy': 0.9200000166893005, 'val_accuracy': 0.719298243522644, 'loss': 0.16495098173618317, 'val_loss': 0.721187949180603, 'precision': 0.8, 'recall': 0.5813953488372093, 'f1-score': 0.6734006734006734}, 9: {'accuracy': 0.9155555367469788, 'val_accuracy': 0.719298243522644, 'loss': 0.1658547818660736, 'val_loss': 0.7790127396583557, 'precision': 0.868421052631579, 'recall': 0.5755813953488372, 'f1-score': 0.6923076923076923}, 10: {'accuracy': 0.9244444370269775, 'val_accuracy': 0.6842105388641357, 'loss': 0.1708623468875885, 'val_loss': 0.8980139493942261, 'precision': 0.9270833333333334, 'recall': 0.5174418604651163, 'f1-score': 0.664179104477612}, 11: {'accuracy': 0.9200000166893005, 'val_accuracy': 0.7368420958518982, 'loss': 0.1670013964176178, 'val_loss': 0.834017813205719, 'precision': 0.91, 'recall': 0.5290697674418605, 'f1-score': 0.6691176470588235}, 12: {'accuracy': 0.9333333373069763, 'val_accuracy': 0.7017543911933899, 'loss': 0.16021417081356049, 'val_loss': 0.7896903157234192, 'precision': 0.8796296296296297, 'recall': 0.5523255813953488, 'f1-score': 0.6785714285714286}, 13: {'accuracy': 0.9155555367469788, 'val_accuracy': 0.7719298005104065, 'loss': 0.1659330427646637, 'val_loss': 0.8227658271789551, 'precision': 0.8932038834951457, 'recall': 0.5348837209302325, 'f1-score': 0.6690909090909091}, 14: {'accuracy': 0.9155555367469788, 'val_accuracy': 0.7017543911933899, 'loss': 0.164462149143219, 'val_loss': 0.793186366558075, 'precision': 0.8888888888888888, 'recall': 0.5581395348837209, 'f1-score': 0.6857142857142857}, 15: {'accuracy': 0.9244444370269775, 'val_accuracy': 0.7017543911933899, 'loss': 0.15739737451076508, 'val_loss': 0.7962461709976196, 'precision': 0.8738738738738738, 'recall': 0.563953488372093, 'f1-score': 0.6855123674911661}, 16: {'accuracy': 0.9333333373069763, 'val_accuracy': 0.7017543911933899, 'loss': 0.1533210724592209, 'val_loss': 0.7830610871315002, 'precision': 0.868421052631579, 'recall': 0.5755813953488372, 'f1-score': 0.6923076923076923}, 17: {'accuracy': 0.9288889169692993, 'val_accuracy': 0.7017543911933899, 'loss': 0.1505722999572754, 'val_loss': 0.7987601161003113, 'precision': 0.8672566371681416, 'recall': 0.5697674418604651, 'f1-score': 0.6877192982456141}, 18: {'accuracy': 0.9333333373069763, 'val_accuracy': 0.719298243522644, 'loss': 0.1536685824394226, 'val_loss': 0.8350579738616943, 'precision': 0.88888888 ...

# %%
import matplotlib.pyplot as plt

# Kiểm tra và trích xuất dữ liệu từ history_dict
epochs_values = list(history_dict.keys())

train_acc = [history_dict[ep].get("accuracy", None) for ep in epochs_values]
val_acc = [history_dict[ep].get("val_accuracy", None) for ep in epochs_values]
train_loss = [history_dict[ep].get("loss", None) for ep in epochs_values]
val_loss = [history_dict[ep].get("val_loss", None) for ep in epochs_values]
precision = [history_dict[ep].get("precision", None) for ep in epochs_values]
recall = [history_dict[ep].get("recall", None) for ep in epochs_values]
f1_score = [history_dict[ep].get("f1-score", None) for ep in epochs_values]

# Tạo biểu đồ
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 🔹 1. Vẽ biểu đồ Accuracy
axes[0, 0].plot(epochs_values, train_acc, marker='o', label="Train Accuracy", color='b')
axes[0, 0].plot(epochs_values, val_acc, marker='s', label="Validation Accuracy", color='g')
axes[0, 0].set_xlabel("Epochs")
axes[0, 0].set_ylabel("Accuracy")
axes[0, 0].set_title("Train & Validation Accuracy vs. Epochs")
axes[0, 0].legend()
axes[0, 0].grid()

# 🔹 2. Vẽ biểu đồ Loss
axes[0, 1].plot(epochs_values, train_loss, marker='o', label="Train Loss", color='r')
axes[0, 1].plot(epochs_values, val_loss, marker='s', label="Validation Loss", color='purple')
axes[0, 1].set_xlabel("Epochs")
axes[0, 1].set_ylabel("Loss")
axes[0, 1].set_title("Train & Validation Loss vs. Epochs")
axes[0, 1].legend()
axes[0, 1].grid()

# 🔹 3. Vẽ biểu đồ Precision, Recall, F1-score
axes[1, 0].plot(epochs_values, precision, marker='o', label="Precision", color='orange')
axes[1, 0].plot(epochs_values, recall, marker='s', label="Recall", color='brown')
axes[1, 0].plot(epochs_values, f1_score, marker='^', label="F1-Score", color='cyan')
axes[1, 0].set_xlabel("Epochs")
axes[1, 0].set_ylabel("Score")
axes[1, 0].set_title("Precision, Recall & F1-Score vs. Epochs")
axes[1, 0].legend()
axes[1, 0].grid()

# Ẩn ô trống (nếu có)
axes[1, 1].axis("off")

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %% [markdown]
# ## THỬ BUILD MÔ HÌNH ĐƠN GIẢN GIỐNG TRONG BÀI BÁO

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout, Input, Concatenate, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# 🔹 Số epochs để huấn luyện
epochs = 50
history_dict = {}

# 🔹 Cập nhật các tham số cho mô hình
MAX_SEQUENCE_LENGTH = 100
EMBEDDING_DIM = 30
NUM_TRADITIONAL_FEATURES = X_train_traditional.shape[1]  # Số đặc trưng truyền thống
FILTERS = 250
KERNEL_SIZE = 5
DENSE_UNITS = 100
DROPOUT_RATE = 0.1
LEARNING_RATE = 0.001
vocab_size = len(tokenizer.word_index) + 1  # Cập nhật vocab_size từ tokenizer

# 🔹 Định nghĩa mô hình với Embedding layer cho token
input_layer_cnn = Input(shape=(MAX_SEQUENCE_LENGTH,))  # (None, 100)
embedding_layer = Embedding(input_dim=vocab_size, output_dim=EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH)(input_layer_cnn)

# Lớp Conv1D và MaxPooling
conv_layer = Conv1D(filters=FILTERS, kernel_size=KERNEL_SIZE, activation='relu')(embedding_layer)
pool_layer = GlobalMaxPooling1D()(conv_layer)

# Lớp Fully Connected (FC)
dense_layer = Dense(DENSE_UNITS, activation='relu')(pool_layer)
dropout_layer = Dropout(DROPOUT_RATE)(dense_layer)

# Kết hợp với các đặc trưng truyền thống
input_layer_traditional = Input(shape=(NUM_TRADITIONAL_FEATURES,))
merged_features = Concatenate()([dropout_layer, input_layer_traditional])

# Lớp Output (Sigmoid)
output_layer = Dense(1, activation='sigmoid')(merged_features)

# Tạo mô hình tổng hợp
model = Model(inputs=[input_layer_cnn, input_layer_traditional], outputs=output_layer)

# Compile mô hình với learning rate thấp hơn
optimizer = Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# 🔹 Tạo callback để in kết quả sau mỗi epoch
class MetricsCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        # Dự đoán trên tập test ngay sau epoch hiện tại
        y_pred = (self.model.predict([X_test, X_test_traditional]) > 0.5).astype("int32")

        # Tính Classification Report đúng cách
        report = classification_report(y_test, y_pred, output_dict=True)

        # Lưu lịch sử từng epoch
        history_dict[epoch + 1] = {
            "accuracy": logs["accuracy"],
            "val_accuracy": logs["val_accuracy"],
            "loss": logs["loss"],
            "val_loss": logs["val_loss"],
            "precision": report["1"]["precision"] if "1" in report else 0,
            "recall": report["1"]["recall"] if "1" in report else 0,
            "f1-score": report["1"]["f1-score"] if "1" in report else 0
        }

        # 🔥 In kết quả sau mỗi epoch
        print(f"\n📌 Epoch {epoch + 1}/{epochs} - "
              f"Accuracy: {logs['accuracy']:.4f}, "
              f"Loss: {logs['loss']:.4f}, "
              f"Val Accuracy: {logs['val_accuracy']:.4f}, "
              f"Val Loss: {logs['val_loss']:.4f}, "
              f"Precision: {history_dict[epoch + 1]['precision']:.4f}, "
              f"Recall: {history_dict[epoch + 1]['recall']:.4f}, "
              f"F1-score: {history_dict[epoch + 1]['f1-score']:.4f}")

# 🔹 Huấn luyện mô hình với callback tùy chỉnh
history = model.fit(
    [X_train, X_train_traditional], y_train,
    validation_data=([X_val, X_val_traditional], y_val),
    epochs=epochs, batch_size=32, verbose=0,
    callbacks=[MetricsCallback()]
)

# 🔹 In toàn bộ lịch sử sau khi huấn luyện xong
print("\n📊 History Dict:")
print(history_dict)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_20            │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_7 (Embedding)   │ (None, 100, 30)        │         59,640 │ input_layer_20[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_16 (Conv1D)        │ (None, 96, 250)        │         37,750 │ embedding_7[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling1d_10   │ (None, 250)            │              0 │ conv1d_16[0][0]        │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_26 (Dense)          │ (None, 100)            │         25,100 │ global_max_pooling1d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_10 (Dropout)      │ (None, 100)            │              0 │ dense_26[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_21            │ (None, 20)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 120)            │              0 │ dropout_10[0][0],      │
# │ (Concatenate)             │                        │                │ input_layer_21[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_27 (Dense)          │ (None, 1)              │            121 │ concatenate_10[0][0]   │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 122,611 (478.95 KB)
#  Trainable params: 122,611 (478.95 KB)
#  Non-trainable params: 0 (0.00 B)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
#
# 📌 Epoch 1/50 - Accuracy: 0.4000, Loss: 0.7812, Val Accuracy: 0.5439, Val Loss: 0.7210, Precision: 0.4805, Recall: 0.2151, F1-score: 0.2972
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 2/50 - Accuracy: 0.5156, Loss: 0.7477, Val Accuracy: 0.6140, Val Loss: 0.7029, Precision: 0.6410, Recall: 0.1453, F1-score: 0.2370
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 📌 Epoch 3/50 - Accuracy: 0.5556, Loss: 0.7252, Val Accuracy: 0.6491, Val Loss: 0.6865, Precision: 0.6667, Recall: 0.1279, F1-score: 0.2146
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# 📌 Epoch 4/50 - Accuracy: 0.5511, Loss: 0.6984, Val Accuracy: 0.6316, Val Loss: 0.6657, Precision: 0.6964, Recall: 0.2267, F1-score: 0.3421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 5/50 - Accuracy: 0.5778, Loss: 0.6731, Val Accuracy: 0.6491, Val Loss: 0.6464, Precision: 0.6981, Recall: 0.2151, F1-score: 0.3289
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# 📌 Epoch 6/50 - Accuracy: 0.6133, Loss: 0.6451, Val Accuracy: 0.6316, Val Loss: 0.6352, Precision: 0.7600, Recall: 0.2209, F1-score: 0.3423
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 7/50 - Accuracy: 0.6400, Loss: 0.6185, Val Accuracy: 0.6140, Val Loss: 0.6220, Precision: 0.7800, Recall: 0.2267, F1-score: 0.3514
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 8/50 - Accuracy: 0.6667, Loss: 0.5819, Val Accuracy: 0.6667, Val Loss: 0.5899, Precision: 0.7761, Recall: 0.3023, F1-score: 0.4351
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 9/50 - Accuracy: 0.7600, Loss: 0.5360, Val Accuracy: 0.7719, Val Loss: 0.5528, Precision: 0.7534, Recall: 0.6395, F1-score: 0.6918
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 10/50 - Accuracy: 0.7911, Loss: 0.5120, Val Accuracy: 0.7895, Val Loss: 0.5165, Precision: 0.7943, Recall: 0.6512, F1-score: 0.7157
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 11/50 - Accuracy: 0.8356, Loss: 0.4399, Val Accuracy: 0.7895, Val Loss: 0.5067, Precision: 0.8319, Recall: 0.5465, F1-score: 0.6596
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 12/50 - Accuracy: 0.8489, Loss: 0.3866, Val Accuracy: 0.8070, Val Loss: 0.4847, Precision: 0.8182, Recall: 0.5756, F1-score: 0.6758
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 13/50 - Accuracy: 0.8533, Loss: 0.3349, Val Accuracy: 0.7719, Val Loss: 0.5062, Precision: 0.8198, Recall: 0.5291, F1-score: 0.6431
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 14/50 - Accuracy: 0.8667, Loss: 0.2953, Val Accuracy: 0.7719, Val Loss: 0.5058, Precision: 0.8103, Recall: 0.5465, F1-score: 0.6528
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
# 📌 Epoch 15/50 - Accuracy: 0.8711, Loss: 0.2661, Val Accuracy: 0.7895, Val Loss: 0.4941, Precision: 0.8110, Recall: 0.5988, F1-score: 0.6890
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# 📌 Epoch 16/50 - Accuracy: 0.8489, Loss: 0.2671, Val Accuracy: 0.7895, Val Loss: 0.5001, Precision: 0.7895, Recall: 0.6105, F1-score: 0.6885
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 17/50 - Accuracy: 0.9022, Loss: 0.2264, Val Accuracy: 0.7018, Val Loss: 0.6636, Precision: 0.8571, Recall: 0.4884, F1-score: 0.6222
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 18/50 - Accuracy: 0.8489, Loss: 0.2765, Val Accuracy: 0.7193, Val Loss: 0.6637, Precision: 0.8447, Recall: 0.5058, F1-score: 0.6327
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 19/50 - Accuracy: 0.8756, Loss: 0.2506, Val Accuracy: 0.7719, Val Loss: 0.5054, Precision: 0.7682, Recall: 0.6744, F1-score: 0.7183
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 20/50 - Accuracy: 0.8800, Loss: 0.2419, Val Accuracy: 0.7544, Val Loss: 0.5798, Precision: 0.8246, Recall: 0.5465, F1-score: 0.6573
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 21/50 - Accuracy: 0.8978, Loss: 0.2216, Val Accuracy: 0.7018, Val Loss: 0.6374, Precision: 0.8505, Recall: 0.5291, F1-score: 0.6523
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 22/50 - Accuracy: 0.8844, Loss: 0.2171, Val Accuracy: 0.7544, Val Loss: 0.5898, Precision: 0.8190, Recall: 0.5523, F1-score: 0.6597
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 23/50 - Accuracy: 0.9111, Loss: 0.2053, Val Accuracy: 0.7544, Val Loss: 0.6093, Precision: 0.8190, Recall: 0.5523, F1-score: 0.6597
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 24/50 - Accuracy: 0.9067, Loss: 0.2040, Val Accuracy: 0.7368, Val Loss: 0.6111, Precision: 0.8220, Recall: 0.5640, F1-score: 0.6690
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 25/50 - Accuracy: 0.8889, Loss: 0.1962, Val Accuracy: 0.7719, Val Loss: 0.5479, Precision: 0.7468, Recall: 0.6686, F1-score: 0.7055
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 26/50 - Accuracy: 0.8489, Loss: 0.2575, Val Accuracy: 0.7719, Val Loss: 0.5992, Precision: 0.7852, Recall: 0.6163, F1-score: 0.6906
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 27/50 - Accuracy: 0.8933, Loss: 0.2063, Val Accuracy: 0.7018, Val Loss: 0.7602, Precision: 0.8750, Recall: 0.4884, F1-score: 0.6269
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 28/50 - Accuracy: 0.8800, Loss: 0.2056, Val Accuracy: 0.7368, Val Loss: 0.6964, Precision: 0.8426, Recall: 0.5291, F1-score: 0.6500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 29/50 - Accuracy: 0.9067, Loss: 0.1867, Val Accuracy: 0.7018, Val Loss: 0.7011, Precision: 0.8440, Recall: 0.5349, F1-score: 0.6548
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 30/50 - Accuracy: 0.9022, Loss: 0.2088, Val Accuracy: 0.6491, Val Loss: 0.8821, Precision: 0.8989, Recall: 0.4651, F1-score: 0.6130
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 31/50 - Accuracy: 0.8844, Loss: 0.2232, Val Accuracy: 0.6667, Val Loss: 0.7433, Precision: 0.8273, Recall: 0.5291, F1-score: 0.6454
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 32/50 - Accuracy: 0.9200, Loss: 0.1896, Val Accuracy: 0.7368, Val Loss: 0.6807, Precision: 0.7953, Recall: 0.5872, F1-score: 0.6756
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 33/50 - Accuracy: 0.9111, Loss: 0.1883, Val Accuracy: 0.7544, Val Loss: 0.7012, Precision: 0.7984, Recall: 0.5756, F1-score: 0.6689
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 34/50 - Accuracy: 0.9111, Loss: 0.1877, Val Accuracy: 0.6842, Val Loss: 0.7318, Precision: 0.8407, Recall: 0.5523, F1-score: 0.6667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 35/50 - Accuracy: 0.9422, Loss: 0.1835, Val Accuracy: 0.6842, Val Loss: 0.7554, Precision: 0.8440, Recall: 0.5349, F1-score: 0.6548
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 36/50 - Accuracy: 0.9200, Loss: 0.1815, Val Accuracy: 0.7018, Val Loss: 0.7409, Precision: 0.8393, Recall: 0.5465, F1-score: 0.6620
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📌 Epoch 37/50 - Accuracy: 0.9244, Loss: 0.1736, Val Accuracy: 0.7018, Val Loss: 0.7288, Precision: 0.8333, Recall: 0.5523, F1-score: 0.6643
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# 📌 Epoch 38/50 - Accuracy: 0.9022, Loss: 0.1887, Val Accuracy: 0.7018, Val Loss: 0.8088, Precision: 0.8641, Recall: 0.5174, F1-score: 0.6473
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 39/50 - Accuracy: 0.9200, Loss: 0.1797, Val Accuracy: 0.7018, Val Loss: 0.7429, Precision: 0.8455, Recall: 0.5407, F1-score: 0.6596
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 40/50 - Accuracy: 0.9156, Loss: 0.1753, Val Accuracy: 0.7193, Val Loss: 0.6826, Precision: 0.8031, Recall: 0.5930, F1-score: 0.6823
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 41/50 - Accuracy: 0.8800, Loss: 0.2012, Val Accuracy: 0.7719, Val Loss: 0.6630, Precision: 0.8030, Recall: 0.6163, F1-score: 0.6974
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# 📌 Epoch 42/50 - Accuracy: 0.9200, Loss: 0.1841, Val Accuracy: 0.7193, Val Loss: 0.7537, Precision: 0.8624, Recall: 0.5465, F1-score: 0.6690
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 43/50 - Accuracy: 0.9200, Loss: 0.1757, Val Accuracy: 0.7193, Val Loss: 0.7634, Precision: 0.8704, Recall: 0.5465, F1-score: 0.6714
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 44/50 - Accuracy: 0.9422, Loss: 0.1721, Val Accuracy: 0.7193, Val Loss: 0.7202, Precision: 0.8547, Recall: 0.5814, F1-score: 0.6920
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 45/50 - Accuracy: 0.9244, Loss: 0.1732, Val Accuracy: 0.7018, Val Loss: 0.8244, Precision: 0.8812, Recall: 0.5174, F1-score: 0.6520
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📌 Epoch 46/50 - Accuracy: 0.9156, Loss: 0.1825, Val Accuracy: 0.7018, Val Loss: 0.8064, Precision: 0.8667, Recall: 0.5291, F1-score: 0.6570
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 47/50 - Accuracy: 0.9111, Loss: 0.1672, Val Accuracy: 0.7193, Val Loss: 0.8085, Precision: 0.8661, Recall: 0.5640, F1-score: 0.6831
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 48/50 - Accuracy: 0.9022, Loss: 0.1698, Val Accuracy: 0.7193, Val Loss: 0.7596, Precision: 0.8175, Recall: 0.5988, F1-score: 0.6913
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 49/50 - Accuracy: 0.8889, Loss: 0.1848, Val Accuracy: 0.7018, Val Loss: 0.7184, Precision: 0.7970, Recall: 0.6163, F1-score: 0.6951
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# 📌 Epoch 50/50 - Accuracy: 0.9111, Loss: 0.1768, Val Accuracy: 0.7018, Val Loss: 0.9236, Precision: 0.9158, Recall: 0.5058, F1-score: 0.6517
#
# 📊 History Dict:
# {1: {'accuracy': 0.4000000059604645, 'val_accuracy': 0.5438596606254578, 'loss': 0.7812159657478333, 'val_loss': 0.720981240272522, 'precision': 0.4805194805194805, 'recall': 0.21511627906976744, 'f1-score': 0.2971887550200803}, 2: {'accuracy': 0.5155555605888367, 'val_accuracy': 0.6140350699424744, 'loss': 0.7477299571037292, 'val_loss': 0.7029063105583191, 'precision': 0.6410256410256411, 'recall': 0.14534883720930233, 'f1-score': 0.23696682464454977}, 3: {'accuracy': 0.5555555820465088, 'val_accuracy': 0.6491228342056274, 'loss': 0.7251583337783813, 'val_loss': 0.6865260004997253, 'precision': 0.6666666666666666, 'recall': 0.12790697674418605, 'f1-score': 0.2146341463414634}, 4: {'accuracy': 0.551111102104187, 'val_accuracy': 0.6315789222717285, 'loss': 0.6983577013015747, 'val_loss': 0.6656855344772339, 'precision': 0.6964285714285714, 'recall': 0.22674418604651161, 'f1-score': 0.34210526315789475}, 5: {'accuracy': 0.5777778029441833, 'val_accuracy': 0.6491228342056274, 'loss': 0.673118531703949, 'val_loss': 0.6463979482650757, 'precision': 0.6981132075471698, 'recall': 0.21511627906976744, 'f1-score': 0.3288888888888889}, 6: {'accuracy': 0.6133333444595337, 'val_accuracy': 0.6315789222717285, 'loss': 0.6450758576393127, 'val_loss': 0.6352254152297974, 'precision': 0.76, 'recall': 0.22093023255813954, 'f1-score': 0.34234234234234234}, 7: {'accuracy': 0.6399999856948853, 'val_accuracy': 0.6140350699424744, 'loss': 0.6185461282730103, 'val_loss': 0.6220114231109619, 'precision': 0.78, 'recall': 0.22674418604651161, 'f1-score': 0.35135135135135137}, 8: {'accuracy': 0.6666666865348816, 'val_accuracy': 0.6666666865348816, 'loss': 0.5819123387336731, 'val_loss': 0.5899128913879395, 'precision': 0.7761194029850746, 'recall': 0.3023255813953488, 'f1-score': 0.4351464435146444}, 9: {'accuracy': 0.7599999904632568, 'val_accuracy': 0.7719298005104065, 'loss': 0.5359674692153931, 'val_loss': 0.5527633428573608, 'precision': 0.7534246575342466, 'recall': 0.6395348837209303, 'f1-score': 0.6918238993710691}, 10: {'accuracy': 0.7911111116409302, 'val_accuracy': 0.7894737124443054, 'loss': 0.5120209455490112, 'val_loss': 0.5165472030639648, 'precision': 0.7943262411347518, 'recall': 0.6511627906976745, 'f1-score': 0.7156549520766773}, 11: {'accuracy': 0.8355555534362793, 'val_accuracy': 0.7894737124443054, 'loss': 0.4398742616176605, 'val_loss': 0.5066880583763123, 'precision': 0.831858407079646, 'recall': 0.5465116279069767, 'f1-score': 0.6596491228070176}, 12: {'accuracy': 0.8488888740539551, 'val_accuracy': 0.8070175647735596, 'loss': 0.3865634500980377, 'val_loss': 0.4847000539302826, 'precision': 0.8181818181818182, 'recall': 0.5755813953488372, 'f1-score': 0.6757679180887372}, 13: {'accuracy': 0.8533333539962769, 'val_accuracy': 0.7719298005104065, 'loss': 0.3349226415157318, 'val_loss': 0.5062083601951599, 'precision': 0.8198198198198198, 'recall': 0.5290697674418605, 'f1-score': 0.6431095406360424}, 14: {'accuracy': 0.8666666746139526, 'val_accuracy': 0.7719298005104065, 'loss': 0.29531362652778625, 'val_loss': 0.5057685375213623, 'precision': 0.8103448275862069, 'recall': 0.5465116279069767, 'f1-score': 0.6527777777777778}, 15: {'accuracy': 0.8711110949516296, 'val_accuracy': 0.7894737124443054, 'loss': 0.26609012484550476, 'val_loss': 0.4940771162509918, 'precision': 0.8110236220472441, 'recall': 0.5988372093023255, 'f1-score': 0.6889632107023411}, 16: {'accuracy': 0.8488888740539551, 'val_accuracy': 0.7894737124443054, 'loss': 0.26706835627555847, 'val_loss': 0.500079333782196, 'precision': 0.7894736842105263, 'recall': 0.6104651162790697, 'f1-score': 0.6885245901639344}, 17: {'accuracy': 0.902222216129303, 'val_accuracy': 0.7017543911933899, 'loss': 0.22642724215984344, 'val_loss': 0.6635725498199463, 'precision': 0.8571428571428571, 'recall': 0.4883720930232558, 'f1-score': 0.6222222222222222}, 18: {'accuracy': 0.8488888740539551, 'val_accuracy': 0.719298243522644, 'loss': 0.2765021324157715, 'val_loss': 0.6637186408042908, 'p ...

# %%
import matplotlib.pyplot as plt

# Kiểm tra và trích xuất dữ liệu từ history_dict
epochs_values = list(history_dict.keys())

train_acc = [history_dict[ep].get("accuracy", None) for ep in epochs_values]
val_acc = [history_dict[ep].get("val_accuracy", None) for ep in epochs_values]
train_loss = [history_dict[ep].get("loss", None) for ep in epochs_values]
val_loss = [history_dict[ep].get("val_loss", None) for ep in epochs_values]
precision = [history_dict[ep].get("precision", None) for ep in epochs_values]
recall = [history_dict[ep].get("recall", None) for ep in epochs_values]
f1_score = [history_dict[ep].get("f1-score", None) for ep in epochs_values]

# Tạo biểu đồ
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 🔹 1. Vẽ biểu đồ Accuracy
axes[0, 0].plot(epochs_values, train_acc, marker='o', label="Train Accuracy", color='b')
axes[0, 0].plot(epochs_values, val_acc, marker='s', label="Validation Accuracy", color='g')
axes[0, 0].set_xlabel("Epochs")
axes[0, 0].set_ylabel("Accuracy")
axes[0, 0].set_title("Train & Validation Accuracy vs. Epochs")
axes[0, 0].legend()
axes[0, 0].grid()

# 🔹 2. Vẽ biểu đồ Loss
axes[0, 1].plot(epochs_values, train_loss, marker='o', label="Train Loss", color='r')
axes[0, 1].plot(epochs_values, val_loss, marker='s', label="Validation Loss", color='purple')
axes[0, 1].set_xlabel("Epochs")
axes[0, 1].set_ylabel("Loss")
axes[0, 1].set_title("Train & Validation Loss vs. Epochs")
axes[0, 1].legend()
axes[0, 1].grid()

# 🔹 3. Vẽ biểu đồ Precision, Recall, F1-score
axes[1, 0].plot(epochs_values, precision, marker='o', label="Precision", color='orange')
axes[1, 0].plot(epochs_values, recall, marker='s', label="Recall", color='brown')
axes[1, 0].plot(epochs_values, f1_score, marker='^', label="F1-Score", color='cyan')
axes[1, 0].set_xlabel("Epochs")
axes[1, 0].set_ylabel("Score")
axes[1, 0].set_title("Precision, Recall & F1-Score vs. Epochs")
axes[1, 0].legend()
axes[1, 0].grid()

# Ẩn ô trống (nếu có)
axes[1, 1].axis("off")

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()
